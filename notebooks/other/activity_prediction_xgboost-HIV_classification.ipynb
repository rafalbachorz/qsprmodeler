# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "xgboost"
RESULT_FILE_REGRESSOR = "result_regressor_xgboost.csv"
RESULT_FILE_CLASSIFIER = "result_classifier_xgboost_HIV.csv" #
# Out:
# C:\Users\aleks\anaconda3\envs\rorgammaqsar\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-10-07 12:12:58,351 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 11:35:53,970 - logger - INFO - Training configuration:
# 2022-10-07 11:35:53,972 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-10-07 11:35:53,973 - logger - INFO - Prediction type: classification
# 2022-10-07 11:35:53,974 - logger - INFO - Data file: HIV.csv
# 2022-10-07 11:35:53,975 - logger - INFO - Max. activity level: 1
# 2022-10-07 11:35:53,976 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 11:35:53,976 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 11:35:53,977 - logger - INFO - Model storage: model_xgboost_classifier_QED_mean_no_limits_HIV.model
# 2022-10-07 11:35:53,977 - logger - INFO - Pipeline configuration:
# 2022-10-07 11:35:53,978 - logger - INFO - FPs?: no
# 2022-10-07 11:35:53,978 - logger - INFO - MDs?: yes
# 2022-10-07 11:35:53,979 - logger - INFO - Scaling?: no
# 2022-10-07 11:35:53,979 - logger - INFO - PCA?: no
# 2022-10-07 11:35:53,980 - logger - INFO - Target transform?: no
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limit

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:13:05,755 - logger - INFO - Training configuration:
# 2022-10-07 12:13:05,756 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-10-07 12:13:05,757 - logger - INFO - Prediction type: classification
# 2022-10-07 12:13:05,758 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:13:05,759 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:13:05,760 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:13:05,761 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:13:05,762 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_mean_no_limits_HIV.model
# 2022-10-07 12:13:05,762 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:13:05,764 - logger - INFO - FPs?: yes
# 2022-10-07 12:13:05,765 - logger - INFO - FP size?: 1024
# 2022-10-07 12:13:05,766 - logger - INFO - MDs?: no
# 2022-10-07 12:13:05,767 - logger - INFO - Scaling?: no
# 2022-10-07 12:13:05,768 - logger - INFO - PCA?: no
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:14:36,782 - logger - INFO - Training configuration:
# 2022-10-07 12:14:36,783 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-10-07 12:14:36,784 - logger - INFO - Prediction type: classification
# 2022-10-07 12:14:36,785 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:14:36,785 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:14:36,786 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:14:36,786 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:14:36,787 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_pca_128_QED_mean_no_limits_HIV.model
# 2022-10-07 12:14:36,788 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:14:36,788 - logger - INFO - FPs?: yes
# 2022-10-07 12:14:36,789 - logger - INFO - FP size?: 1024
# 2022-10-07 12:14:36,790 - logger - INFO - MDs?: yes
# 2022-10-07 12:14:36,791 - logger - INFO - Scaling?: no
# 2022-10-07 12:14:36,791 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:24:59,069 - logger - INFO - Training configuration:
# 2022-10-07 12:24:59,070 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-10-07 12:24:59,071 - logger - INFO - Prediction type: classification
# 2022-10-07 12:24:59,072 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:24:59,073 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:24:59,074 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:24:59,075 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:24:59,076 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_pca_256_QED_mean_no_limits_HIV.model
# 2022-10-07 12:24:59,077 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:24:59,077 - logger - INFO - FPs?: yes
# 2022-10-07 12:24:59,078 - logger - INFO - FP size?: 1024
# 2022-10-07 12:24:59,079 - logger - INFO - MDs?: yes
# 2022-10-07 12:24:59,080 - logger - INFO - Scaling?: no
# 2022-10-07 12:24:59,081 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:35:01,095 - logger - INFO - Training configuration:
# 2022-10-07 12:35:01,096 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-10-07 12:35:01,097 - logger - INFO - Prediction type: classification
# 2022-10-07 12:35:01,098 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:35:01,099 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:35:01,100 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:35:01,101 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:35:01,101 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_pca_512_QED_mean_no_limits_HIV.model
# 2022-10-07 12:35:01,102 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:35:01,103 - logger - INFO - FPs?: yes
# 2022-10-07 12:35:01,104 - logger - INFO - FP size?: 1024
# 2022-10-07 12:35:01,107 - logger - INFO - MDs?: yes
# 2022-10-07 12:35:01,107 - logger - INFO - Scaling?: no
# 2022-10-07 12:35:01,108 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:44:53,793 - logger - INFO - Training configuration:
# 2022-10-07 12:44:53,794 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-10-07 12:44:53,795 - logger - INFO - Prediction type: classification
# 2022-10-07 12:44:53,796 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:44:53,797 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:44:53,798 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:44:53,799 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:44:53,800 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_pca_1024_QED_mean_no_limits_HIV.model
# 2022-10-07 12:44:53,801 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:44:53,802 - logger - INFO - FPs?: yes
# 2022-10-07 12:44:53,803 - logger - INFO - FP size?: 1024
# 2022-10-07 12:44:53,804 - logger - INFO - MDs?: yes
# 2022-10-07 12:44:53,807 - logger - INFO - Scaling?: no
# 2022-10-07 12:44:53,807 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)
