# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "bagging"
RESULT_FILE_REGRESSOR = "result_regressor_bagging.csv"
RESULT_FILE_CLASSIFIER = "result_classifier_bagging_HIV.csv"
# Out:
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-10-07 12:56:49.706217: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-10-07 12:56:51,493 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:56:51,515 - logger - INFO - Training configuration:
# 2022-10-07 12:56:51,516 - logger - INFO - Prediction methodology: M_Bagging
# 2022-10-07 12:56:51,517 - logger - INFO - Prediction type: classification
# 2022-10-07 12:56:51,517 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:56:51,518 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:56:51,519 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:56:51,520 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:56:51,520 - logger - INFO - Model storage: model_bagging_classifier_QED_mean_no_limit_HIV.model
# 2022-10-07 12:56:51,521 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:56:51,522 - logger - INFO - FPs?: no
# 2022-10-07 12:56:51,523 - logger - INFO - MDs?: yes
# 2022-10-07 12:56:51,523 - logger - INFO - Scaling?: no
# 2022-10-07 12:56:51,524 - logger - INFO - PCA?: no
# 2022-10-07 12:56:51,525 - logger - INFO - Target transform?: no
# 2022-10-07 12:56:51,526 - logger - INFO - Target binarization?: no
# 2022-10-07 12:56:51,577 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.8024001590508345, 'max_samples': 0.8086577985712339, 'n_estimators': 41, 'oob_score': False, 'verbose': 0, 'warm_start': False, 'n_jobs': 8}
# 2022-10-07 12:56:51,578 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:56:51,579 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:56:51,581 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:56:51,582 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 319.36it/s]
# 2022-10-07 12:57:12,705 - logger - INFO - Precision on hold-out: 0.527778
# 2022-10-07 12:57:12,706 - logger - INFO - Recall on hold-out: 0.136691
# 2022-10-07 12:57:12,707 - logger - INFO - Accuracy on hold-out: 0.966691
# 2022-10-07 12:57:12,708 - logger - INFO - F1-score on hold-out: 0.217143
# 2022-10-07 12:57:12,708 - logger - INFO - ROC-AUC on hold-out: 0.566206
# 2022-10-07 12:57:12,709 - logger - INFO - Average precision on hold-out: 0.101318
# 2022-10-07 12:57:12,709 - logger - INFO - MCC on hold-out: 0.256880
# 2022-10-07 12:57:12,897 - logger - INFO - Performance on training set
# 2022-10-07 12:57:12,898 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:57:12,898 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:57:12,899 - logger - INFO - CreateFPS transform...
# [12:57:17] WARNING: not removing hydrogen atom without neighbors
# [12:57:17] WARNING: not removing hydrogen atom without neighbors
# [12:58:46] WARNING: not removing hydrogen atom without neighbors
# [12:58:46] WARNING: not removing hydrogen atom without neighbors
# [12:58:46] WARNING: not removing hydrogen atom without neighbors
# [12:58:46] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:02<00:00, 302.58it/s]
# [13:00:04] WARNING: not removing hydrogen atom without neighbors
# [13:00:04] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:00:20,153 - logger - INFO - Precision on training: 0.988139
# 2022-10-07 13:00:20,154 - logger - INFO - Recall on training: 0.830521
# 2022-10-07 13:00:20,155 - logger - INFO - Accuracy on training: 0.993678
# 2022-10-07 13:00:20,156 - logger - INFO - F1-score on training: 0.902500
# 2022-10-07 13:00:20,157 - logger - INFO - ROC-AUC on training: 0.915079
# 2022-10-07 13:00:20,157 - logger - INFO - Average precision on training: 0.826641
# 2022-10-07 13:00:20,158 - logger - INFO - MCC on training 0.902886

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limit

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:00:21,049 - logger - INFO - Training configuration:
# 2022-10-07 13:00:21,050 - logger - INFO - Prediction methodology: M_Bagging
# 2022-10-07 13:00:21,051 - logger - INFO - Prediction type: classification
# 2022-10-07 13:00:21,052 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:00:21,053 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:00:21,053 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:00:21,054 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:00:21,054 - logger - INFO - Model storage: model_bagging_classifier_Morgan_1024_mean_no_limit_HIV.model
# 2022-10-07 13:00:21,055 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:00:21,057 - logger - INFO - FPs?: yes
# 2022-10-07 13:00:21,058 - logger - INFO - FP size?: 1024
# 2022-10-07 13:00:21,059 - logger - INFO - MDs?: no
# 2022-10-07 13:00:21,060 - logger - INFO - Scaling?: no
# 2022-10-07 13:00:21,061 - logger - INFO - PCA?: no
# 2022-10-07 13:00:21,062 - logger - INFO - Target transform?: no
# 2022-10-07 13:00:21,063 - logger - INFO - Target binarization?: no
# 2022-10-07 13:00:21,706 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.8290298023988811, 'max_samples': 0.7519422183730745, 'n_estimators': 45, 'oob_score': False, 'verbose': 0, 'warm_start': False, 'n_jobs': 8}
# 2022-10-07 13:00:21,708 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:00:21,709 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:21,710 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:21,711 - logger - INFO - CreateFPS transform...
# 2022-10-07 13:00:25,394 - logger - INFO - Precision on hold-out: 0.712329
# 2022-10-07 13:00:25,397 - logger - INFO - Recall on hold-out: 0.374101
# 2022-10-07 13:00:25,398 - logger - INFO - Accuracy on hold-out: 0.973742
# 2022-10-07 13:00:25,399 - logger - INFO - F1-score on hold-out: 0.490566
# 2022-10-07 13:00:25,400 - logger - INFO - ROC-AUC on hold-out: 0.684408
# 2022-10-07 13:00:25,401 - logger - INFO - Average precision on hold-out: 0.287635
# 2022-10-07 13:00:25,402 - logger - INFO - MCC on hold-out: 0.504754
# 2022-10-07 13:00:25,583 - logger - INFO - Performance on training set
# 2022-10-07 13:00:25,585 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:25,587 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:25,588 - logger - INFO - CreateFPS transform...
# [13:00:30] WARNING: not removing hydrogen atom without neighbors
# [13:00:30] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:00:55,976 - logger - INFO - Precision on training: 0.989538
# 2022-10-07 13:00:55,978 - logger - INFO - Recall on training: 0.870399
# 2022-10-07 13:00:55,979 - logger - INFO - Accuracy on training: 0.995110
# 2022-10-07 13:00:55,980 - logger - INFO - F1-score on training: 0.926153
# 2022-10-07 13:00:55,981 - logger - INFO - ROC-AUC on training: 0.935031
# 2022-10-07 13:00:55,982 - logger - INFO - Average precision on training: 0.865858
# 2022-10-07 13:00:55,982 - logger - INFO - MCC on training 0.925668

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:00:56,906 - logger - INFO - Training configuration:
# 2022-10-07 13:00:56,906 - logger - INFO - Prediction methodology: M_Bagging
# 2022-10-07 13:00:56,907 - logger - INFO - Prediction type: classification
# 2022-10-07 13:00:56,908 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:00:56,908 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:00:56,909 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:00:56,910 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:00:56,910 - logger - INFO - Model storage: model_bagging_classifier_Morgan_1024_pca_128_QED_mean_no_limit_HIV.model
# 2022-10-07 13:00:56,911 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:00:56,912 - logger - INFO - FPs?: yes
# 2022-10-07 13:00:56,912 - logger - INFO - FP size?: 1024
# 2022-10-07 13:00:56,913 - logger - INFO - MDs?: yes
# 2022-10-07 13:00:56,913 - logger - INFO - Scaling?: no
# 2022-10-07 13:00:56,914 - logger - INFO - PCA?: yes
# 2022-10-07 13:00:56,914 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:00:56,914 - logger - INFO - PCA - number of components: 128
# 2022-10-07 13:00:56,915 - logger - INFO - Target transform?: no
# 2022-10-07 13:00:56,915 - logger - INFO - Target binarization?: no
# 2022-10-07 13:00:57,568 - logger - INFO - PCA constructor...
# 2022-10-07 13:00:57,569 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7551060274119887, 'max_samples': 0.7923655136685849, 'n_estimators': 32, 'oob_score': False, 'verbose': 0, 'warm_start': False, 'n_jobs': 8}
# 2022-10-07 13:00:57,571 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:00:57,572 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:57,573 - logger - INFO - CreateFPS transform...
# [13:01:02] WARNING: not removing hydrogen atom without neighbors
# [13:01:02] WARNING: not removing hydrogen atom without neighbors
# [13:02:50] WARNING: not removing hydrogen atom without neighbors
# [13:02:50] WARNING: not removing hydrogen atom without neighbors
# [13:02:50] WARNING: not removing hydrogen atom without neighbors
# [13:02:50] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:57<00:00, 314.36it/s]
# [13:04:02] WARNING: not removing hydrogen atom without neighbors
# [13:04:02] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:04:17,559 - logger - INFO - Scaler fit...
# 2022-10-07 13:04:24,704 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:04:24,706 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:13<00:00, 309.94it/s]
# 2022-10-07 13:04:50,550 - logger - INFO - PCA transform...
# 2022-10-07 13:04:51,168 - logger - INFO - Precision on hold-out: 0.825000
# 2022-10-07 13:04:51,170 - logger - INFO - Recall on hold-out: 0.237410
# 2022-10-07 13:04:51,171 - logger - INFO - Accuracy on hold-out: 0.972526
# 2022-10-07 13:04:51,171 - logger - INFO - F1-score on hold-out: 0.368715
# 2022-10-07 13:04:51,172 - logger - INFO - ROC-AUC on hold-out: 0.617824
# 2022-10-07 13:04:51,172 - logger - INFO - Average precision on hold-out: 0.221635
# 2022-10-07 13:04:51,173 - logger - INFO - MCC on hold-out: 0.433909
# 2022-10-07 13:04:51,342 - logger - INFO - Performance on training set
# 2022-10-07 13:04:51,343 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:04:51,344 - logger - INFO - CreateFPS transform...
# [13:04:56] WARNING: not removing hydrogen atom without neighbors
# [13:04:56] WARNING: not removing hydrogen atom without neighbors
# [13:06:48] WARNING: not removing hydrogen atom without neighbors
# [13:06:48] WARNING: not removing hydrogen atom without neighbors
# [13:06:48] WARNING: not removing hydrogen atom without neighbors
# [13:06:48] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:08<00:00, 288.33it/s]
# [13:08:07] WARNING: not removing hydrogen atom without neighbors
# [13:08:07] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:08:32,668 - logger - INFO - Scaler fit...
# 2022-10-07 13:08:39,841 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:08:39,843 - logger - INFO - CreateFPS transform...
# [13:08:44] WARNING: not removing hydrogen atom without neighbors
# [13:08:44] WARNING: not removing hydrogen atom without neighbors
# [13:10:42] WARNING: not removing hydrogen atom without neighbors
# [13:10:42] WARNING: not removing hydrogen atom without neighbors
# [13:10:42] WARNING: not removing hydrogen atom without neighbors
# [13:10:42] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:02<00:00, 302.43it/s]
# [13:11:59] WARNING: not removing hydrogen atom without neighbors
# [13:11:59] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:12:15,081 - logger - INFO - PCA transform...
# 2022-10-07 13:12:17,867 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:12:17,869 - logger - INFO - Recall on training: 0.842025
# 2022-10-07 13:12:17,870 - logger - INFO - Accuracy on training: 0.994435
# 2022-10-07 13:12:17,871 - logger - INFO - F1-score on training: 0.914238
# 2022-10-07 13:12:17,872 - logger - INFO - ROC-AUC on training: 0.921012
# 2022-10-07 13:12:17,872 - logger - INFO - Average precision on training: 0.847590
# 2022-10-07 13:12:17,873 - logger - INFO - MCC on training 0.914984

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:12:18,776 - logger - INFO - Training configuration:
# 2022-10-07 13:12:18,776 - logger - INFO - Prediction methodology: M_Bagging
# 2022-10-07 13:12:18,777 - logger - INFO - Prediction type: classification
# 2022-10-07 13:12:18,778 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:12:18,778 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:12:18,779 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:12:18,779 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:12:18,780 - logger - INFO - Model storage: model_bagging_classifier_Morgan_1024_pca_256_QED_mean_no_limit_HIV.model
# 2022-10-07 13:12:18,781 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:12:18,781 - logger - INFO - FPs?: yes
# 2022-10-07 13:12:18,782 - logger - INFO - FP size?: 1024
# 2022-10-07 13:12:18,782 - logger - INFO - MDs?: yes
# 2022-10-07 13:12:18,783 - logger - INFO - Scaling?: no
# 2022-10-07 13:12:18,783 - logger - INFO - PCA?: yes
# 2022-10-07 13:12:18,784 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:12:18,785 - logger - INFO - PCA - number of components: 256
# 2022-10-07 13:12:18,785 - logger - INFO - Target transform?: no
# 2022-10-07 13:12:18,786 - logger - INFO - Target binarization?: no
# 2022-10-07 13:12:19,431 - logger - INFO - PCA constructor...
# 2022-10-07 13:12:19,433 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.8031986728551728, 'max_samples': 0.7810210376118932, 'n_estimators': 26, 'oob_score': False, 'verbose': 0, 'warm_start': False, 'n_jobs': 8}
# 2022-10-07 13:12:19,433 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:12:19,434 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:12:19,435 - logger - INFO - CreateFPS transform...
# [13:12:24] WARNING: not removing hydrogen atom without neighbors
# [13:12:24] WARNING: not removing hydrogen atom without neighbors
# [13:14:17] WARNING: not removing hydrogen atom without neighbors
# [13:14:17] WARNING: not removing hydrogen atom without neighbors
# [13:14:17] WARNING: not removing hydrogen atom without neighbors
# [13:14:17] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:01<00:00, 305.69it/s]
# [13:15:26] WARNING: not removing hydrogen atom without neighbors
# [13:15:26] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:15:41,781 - logger - INFO - Scaler fit...
# 2022-10-07 13:15:54,660 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:15:54,662 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:19<00:00, 208.22it/s]
# 2022-10-07 13:16:22,966 - logger - INFO - PCA transform...
# 2022-10-07 13:16:23,483 - logger - INFO - Precision on hold-out: 0.731707
# 2022-10-07 13:16:23,485 - logger - INFO - Recall on hold-out: 0.215827
# 2022-10-07 13:16:23,486 - logger - INFO - Accuracy on hold-out: 0.970824
# 2022-10-07 13:16:23,487 - logger - INFO - F1-score on hold-out: 0.333333
# 2022-10-07 13:16:23,489 - logger - INFO - ROC-AUC on hold-out: 0.606530
# 2022-10-07 13:16:23,490 - logger - INFO - Average precision on hold-out: 0.184424
# 2022-10-07 13:16:23,491 - logger - INFO - MCC on hold-out: 0.387549
# 2022-10-07 13:16:23,674 - logger - INFO - Performance on training set
# 2022-10-07 13:16:23,675 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:16:23,677 - logger - INFO - CreateFPS transform...
# [13:16:28] WARNING: not removing hydrogen atom without neighbors
# [13:16:28] WARNING: not removing hydrogen atom without neighbors
# [13:18:16] WARNING: not removing hydrogen atom without neighbors
# [13:18:16] WARNING: not removing hydrogen atom without neighbors
# [13:18:16] WARNING: not removing hydrogen atom without neighbors
# [13:18:16] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:10<00:00, 284.49it/s]
# [13:19:39] WARNING: not removing hydrogen atom without neighbors
# [13:19:39] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:19:54,416 - logger - INFO - Scaler fit...
# 2022-10-07 13:20:18,360 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:20:18,363 - logger - INFO - CreateFPS transform...
# [13:20:28] WARNING: not removing hydrogen atom without neighbors
# [13:20:28] WARNING: not removing hydrogen atom without neighbors
# [13:22:20] WARNING: not removing hydrogen atom without neighbors
# [13:22:20] WARNING: not removing hydrogen atom without neighbors
# [13:22:20] WARNING: not removing hydrogen atom without neighbors
# [13:22:20] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [01:52<00:00, 330.18it/s]
# [13:23:41] WARNING: not removing hydrogen atom without neighbors
# [13:23:41] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:23:56,317 - logger - INFO - PCA transform...
# 2022-10-07 13:23:59,378 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:23:59,379 - logger - INFO - Recall on training: 0.792945
# 2022-10-07 13:23:59,380 - logger - INFO - Accuracy on training: 0.992705
# 2022-10-07 13:23:59,381 - logger - INFO - F1-score on training: 0.884517
# 2022-10-07 13:23:59,382 - logger - INFO - ROC-AUC on training: 0.896472
# 2022-10-07 13:23:59,382 - logger - INFO - Average precision on training: 0.800239
# 2022-10-07 13:23:59,383 - logger - INFO - MCC on training 0.887127

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:24:00,259 - logger - INFO - Training configuration:
# 2022-10-07 13:24:00,259 - logger - INFO - Prediction methodology: M_Bagging
# 2022-10-07 13:24:00,260 - logger - INFO - Prediction type: classification
# 2022-10-07 13:24:00,260 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:24:00,260 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:24:00,261 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:24:00,261 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:24:00,262 - logger - INFO - Model storage: model_bagging_classifier_Morgan_1024_pca_512_QED_mean_no_limit_HIV.model
# 2022-10-07 13:24:00,262 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:24:00,262 - logger - INFO - FPs?: yes
# 2022-10-07 13:24:00,263 - logger - INFO - FP size?: 1024
# 2022-10-07 13:24:00,263 - logger - INFO - MDs?: yes
# 2022-10-07 13:24:00,263 - logger - INFO - Scaling?: no
# 2022-10-07 13:24:00,264 - logger - INFO - PCA?: yes
# 2022-10-07 13:24:00,264 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:24:00,264 - logger - INFO - PCA - number of components: 512
# 2022-10-07 13:24:00,266 - logger - INFO - Target transform?: no
# 2022-10-07 13:24:00,266 - logger - INFO - Target binarization?: no
# 2022-10-07 13:24:01,176 - logger - INFO - PCA constructor...
# 2022-10-07 13:24:01,178 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.8508554920075141, 'max_samples': 0.7809398018448157, 'n_estimators': 64, 'oob_score': False, 'verbose': 0, 'warm_start': False, 'n_jobs': 8}
# 2022-10-07 13:24:01,179 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:24:01,180 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:24:01,181 - logger - INFO - CreateFPS transform...
# [13:24:05] WARNING: not removing hydrogen atom without neighbors
# [13:24:05] WARNING: not removing hydrogen atom without neighbors
# [13:26:05] WARNING: not removing hydrogen atom without neighbors
# [13:26:05] WARNING: not removing hydrogen atom without neighbors
# [13:26:05] WARNING: not removing hydrogen atom without neighbors
# [13:26:05] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:04<00:00, 297.99it/s]
# [13:27:14] WARNING: not removing hydrogen atom without neighbors
# [13:27:14] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:27:28,966 - logger - INFO - Scaler fit...
# 2022-10-07 13:27:57,302 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:27:57,304 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 323.93it/s]
# 2022-10-07 13:28:18,965 - logger - INFO - PCA transform...
# 2022-10-07 13:28:19,689 - logger - INFO - Precision on hold-out: 0.756098
# 2022-10-07 13:28:19,691 - logger - INFO - Recall on hold-out: 0.223022
# 2022-10-07 13:28:19,692 - logger - INFO - Accuracy on hold-out: 0.971310
# 2022-10-07 13:28:19,693 - logger - INFO - F1-score on hold-out: 0.344444
# 2022-10-07 13:28:19,694 - logger - INFO - ROC-AUC on hold-out: 0.610253
# 2022-10-07 13:28:19,694 - logger - INFO - Average precision on hold-out: 0.194884
# 2022-10-07 13:28:19,695 - logger - INFO - MCC on hold-out: 0.401092
# 2022-10-07 13:28:19,878 - logger - INFO - Performance on training set
# 2022-10-07 13:28:19,879 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:28:19,880 - logger - INFO - CreateFPS transform...
# [13:28:24] WARNING: not removing hydrogen atom without neighbors
# [13:28:24] WARNING: not removing hydrogen atom without neighbors
# [13:30:28] WARNING: not removing hydrogen atom without neighbors
# [13:30:28] WARNING: not removing hydrogen atom without neighbors
# [13:30:28] WARNING: not removing hydrogen atom without neighbors
# [13:30:28] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:06<00:00, 292.16it/s]
# [13:31:47] WARNING: not removing hydrogen atom without neighbors
# [13:31:47] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:32:08,163 - logger - INFO - Scaler fit...
# 2022-10-07 13:32:35,946 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:32:35,954 - logger - INFO - CreateFPS transform...
# [13:32:40] WARNING: not removing hydrogen atom without neighbors
# [13:32:40] WARNING: not removing hydrogen atom without neighbors
# [13:34:45] WARNING: not removing hydrogen atom without neighbors
# [13:34:45] WARNING: not removing hydrogen atom without neighbors
# [13:34:45] WARNING: not removing hydrogen atom without neighbors
# [13:34:45] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:10<00:00, 283.41it/s]
# [13:36:03] WARNING: not removing hydrogen atom without neighbors
# [13:36:03] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:36:19,798 - logger - INFO - PCA transform...
# 2022-10-07 13:36:28,251 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:36:28,254 - logger - INFO - Recall on training: 0.885736
# 2022-10-07 13:36:28,255 - logger - INFO - Accuracy on training: 0.995974
# 2022-10-07 13:36:28,256 - logger - INFO - F1-score on training: 0.939406
# 2022-10-07 13:36:28,257 - logger - INFO - ROC-AUC on training: 0.942868
# 2022-10-07 13:36:28,258 - logger - INFO - Average precision on training: 0.889762
# 2022-10-07 13:36:28,259 - logger - INFO - MCC on training 0.939178

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:36:30,182 - logger - INFO - Training configuration:
# 2022-10-07 13:36:30,184 - logger - INFO - Prediction methodology: M_Bagging
# 2022-10-07 13:36:30,185 - logger - INFO - Prediction type: classification
# 2022-10-07 13:36:30,186 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:36:30,186 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:36:30,187 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:36:30,188 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:36:30,188 - logger - INFO - Model storage: model_bagging_classifier_Morgan_1024_pca_1024_QED_mean_no_limit_HIV.model
# 2022-10-07 13:36:30,189 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:36:30,189 - logger - INFO - FPs?: yes
# 2022-10-07 13:36:30,190 - logger - INFO - FP size?: 1024
# 2022-10-07 13:36:30,190 - logger - INFO - MDs?: yes
# 2022-10-07 13:36:30,191 - logger - INFO - Scaling?: no
# 2022-10-07 13:36:30,191 - logger - INFO - PCA?: yes
# 2022-10-07 13:36:30,192 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:36:30,192 - logger - INFO - PCA - number of components: 1024
# 2022-10-07 13:36:30,193 - logger - INFO - Target transform?: no
# 2022-10-07 13:36:30,196 - logger - INFO - Target binarization?: no
# 2022-10-07 13:36:31,149 - logger - INFO - PCA constructor...
# 2022-10-07 13:36:31,152 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'bootstrap_features': False, 'max_features': 0.7500791420427422, 'max_samples': 0.8108012251874923, 'n_estimators': 62, 'oob_score': False, 'verbose': 0, 'warm_start': False, 'n_jobs': 8}
# 2022-10-07 13:36:31,153 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:36:31,154 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:36:31,155 - logger - INFO - CreateFPS transform...
# [13:36:36] WARNING: not removing hydrogen atom without neighbors
# [13:36:36] WARNING: not removing hydrogen atom without neighbors
# [13:38:30] WARNING: not removing hydrogen atom without neighbors
# [13:38:30] WARNING: not removing hydrogen atom without neighbors
# [13:38:30] WARNING: not removing hydrogen atom without neighbors
# [13:38:30] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:05<00:00, 296.04it/s]
# [13:39:43] WARNING: not removing hydrogen atom without neighbors
# [13:39:43] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:39:59,287 - logger - INFO - Scaler fit...
# 2022-10-07 13:40:07,082 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:40:07,085 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 335.13it/s]
# 2022-10-07 13:40:32,124 - logger - INFO - PCA transform...
# 2022-10-07 13:40:33,136 - logger - INFO - Precision on hold-out: 0.818182
# 2022-10-07 13:40:33,137 - logger - INFO - Recall on hold-out: 0.194245
# 2022-10-07 13:40:33,137 - logger - INFO - Accuracy on hold-out: 0.971310
# 2022-10-07 13:40:33,138 - logger - INFO - F1-score on hold-out: 0.313953
# 2022-10-07 13:40:33,139 - logger - INFO - ROC-AUC on hold-out: 0.596367
# 2022-10-07 13:40:33,139 - logger - INFO - Average precision on hold-out: 0.186158
# 2022-10-07 13:40:33,139 - logger - INFO - MCC on hold-out: 0.390386
# 2022-10-07 13:40:33,296 - logger - INFO - Performance on training set
# 2022-10-07 13:40:33,297 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:40:33,297 - logger - INFO - CreateFPS transform...
# [13:40:37] WARNING: not removing hydrogen atom without neighbors
# [13:40:37] WARNING: not removing hydrogen atom without neighbors
# [13:42:16] WARNING: not removing hydrogen atom without neighbors
# [13:42:16] WARNING: not removing hydrogen atom without neighbors
# [13:42:16] WARNING: not removing hydrogen atom without neighbors
# [13:42:16] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [01:46<00:00, 347.45it/s]
# [13:43:20] WARNING: not removing hydrogen atom without neighbors
# [13:43:20] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:43:34,998 - logger - INFO - Scaler fit...
# 2022-10-07 13:43:43,476 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:43:43,478 - logger - INFO - CreateFPS transform...
# [13:43:47] WARNING: not removing hydrogen atom without neighbors
# [13:43:47] WARNING: not removing hydrogen atom without neighbors
# [13:45:31] WARNING: not removing hydrogen atom without neighbors
# [13:45:31] WARNING: not removing hydrogen atom without neighbors
# [13:45:31] WARNING: not removing hydrogen atom without neighbors
# [13:45:31] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [01:54<00:00, 322.23it/s]
# [13:46:48] WARNING: not removing hydrogen atom without neighbors
# [13:46:48] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:47:02,426 - logger - INFO - PCA transform...
# 2022-10-07 13:47:08,704 - logger - INFO - Precision on training: 0.999164
# 2022-10-07 13:47:08,706 - logger - INFO - Recall on training: 0.916411
# 2022-10-07 13:47:08,708 - logger - INFO - Accuracy on training: 0.997028
# 2022-10-07 13:47:08,709 - logger - INFO - F1-score on training: 0.956000
# 2022-10-07 13:47:08,710 - logger - INFO - ROC-AUC on training: 0.958192
# 2022-10-07 13:47:08,711 - logger - INFO - Average precision on training: 0.918590
# 2022-10-07 13:47:08,711 - logger - INFO - MCC on training 0.955420

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)
