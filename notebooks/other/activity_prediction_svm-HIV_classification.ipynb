# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "svm"
RESULT_FILE_REGRESSOR = "result_regressor_svm.csv"
RESULT_FILE_CLASSIFIER = "result_classifier_svm_HIV.csv"
# Out:
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-10-20 12:25:40.657779: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-10-20 12:25:43,378 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-20 11:34:22,605 - logger - INFO - Training configuration:
# 2022-10-20 11:34:22,606 - logger - INFO - Prediction methodology: M_SVM
# 2022-10-20 11:34:22,607 - logger - INFO - Prediction type: classification
# 2022-10-20 11:34:22,608 - logger - INFO - Data file: HIV.csv
# 2022-10-20 11:34:22,609 - logger - INFO - Max. activity level: 1
# 2022-10-20 11:34:22,610 - logger - INFO - Std. threshold: 1000000
# 2022-10-20 11:34:22,610 - logger - INFO - Data preparation strategy: mean
# 2022-10-20 11:34:22,610 - logger - INFO - Model storage: model_svm_classifier_QED_mean_no_limit_HIV.model
# 2022-10-20 11:34:22,611 - logger - INFO - Pipeline configuration:
# 2022-10-20 11:34:22,611 - logger - INFO - FPs?: no
# 2022-10-20 11:34:22,612 - logger - INFO - MDs?: yes
# 2022-10-20 11:34:22,612 - logger - INFO - Scaling?: yes
# 2022-10-20 11:34:22,613 - logger - INFO - PCA?: no
# 2022-10-20 11:34:22,613 - logger - INFO - Target transform?: no
# 2022-10-20 11:34:22,613 - logger - INFO - Target binarization?: no
# 2022-10-20 11:34:22,649 - logger - INFO - Scaler constructor...
# 2022-10-20 11:34:22,650 - logger - INFO - Optimal hyperparameters:, {'C': 0.2751266801694262, 'break_ties': False, 'cache_size': 200, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': True, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# 2022-10-20 11:34:22,652 - logger - INFO - Performance on external (hold-out) set
# 2022-10-20 11:34:22,652 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:34:22,653 - logger - INFO - CreateFPS transform...
# [11:34:26] WARNING: not removing hydrogen atom without neighbors
# [11:34:26] WARNING: not removing hydrogen atom without neighbors
# [11:35:45] WARNING: not removing hydrogen atom without neighbors
# [11:35:45] WARNING: not removing hydrogen atom without neighbors
# [11:35:45] WARNING: not removing hydrogen atom without neighbors
# [11:35:45] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:45<00:00, 351.08it/s]
# [11:36:48] WARNING: not removing hydrogen atom without neighbors
# [11:36:48] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:37:02,287 - logger - INFO - Scaler fit...
# 2022-10-20 11:37:02,297 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:37:02,298 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:11<00:00, 352.43it/s]
# 2022-10-20 11:37:19,924 - logger - INFO - Scaler transform...
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-20 11:37:20,509 - logger - INFO - Precision on hold-out: 0.000000
# 2022-10-20 11:37:20,510 - logger - INFO - Recall on hold-out: 0.000000
# 2022-10-20 11:37:20,511 - logger - INFO - Accuracy on hold-out: 0.966205
# 2022-10-20 11:37:20,512 - logger - INFO - F1-score on hold-out: 0.000000
# 2022-10-20 11:37:20,513 - logger - INFO - ROC-AUC on hold-out: 0.500000
# 2022-10-20 11:37:20,514 - logger - INFO - Average precision on hold-out: 0.033795
# 2022-10-20 11:37:20,514 - logger - INFO - MCC on hold-out: 0.000000
# 2022-10-20 11:37:20,666 - logger - INFO - Performance on training set
# 2022-10-20 11:37:20,667 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:37:20,668 - logger - INFO - CreateFPS transform...
# [11:37:25] WARNING: not removing hydrogen atom without neighbors
# [11:37:25] WARNING: not removing hydrogen atom without neighbors
# [11:38:43] WARNING: not removing hydrogen atom without neighbors
# [11:38:43] WARNING: not removing hydrogen atom without neighbors
# [11:38:43] WARNING: not removing hydrogen atom without neighbors
# [11:38:43] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:45<00:00, 350.26it/s]
# [11:39:46] WARNING: not removing hydrogen atom without neighbors
# [11:39:46] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:39:59,863 - logger - INFO - Scaler fit...
# 2022-10-20 11:39:59,872 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:39:59,874 - logger - INFO - CreateFPS transform...
# [11:40:03] WARNING: not removing hydrogen atom without neighbors
# [11:40:03] WARNING: not removing hydrogen atom without neighbors
# [11:41:22] WARNING: not removing hydrogen atom without neighbors
# [11:41:22] WARNING: not removing hydrogen atom without neighbors
# [11:41:22] WARNING: not removing hydrogen atom without neighbors
# [11:41:22] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:45<00:00, 352.39it/s]
# [11:42:25] WARNING: not removing hydrogen atom without neighbors
# [11:42:25] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:42:38,671 - logger - INFO - Scaler transform...
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-20 11:42:41,487 - logger - INFO - Precision on training: 0.000000
# 2022-10-20 11:42:41,488 - logger - INFO - Recall on training: 0.000000
# 2022-10-20 11:42:41,489 - logger - INFO - Accuracy on training: 0.964770
# 2022-10-20 11:42:41,490 - logger - INFO - F1-score on training: 0.000000
# 2022-10-20 11:42:41,491 - logger - INFO - ROC-AUC on training: 0.500000
# 2022-10-20 11:42:41,492 - logger - INFO - Average precision on training: 0.035230
# 2022-10-20 11:42:41,492 - logger - INFO - MCC on training 0.000000

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limit

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-20 11:42:42,228 - logger - INFO - Training configuration:
# 2022-10-20 11:42:42,230 - logger - INFO - Prediction methodology: M_SVM
# 2022-10-20 11:42:42,230 - logger - INFO - Prediction type: classification
# 2022-10-20 11:42:42,231 - logger - INFO - Data file: HIV.csv
# 2022-10-20 11:42:42,232 - logger - INFO - Max. activity level: 1
# 2022-10-20 11:42:42,233 - logger - INFO - Std. threshold: 1000000
# 2022-10-20 11:42:42,233 - logger - INFO - Data preparation strategy: mean
# 2022-10-20 11:42:42,234 - logger - INFO - Model storage: model_svm_classifier_Morgan_1024_mean_no_limit_HIV.model
# 2022-10-20 11:42:42,234 - logger - INFO - Pipeline configuration:
# 2022-10-20 11:42:42,235 - logger - INFO - FPs?: yes
# 2022-10-20 11:42:42,235 - logger - INFO - FP size?: 1024
# 2022-10-20 11:42:42,236 - logger - INFO - MDs?: no
# 2022-10-20 11:42:42,236 - logger - INFO - Scaling?: no
# 2022-10-20 11:42:42,236 - logger - INFO - PCA?: no
# 2022-10-20 11:42:42,237 - logger - INFO - Target transform?: no
# 2022-10-20 11:42:42,237 - logger - INFO - Target binarization?: no
# 2022-10-20 11:42:42,440 - logger - INFO - Optimal hyperparameters:, {'C': 1.9964739933836433, 'break_ties': False, 'cache_size': 200, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': True, 'shrinking': False, 'tol': 0.001, 'verbose': False}
# 2022-10-20 11:42:42,441 - logger - INFO - Performance on external (hold-out) set
# 2022-10-20 11:42:42,442 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:42:42,443 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:42:42,444 - logger - INFO - CreateFPS transform...
# 2022-10-20 11:42:52,851 - logger - INFO - Precision on hold-out: 0.869565
# 2022-10-20 11:42:52,853 - logger - INFO - Recall on hold-out: 0.143885
# 2022-10-20 11:42:52,854 - logger - INFO - Accuracy on hold-out: 0.970338
# 2022-10-20 11:42:52,854 - logger - INFO - F1-score on hold-out: 0.246914
# 2022-10-20 11:42:52,855 - logger - INFO - ROC-AUC on hold-out: 0.571565
# 2022-10-20 11:42:52,855 - logger - INFO - Average precision on hold-out: 0.154050
# 2022-10-20 11:42:52,856 - logger - INFO - MCC on hold-out: 0.346838
# 2022-10-20 11:42:53,012 - logger - INFO - Performance on training set
# 2022-10-20 11:42:53,013 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:42:53,014 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:42:53,014 - logger - INFO - CreateFPS transform...
# [11:42:57] WARNING: not removing hydrogen atom without neighbors
# [11:42:57] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:44:24,551 - logger - INFO - Precision on training: 0.895753
# 2022-10-20 11:44:24,553 - logger - INFO - Recall on training: 0.177914
# 2022-10-20 11:44:24,554 - logger - INFO - Accuracy on training: 0.970309
# 2022-10-20 11:44:24,555 - logger - INFO - F1-score on training: 0.296865
# 2022-10-20 11:44:24,556 - logger - INFO - ROC-AUC on training: 0.588579
# 2022-10-20 11:44:24,557 - logger - INFO - Average precision on training: 0.188329
# 2022-10-20 11:44:24,558 - logger - INFO - MCC on training 0.391820

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-20 11:44:25,306 - logger - INFO - Training configuration:
# 2022-10-20 11:44:25,307 - logger - INFO - Prediction methodology: M_SVM
# 2022-10-20 11:44:25,308 - logger - INFO - Prediction type: classification
# 2022-10-20 11:44:25,308 - logger - INFO - Data file: HIV.csv
# 2022-10-20 11:44:25,309 - logger - INFO - Max. activity level: 1
# 2022-10-20 11:44:25,310 - logger - INFO - Std. threshold: 1000000
# 2022-10-20 11:44:25,310 - logger - INFO - Data preparation strategy: mean
# 2022-10-20 11:44:25,311 - logger - INFO - Model storage: model_svm_classifier_Morgan_1024_pca_128_QED_mean_no_limit_HIV.model
# 2022-10-20 11:44:25,313 - logger - INFO - Pipeline configuration:
# 2022-10-20 11:44:25,314 - logger - INFO - FPs?: yes
# 2022-10-20 11:44:25,314 - logger - INFO - FP size?: 1024
# 2022-10-20 11:44:25,315 - logger - INFO - MDs?: yes
# 2022-10-20 11:44:25,315 - logger - INFO - Scaling?: yes
# 2022-10-20 11:44:25,316 - logger - INFO - PCA?: yes
# 2022-10-20 11:44:25,316 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-20 11:44:25,317 - logger - INFO - PCA - number of components: 128
# 2022-10-20 11:44:25,317 - logger - INFO - Target transform?: no
# 2022-10-20 11:44:25,317 - logger - INFO - Target binarization?: no
# 2022-10-20 11:44:25,509 - logger - INFO - Scaler constructor...
# 2022-10-20 11:44:25,510 - logger - INFO - PCA constructor...
# 2022-10-20 11:44:25,511 - logger - INFO - Optimal hyperparameters:, {'C': 0.9686236062970939, 'break_ties': False, 'cache_size': 200, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'poly', 'max_iter': -1, 'probability': True, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# 2022-10-20 11:44:25,512 - logger - INFO - Performance on external (hold-out) set
# 2022-10-20 11:44:25,513 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:44:25,514 - logger - INFO - CreateFPS transform...
# [11:44:29] WARNING: not removing hydrogen atom without neighbors
# [11:44:29] WARNING: not removing hydrogen atom without neighbors
# [11:46:07] WARNING: not removing hydrogen atom without neighbors
# [11:46:07] WARNING: not removing hydrogen atom without neighbors
# [11:46:07] WARNING: not removing hydrogen atom without neighbors
# [11:46:07] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:46<00:00, 346.85it/s]
# [11:47:11] WARNING: not removing hydrogen atom without neighbors
# [11:47:11] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:47:25,185 - logger - INFO - Scaler fit...
# 2022-10-20 11:47:25,445 - logger - INFO - Scaler transform...
# 2022-10-20 11:47:25,821 - logger - INFO - Scaler fit...
# 2022-10-20 11:47:28,762 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:47:28,763 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:11<00:00, 353.51it/s]
# 2022-10-20 11:47:48,052 - logger - INFO - Scaler transform...
# 2022-10-20 11:47:48,103 - logger - INFO - PCA transform...
# 2022-10-20 11:47:50,680 - logger - INFO - Precision on hold-out: 0.772727
# 2022-10-20 11:47:50,681 - logger - INFO - Recall on hold-out: 0.244604
# 2022-10-20 11:47:50,681 - logger - INFO - Accuracy on hold-out: 0.972040
# 2022-10-20 11:47:50,682 - logger - INFO - F1-score on hold-out: 0.371585
# 2022-10-20 11:47:50,682 - logger - INFO - ROC-AUC on hold-out: 0.621044
# 2022-10-20 11:47:50,683 - logger - INFO - Average precision on hold-out: 0.214541
# 2022-10-20 11:47:50,683 - logger - INFO - MCC on hold-out: 0.425230
# 2022-10-20 11:47:50,824 - logger - INFO - Performance on training set
# 2022-10-20 11:47:50,825 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:47:50,826 - logger - INFO - CreateFPS transform...
# [11:47:55] WARNING: not removing hydrogen atom without neighbors
# [11:47:55] WARNING: not removing hydrogen atom without neighbors
# [11:49:28] WARNING: not removing hydrogen atom without neighbors
# [11:49:28] WARNING: not removing hydrogen atom without neighbors
# [11:49:28] WARNING: not removing hydrogen atom without neighbors
# [11:49:28] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:41<00:00, 362.91it/s]
# [11:50:30] WARNING: not removing hydrogen atom without neighbors
# [11:50:30] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:50:43,613 - logger - INFO - Scaler fit...
# 2022-10-20 11:50:43,868 - logger - INFO - Scaler transform...
# 2022-10-20 11:50:44,233 - logger - INFO - Scaler fit...
# 2022-10-20 11:50:47,006 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:50:47,006 - logger - INFO - CreateFPS transform...
# [11:50:51] WARNING: not removing hydrogen atom without neighbors
# [11:50:51] WARNING: not removing hydrogen atom without neighbors
# [11:52:23] WARNING: not removing hydrogen atom without neighbors
# [11:52:23] WARNING: not removing hydrogen atom without neighbors
# [11:52:23] WARNING: not removing hydrogen atom without neighbors
# [11:52:23] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:42<00:00, 361.68it/s]
# [11:53:26] WARNING: not removing hydrogen atom without neighbors
# [11:53:26] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:53:39,777 - logger - INFO - Scaler transform...
# 2022-10-20 11:53:40,405 - logger - INFO - PCA transform...
# 2022-10-20 11:54:01,735 - logger - INFO - Precision on training: 0.969450
# 2022-10-20 11:54:01,737 - logger - INFO - Recall on training: 0.365031
# 2022-10-20 11:54:01,739 - logger - INFO - Accuracy on training: 0.977225
# 2022-10-20 11:54:01,740 - logger - INFO - F1-score on training: 0.530362
# 2022-10-20 11:54:01,741 - logger - INFO - ROC-AUC on training: 0.682305
# 2022-10-20 11:54:01,741 - logger - INFO - Average precision on training: 0.376249
# 2022-10-20 11:54:01,742 - logger - INFO - MCC on training 0.587542

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-20 11:54:02,479 - logger - INFO - Training configuration:
# 2022-10-20 11:54:02,480 - logger - INFO - Prediction methodology: M_SVM
# 2022-10-20 11:54:02,481 - logger - INFO - Prediction type: classification
# 2022-10-20 11:54:02,482 - logger - INFO - Data file: HIV.csv
# 2022-10-20 11:54:02,482 - logger - INFO - Max. activity level: 1
# 2022-10-20 11:54:02,483 - logger - INFO - Std. threshold: 1000000
# 2022-10-20 11:54:02,484 - logger - INFO - Data preparation strategy: mean
# 2022-10-20 11:54:02,484 - logger - INFO - Model storage: model_svm_classifier_Morgan_1024_pca_256_QED_mean_no_limit_HIV.model
# 2022-10-20 11:54:02,485 - logger - INFO - Pipeline configuration:
# 2022-10-20 11:54:02,485 - logger - INFO - FPs?: yes
# 2022-10-20 11:54:02,486 - logger - INFO - FP size?: 1024
# 2022-10-20 11:54:02,487 - logger - INFO - MDs?: yes
# 2022-10-20 11:54:02,487 - logger - INFO - Scaling?: yes
# 2022-10-20 11:54:02,488 - logger - INFO - PCA?: yes
# 2022-10-20 11:54:02,488 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-20 11:54:02,489 - logger - INFO - PCA - number of components: 256
# 2022-10-20 11:54:02,490 - logger - INFO - Target transform?: no
# 2022-10-20 11:54:02,490 - logger - INFO - Target binarization?: no
# 2022-10-20 11:54:03,240 - logger - INFO - Scaler constructor...
# 2022-10-20 11:54:03,241 - logger - INFO - PCA constructor...
# 2022-10-20 11:54:03,242 - logger - INFO - Optimal hyperparameters:, {'C': 0.8531541678321188, 'break_ties': False, 'cache_size': 200, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'poly', 'max_iter': -1, 'probability': True, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# 2022-10-20 11:54:03,243 - logger - INFO - Performance on external (hold-out) set
# 2022-10-20 11:54:03,245 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:54:03,246 - logger - INFO - CreateFPS transform...
# [11:54:07] WARNING: not removing hydrogen atom without neighbors
# [11:54:07] WARNING: not removing hydrogen atom without neighbors
# [11:55:43] WARNING: not removing hydrogen atom without neighbors
# [11:55:43] WARNING: not removing hydrogen atom without neighbors
# [11:55:43] WARNING: not removing hydrogen atom without neighbors
# [11:55:43] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:44<00:00, 354.16it/s]
# [11:56:45] WARNING: not removing hydrogen atom without neighbors
# [11:56:45] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 11:56:59,443 - logger - INFO - Scaler fit...
# 2022-10-20 11:56:59,700 - logger - INFO - Scaler transform...
# 2022-10-20 11:57:00,075 - logger - INFO - Scaler fit...
# 2022-10-20 11:57:03,979 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:57:03,980 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:11<00:00, 356.39it/s]
# 2022-10-20 11:57:23,172 - logger - INFO - Scaler transform...
# 2022-10-20 11:57:23,216 - logger - INFO - PCA transform...
# 2022-10-20 11:57:28,530 - logger - INFO - Precision on hold-out: 0.744681
# 2022-10-20 11:57:28,531 - logger - INFO - Recall on hold-out: 0.251799
# 2022-10-20 11:57:28,532 - logger - INFO - Accuracy on hold-out: 0.971797
# 2022-10-20 11:57:28,533 - logger - INFO - F1-score on hold-out: 0.376344
# 2022-10-20 11:57:28,534 - logger - INFO - ROC-AUC on hold-out: 0.624389
# 2022-10-20 11:57:28,535 - logger - INFO - Average precision on hold-out: 0.212795
# 2022-10-20 11:57:28,536 - logger - INFO - MCC on hold-out: 0.422963
# 2022-10-20 11:57:28,703 - logger - INFO - Performance on training set
# 2022-10-20 11:57:28,704 - logger - INFO - CreateFPS fit...
# 2022-10-20 11:57:28,705 - logger - INFO - CreateFPS transform...
# [11:57:32] WARNING: not removing hydrogen atom without neighbors
# [11:57:32] WARNING: not removing hydrogen atom without neighbors
# [11:59:08] WARNING: not removing hydrogen atom without neighbors
# [11:59:08] WARNING: not removing hydrogen atom without neighbors
# [11:59:08] WARNING: not removing hydrogen atom without neighbors
# [11:59:08] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:45<00:00, 351.82it/s]
# [12:00:11] WARNING: not removing hydrogen atom without neighbors
# [12:00:11] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:00:24,817 - logger - INFO - Scaler fit...
# 2022-10-20 12:00:25,076 - logger - INFO - Scaler transform...
# 2022-10-20 12:00:25,451 - logger - INFO - Scaler fit...
# 2022-10-20 12:00:29,617 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:00:29,619 - logger - INFO - CreateFPS transform...
# [12:00:33] WARNING: not removing hydrogen atom without neighbors
# [12:00:33] WARNING: not removing hydrogen atom without neighbors
# [12:02:09] WARNING: not removing hydrogen atom without neighbors
# [12:02:09] WARNING: not removing hydrogen atom without neighbors
# [12:02:09] WARNING: not removing hydrogen atom without neighbors
# [12:02:09] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:44<00:00, 353.44it/s]
# [12:03:11] WARNING: not removing hydrogen atom without neighbors
# [12:03:11] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:03:24,582 - logger - INFO - Scaler transform...
# 2022-10-20 12:03:25,212 - logger - INFO - PCA transform...
# 2022-10-20 12:04:08,882 - logger - INFO - Precision on training: 0.972171
# 2022-10-20 12:04:08,885 - logger - INFO - Recall on training: 0.401840
# 2022-10-20 12:04:08,886 - logger - INFO - Accuracy on training: 0.978522
# 2022-10-20 12:04:08,887 - logger - INFO - F1-score on training: 0.568638
# 2022-10-20 12:04:08,888 - logger - INFO - ROC-AUC on training: 0.700710
# 2022-10-20 12:04:08,889 - logger - INFO - Average precision on training: 0.411731
# 2022-10-20 12:04:08,890 - logger - INFO - MCC on training 0.617790

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-20 12:09:52,606 - logger - INFO - Training configuration:
# 2022-10-20 12:09:52,608 - logger - INFO - Prediction methodology: M_SVM
# 2022-10-20 12:09:52,609 - logger - INFO - Prediction type: classification
# 2022-10-20 12:09:52,611 - logger - INFO - Data file: HIV.csv
# 2022-10-20 12:09:52,612 - logger - INFO - Max. activity level: 1
# 2022-10-20 12:09:52,613 - logger - INFO - Std. threshold: 1000000
# 2022-10-20 12:09:52,614 - logger - INFO - Data preparation strategy: mean
# 2022-10-20 12:09:52,615 - logger - INFO - Model storage: model_svm_classifier_Morgan_1024_pca_512_QED_mean_no_limit_HIV.model
# 2022-10-20 12:09:52,616 - logger - INFO - Pipeline configuration:
# 2022-10-20 12:09:52,616 - logger - INFO - FPs?: yes
# 2022-10-20 12:09:52,616 - logger - INFO - FP size?: 1024
# 2022-10-20 12:09:52,617 - logger - INFO - MDs?: yes
# 2022-10-20 12:09:52,617 - logger - INFO - Scaling?: yes
# 2022-10-20 12:09:52,618 - logger - INFO - PCA?: yes
# 2022-10-20 12:09:52,618 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-20 12:09:52,619 - logger - INFO - PCA - number of components: 512
# 2022-10-20 12:09:52,619 - logger - INFO - Target transform?: no
# 2022-10-20 12:09:52,620 - logger - INFO - Target binarization?: no
# 2022-10-20 12:09:52,892 - logger - INFO - Scaler constructor...
# 2022-10-20 12:09:52,893 - logger - INFO - PCA constructor...
# 2022-10-20 12:09:52,895 - logger - INFO - Optimal hyperparameters:, {'C': 1.5874140400935115, 'break_ties': False, 'cache_size': 200, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': True, 'shrinking': False, 'tol': 0.001, 'verbose': False}
# 2022-10-20 12:09:52,896 - logger - INFO - Performance on external (hold-out) set
# 2022-10-20 12:09:52,897 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:09:52,898 - logger - INFO - CreateFPS transform...
# [12:09:57] WARNING: not removing hydrogen atom without neighbors
# [12:09:57] WARNING: not removing hydrogen atom without neighbors
# [12:11:32] WARNING: not removing hydrogen atom without neighbors
# [12:11:32] WARNING: not removing hydrogen atom without neighbors
# [12:11:32] WARNING: not removing hydrogen atom without neighbors
# [12:11:32] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:44<00:00, 353.06it/s]
# [12:12:35] WARNING: not removing hydrogen atom without neighbors
# [12:12:35] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:12:49,070 - logger - INFO - Scaler fit...
# 2022-10-20 12:12:49,334 - logger - INFO - Scaler transform...
# 2022-10-20 12:12:49,607 - logger - INFO - Scaler fit...
# 2022-10-20 12:12:56,837 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:12:56,838 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:11<00:00, 354.25it/s]
# 2022-10-20 12:13:16,160 - logger - INFO - Scaler transform...
# 2022-10-20 12:13:16,231 - logger - INFO - PCA transform...
# 2022-10-20 12:13:20,084 - logger - INFO - Precision on hold-out: 0.794118
# 2022-10-20 12:13:20,086 - logger - INFO - Recall on hold-out: 0.194245
# 2022-10-20 12:13:20,087 - logger - INFO - Accuracy on hold-out: 0.971067
# 2022-10-20 12:13:20,088 - logger - INFO - F1-score on hold-out: 0.312139
# 2022-10-20 12:13:20,089 - logger - INFO - ROC-AUC on hold-out: 0.596242
# 2022-10-20 12:13:20,089 - logger - INFO - Average precision on hold-out: 0.181484
# 2022-10-20 12:13:20,089 - logger - INFO - MCC on hold-out: 0.384147
# 2022-10-20 12:13:20,226 - logger - INFO - Performance on training set
# 2022-10-20 12:13:20,227 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:13:20,227 - logger - INFO - CreateFPS transform...
# [12:13:24] WARNING: not removing hydrogen atom without neighbors
# [12:13:24] WARNING: not removing hydrogen atom without neighbors
# [12:15:00] WARNING: not removing hydrogen atom without neighbors
# [12:15:00] WARNING: not removing hydrogen atom without neighbors
# [12:15:00] WARNING: not removing hydrogen atom without neighbors
# [12:15:00] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:44<00:00, 355.85it/s]
# [12:16:01] WARNING: not removing hydrogen atom without neighbors
# [12:16:01] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:16:15,393 - logger - INFO - Scaler fit...
# 2022-10-20 12:16:15,648 - logger - INFO - Scaler transform...
# 2022-10-20 12:16:16,012 - logger - INFO - Scaler fit...
# 2022-10-20 12:16:23,377 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:16:23,378 - logger - INFO - CreateFPS transform...
# [12:16:27] WARNING: not removing hydrogen atom without neighbors
# [12:16:27] WARNING: not removing hydrogen atom without neighbors
# [12:18:01] WARNING: not removing hydrogen atom without neighbors
# [12:18:01] WARNING: not removing hydrogen atom without neighbors
# [12:18:01] WARNING: not removing hydrogen atom without neighbors
# [12:18:01] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:43<00:00, 358.91it/s]
# [12:19:03] WARNING: not removing hydrogen atom without neighbors
# [12:19:03] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:19:17,497 - logger - INFO - Scaler transform...
# 2022-10-20 12:19:18,121 - logger - INFO - PCA transform...
# 2022-10-20 12:19:48,048 - logger - INFO - Precision on training: 0.807074
# 2022-10-20 12:19:48,049 - logger - INFO - Recall on training: 0.192485
# 2022-10-20 12:19:48,050 - logger - INFO - Accuracy on training: 0.969930
# 2022-10-20 12:19:48,050 - logger - INFO - F1-score on training: 0.310836
# 2022-10-20 12:19:48,051 - logger - INFO - ROC-AUC on training: 0.595402
# 2022-10-20 12:19:48,051 - logger - INFO - Average precision on training: 0.183798
# 2022-10-20 12:19:48,052 - logger - INFO - MCC on training 0.385382

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-20 12:25:49,820 - logger - INFO - Training configuration:
# 2022-10-20 12:25:49,821 - logger - INFO - Prediction methodology: M_SVM
# 2022-10-20 12:25:49,823 - logger - INFO - Prediction type: classification
# 2022-10-20 12:25:49,824 - logger - INFO - Data file: HIV.csv
# 2022-10-20 12:25:49,825 - logger - INFO - Max. activity level: 1
# 2022-10-20 12:25:49,826 - logger - INFO - Std. threshold: 1000000
# 2022-10-20 12:25:49,827 - logger - INFO - Data preparation strategy: mean
# 2022-10-20 12:25:49,827 - logger - INFO - Model storage: model_svm_classifier_Morgan_1024_pca_1024_QED_mean_no_limit_HIV.model
# 2022-10-20 12:25:49,828 - logger - INFO - Pipeline configuration:
# 2022-10-20 12:25:49,828 - logger - INFO - FPs?: yes
# 2022-10-20 12:25:49,829 - logger - INFO - FP size?: 1024
# 2022-10-20 12:25:49,829 - logger - INFO - MDs?: yes
# 2022-10-20 12:25:49,830 - logger - INFO - Scaling?: yes
# 2022-10-20 12:25:49,830 - logger - INFO - PCA?: yes
# 2022-10-20 12:25:49,830 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-20 12:25:49,831 - logger - INFO - PCA - number of components: 1024
# 2022-10-20 12:25:49,831 - logger - INFO - Target transform?: no
# 2022-10-20 12:25:49,832 - logger - INFO - Target binarization?: no
# 2022-10-20 12:25:50,091 - logger - INFO - Scaler constructor...
# 2022-10-20 12:25:50,092 - logger - INFO - PCA constructor...
# 2022-10-20 12:25:50,093 - logger - INFO - Optimal hyperparameters:, {'C': 1.8357746029046778, 'break_ties': False, 'cache_size': 200, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': True, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# 2022-10-20 12:25:50,094 - logger - INFO - Performance on external (hold-out) set
# 2022-10-20 12:25:50,095 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:25:50,096 - logger - INFO - CreateFPS transform...
# [12:25:54] WARNING: not removing hydrogen atom without neighbors
# [12:25:54] WARNING: not removing hydrogen atom without neighbors
# [12:27:28] WARNING: not removing hydrogen atom without neighbors
# [12:27:28] WARNING: not removing hydrogen atom without neighbors
# [12:27:28] WARNING: not removing hydrogen atom without neighbors
# [12:27:28] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████| 37014/37014 [01:42<00:00, 360.70it/s]
# [12:28:30] WARNING: not removing hydrogen atom without neighbors
# [12:28:30] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:28:44,072 - logger - INFO - Scaler fit...
# 2022-10-20 12:28:44,329 - logger - INFO - Scaler transform...
# 2022-10-20 12:28:44,601 - logger - INFO - Scaler fit...
# 2022-10-20 12:28:49,606 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:28:49,607 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████| 4113/4113 [00:11<00:00, 364.89it/s]
# 2022-10-20 12:29:08,558 - logger - INFO - Scaler transform...
# 2022-10-20 12:29:08,606 - logger - INFO - PCA transform...
# 2022-10-20 12:29:16,965 - logger - INFO - Precision on hold-out: 0.900000
# 2022-10-20 12:29:16,966 - logger - INFO - Recall on hold-out: 0.194245
# 2022-10-20 12:29:16,967 - logger - INFO - Accuracy on hold-out: 0.972040
# 2022-10-20 12:29:16,967 - logger - INFO - F1-score on hold-out: 0.319527
# 2022-10-20 12:29:16,968 - logger - INFO - ROC-AUC on hold-out: 0.596745
# 2022-10-20 12:29:16,968 - logger - INFO - Average precision on hold-out: 0.202051
# 2022-10-20 12:29:16,969 - logger - INFO - MCC on hold-out: 0.410893
# 2022-10-20 12:29:17,108 - logger - INFO - Performance on training set
# 2022-10-20 12:29:17,109 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:29:17,110 - logger - INFO - CreateFPS transform...
# [12:29:21] WARNING: not removing hydrogen atom without neighbors
# [12:29:21] WARNING: not removing hydrogen atom without neighbors
# [12:30:54] WARNING: not removing hydrogen atom without neighbors
# [12:30:54] WARNING: not removing hydrogen atom without neighbors
# [12:30:54] WARNING: not removing hydrogen atom without neighbors
# [12:30:54] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████| 37014/37014 [01:42<00:00, 361.54it/s]
# [12:31:57] WARNING: not removing hydrogen atom without neighbors
# [12:31:57] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:32:10,776 - logger - INFO - Scaler fit...
# 2022-10-20 12:32:11,032 - logger - INFO - Scaler transform...
# 2022-10-20 12:32:11,401 - logger - INFO - Scaler fit...
# 2022-10-20 12:32:16,476 - logger - INFO - CreateFPS fit...
# 2022-10-20 12:32:16,478 - logger - INFO - CreateFPS transform...
# [12:32:20] WARNING: not removing hydrogen atom without neighbors
# [12:32:20] WARNING: not removing hydrogen atom without neighbors
# [12:33:54] WARNING: not removing hydrogen atom without neighbors
# [12:33:54] WARNING: not removing hydrogen atom without neighbors
# [12:33:54] WARNING: not removing hydrogen atom without neighbors
# [12:33:54] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████| 37014/37014 [01:43<00:00, 358.37it/s]
# [12:34:56] WARNING: not removing hydrogen atom without neighbors
# [12:34:56] WARNING: not removing hydrogen atom without neighbors
# 2022-10-20 12:35:10,496 - logger - INFO - Scaler transform...
# 2022-10-20 12:35:11,114 - logger - INFO - PCA transform...
# 2022-10-20 12:36:22,868 - logger - INFO - Precision on training: 0.883392
# 2022-10-20 12:36:22,871 - logger - INFO - Recall on training: 0.191718
# 2022-10-20 12:36:22,872 - logger - INFO - Accuracy on training: 0.970633
# 2022-10-20 12:36:22,873 - logger - INFO - F1-score on training: 0.315060
# 2022-10-20 12:36:22,874 - logger - INFO - ROC-AUC on training: 0.595397
# 2022-10-20 12:36:22,875 - logger - INFO - Average precision on training: 0.197838
# 2022-10-20 12:36:22,876 - logger - INFO - MCC on training 0.403820

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)
