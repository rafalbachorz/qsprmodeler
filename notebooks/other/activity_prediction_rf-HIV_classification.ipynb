# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "rf"
RESULT_FILE_REGRESSOR = "result_regressor_rf.csv"
RESULT_FILE_CLASSIFIER = "result_classifier_rf_HIV.csv"
# Out:
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-10-07 12:48:05.197948: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-10-07 12:48:07,020 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:48:07,040 - logger - INFO - Training configuration:
# 2022-10-07 12:48:07,041 - logger - INFO - Prediction methodology: M_RandomForest
# 2022-10-07 12:48:07,041 - logger - INFO - Prediction type: classification
# 2022-10-07 12:48:07,042 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:48:07,042 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:48:07,043 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:48:07,044 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:48:07,044 - logger - INFO - Model storage: model_rf_classifier_QED_mean_no_limit_HIV.model
# 2022-10-07 12:48:07,046 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:48:07,047 - logger - INFO - FPs?: no
# 2022-10-07 12:48:07,047 - logger - INFO - MDs?: yes
# 2022-10-07 12:48:07,048 - logger - INFO - Scaling?: no
# 2022-10-07 12:48:07,049 - logger - INFO - PCA?: no
# 2022-10-07 12:48:07,049 - logger - INFO - Target transform?: no
# 2022-10-07 12:48:07,050 - logger - INFO - Target binarization?: no
# 2022-10-07 12:48:07,121 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'log_loss', 'max_depth': 20, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 90, 'n_jobs': 8, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 2022-10-07 12:48:07,123 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:48:07,123 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:48:07,124 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:48:07,125 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 330.57it/s]
# 2022-10-07 12:48:26,438 - logger - INFO - Precision on hold-out: 0.724138
# 2022-10-07 12:48:26,440 - logger - INFO - Recall on hold-out: 0.151079
# 2022-10-07 12:48:26,441 - logger - INFO - Accuracy on hold-out: 0.969365
# 2022-10-07 12:48:26,441 - logger - INFO - F1-score on hold-out: 0.250000
# 2022-10-07 12:48:26,442 - logger - INFO - ROC-AUC on hold-out: 0.574533
# 2022-10-07 12:48:26,443 - logger - INFO - Average precision on hold-out: 0.138092
# 2022-10-07 12:48:26,443 - logger - INFO - MCC on hold-out: 0.321928
# 2022-10-07 12:48:26,624 - logger - INFO - Performance on training set
# 2022-10-07 12:48:26,626 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:48:26,626 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:48:26,627 - logger - INFO - CreateFPS transform...
# [12:48:31] WARNING: not removing hydrogen atom without neighbors
# [12:48:31] WARNING: not removing hydrogen atom without neighbors
# [12:49:56] WARNING: not removing hydrogen atom without neighbors
# [12:49:56] WARNING: not removing hydrogen atom without neighbors
# [12:49:56] WARNING: not removing hydrogen atom without neighbors
# [12:49:56] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:55<00:00, 321.14it/s]
# [12:51:05] WARNING: not removing hydrogen atom without neighbors
# [12:51:05] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:51:20,742 - logger - INFO - Precision on training: 0.989157
# 2022-10-07 12:51:20,743 - logger - INFO - Recall on training: 0.629601
# 2022-10-07 12:51:20,743 - logger - INFO - Accuracy on training: 0.986708
# 2022-10-07 12:51:20,744 - logger - INFO - F1-score on training: 0.769447
# 2022-10-07 12:51:20,745 - logger - INFO - ROC-AUC on training: 0.814675
# 2022-10-07 12:51:20,745 - logger - INFO - Average precision on training: 0.635823
# 2022-10-07 12:51:20,746 - logger - INFO - MCC on training 0.783661

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limit

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:51:21,566 - logger - INFO - Training configuration:
# 2022-10-07 12:51:21,567 - logger - INFO - Prediction methodology: M_RandomForest
# 2022-10-07 12:51:21,567 - logger - INFO - Prediction type: classification
# 2022-10-07 12:51:21,568 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:51:21,569 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:51:21,569 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:51:21,570 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:51:21,570 - logger - INFO - Model storage: model_rf_classifier_Morgan_1024_mean_no_limit_HIV.model
# 2022-10-07 12:51:21,571 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:51:21,571 - logger - INFO - FPs?: yes
# 2022-10-07 12:51:21,572 - logger - INFO - FP size?: 1024
# 2022-10-07 12:51:21,572 - logger - INFO - MDs?: no
# 2022-10-07 12:51:21,573 - logger - INFO - Scaling?: no
# 2022-10-07 12:51:21,574 - logger - INFO - PCA?: no
# 2022-10-07 12:51:21,574 - logger - INFO - Target transform?: no
# 2022-10-07 12:51:21,575 - logger - INFO - Target binarization?: no
# 2022-10-07 12:51:22,246 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'entropy', 'max_depth': 24, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 90, 'n_jobs': 8, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 2022-10-07 12:51:22,247 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:51:22,248 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:51:22,248 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:51:22,249 - logger - INFO - CreateFPS transform...
# 2022-10-07 12:51:25,486 - logger - INFO - Precision on hold-out: 0.785714
# 2022-10-07 12:51:25,487 - logger - INFO - Recall on hold-out: 0.316547
# 2022-10-07 12:51:25,487 - logger - INFO - Accuracy on hold-out: 0.973985
# 2022-10-07 12:51:25,488 - logger - INFO - F1-score on hold-out: 0.451282
# 2022-10-07 12:51:25,488 - logger - INFO - ROC-AUC on hold-out: 0.656764
# 2022-10-07 12:51:25,489 - logger - INFO - Average precision on hold-out: 0.271813
# 2022-10-07 12:51:25,490 - logger - INFO - MCC on hold-out: 0.488877
# 2022-10-07 12:51:25,669 - logger - INFO - Performance on training set
# 2022-10-07 12:51:25,670 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:51:25,671 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:51:25,671 - logger - INFO - CreateFPS transform...
# [12:51:30] WARNING: not removing hydrogen atom without neighbors
# [12:51:30] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:51:52,269 - logger - INFO - Precision on training: 0.992754
# 2022-10-07 12:51:52,271 - logger - INFO - Recall on training: 0.525307
# 2022-10-07 12:51:52,271 - logger - INFO - Accuracy on training: 0.983142
# 2022-10-07 12:51:52,272 - logger - INFO - F1-score on training: 0.687061
# 2022-10-07 12:51:52,272 - logger - INFO - ROC-AUC on training: 0.762583
# 2022-10-07 12:51:52,273 - logger - INFO - Average precision on training: 0.538224
# 2022-10-07 12:51:52,274 - logger - INFO - MCC on training 0.715829

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:51:53,094 - logger - INFO - Training configuration:
# 2022-10-07 12:51:53,095 - logger - INFO - Prediction methodology: M_RandomForest
# 2022-10-07 12:51:53,095 - logger - INFO - Prediction type: classification
# 2022-10-07 12:51:53,096 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:51:53,096 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:51:53,097 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:51:53,097 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:51:53,097 - logger - INFO - Model storage: model_rf_classifier_Morgan_1024_pca_128_QED_mean_no_limit_HIV.model
# 2022-10-07 12:51:53,098 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:51:53,098 - logger - INFO - FPs?: yes
# 2022-10-07 12:51:53,098 - logger - INFO - FP size?: 1024
# 2022-10-07 12:51:53,099 - logger - INFO - MDs?: yes
# 2022-10-07 12:51:53,100 - logger - INFO - Scaling?: no
# 2022-10-07 12:51:53,100 - logger - INFO - PCA?: yes
# 2022-10-07 12:51:53,101 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 12:51:53,101 - logger - INFO - PCA - number of components: 128
# 2022-10-07 12:51:53,102 - logger - INFO - Target transform?: no
# 2022-10-07 12:51:53,102 - logger - INFO - Target binarization?: no
# 2022-10-07 12:51:53,805 - logger - INFO - PCA constructor...
# 2022-10-07 12:51:53,806 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'gini', 'max_depth': 26, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 176, 'n_jobs': 8, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 2022-10-07 12:51:53,807 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:51:53,808 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:51:53,809 - logger - INFO - CreateFPS transform...
# [12:51:58] WARNING: not removing hydrogen atom without neighbors
# [12:51:58] WARNING: not removing hydrogen atom without neighbors
# [12:53:40] WARNING: not removing hydrogen atom without neighbors
# [12:53:40] WARNING: not removing hydrogen atom without neighbors
# [12:53:40] WARNING: not removing hydrogen atom without neighbors
# [12:53:40] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:51<00:00, 331.28it/s]
# [12:54:48] WARNING: not removing hydrogen atom without neighbors
# [12:54:48] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:55:03,436 - logger - INFO - Scaler fit...
# 2022-10-07 12:55:09,319 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:55:09,320 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 330.64it/s]
# 2022-10-07 12:55:30,143 - logger - INFO - PCA transform...
# 2022-10-07 12:55:30,625 - logger - INFO - Precision on hold-out: 0.838710
# 2022-10-07 12:55:30,627 - logger - INFO - Recall on hold-out: 0.187050
# 2022-10-07 12:55:30,628 - logger - INFO - Accuracy on hold-out: 0.971310
# 2022-10-07 12:55:30,629 - logger - INFO - F1-score on hold-out: 0.305882
# 2022-10-07 12:55:30,630 - logger - INFO - ROC-AUC on hold-out: 0.592896
# 2022-10-07 12:55:30,631 - logger - INFO - Average precision on hold-out: 0.184355
# 2022-10-07 12:55:30,632 - logger - INFO - MCC on hold-out: 0.388178
# 2022-10-07 12:55:30,813 - logger - INFO - Performance on training set
# 2022-10-07 12:55:30,814 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:55:30,815 - logger - INFO - CreateFPS transform...
# [12:55:35] WARNING: not removing hydrogen atom without neighbors
# [12:55:35] WARNING: not removing hydrogen atom without neighbors
# [12:57:24] WARNING: not removing hydrogen atom without neighbors
# [12:57:24] WARNING: not removing hydrogen atom without neighbors
# [12:57:24] WARNING: not removing hydrogen atom without neighbors
# [12:57:24] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:00<00:00, 308.23it/s]
# [12:58:35] WARNING: not removing hydrogen atom without neighbors
# [12:58:35] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:58:51,328 - logger - INFO - Scaler fit...
# 2022-10-07 12:58:58,235 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:58:58,238 - logger - INFO - CreateFPS transform...
# [12:59:03] WARNING: not removing hydrogen atom without neighbors
# [12:59:03] WARNING: not removing hydrogen atom without neighbors
# [13:00:55] WARNING: not removing hydrogen atom without neighbors
# [13:00:55] WARNING: not removing hydrogen atom without neighbors
# [13:00:55] WARNING: not removing hydrogen atom without neighbors
# [13:00:55] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:01<00:00, 304.97it/s]
# [13:02:06] WARNING: not removing hydrogen atom without neighbors
# [13:02:06] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:02:22,320 - logger - INFO - PCA transform...
# 2022-10-07 13:02:23,954 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:02:23,955 - logger - INFO - Recall on training: 0.496166
# 2022-10-07 13:02:23,956 - logger - INFO - Accuracy on training: 0.982250
# 2022-10-07 13:02:23,957 - logger - INFO - F1-score on training: 0.663250
# 2022-10-07 13:02:23,958 - logger - INFO - ROC-AUC on training: 0.748083
# 2022-10-07 13:02:23,959 - logger - INFO - Average precision on training: 0.513916
# 2022-10-07 13:02:23,960 - logger - INFO - MCC on training 0.697999

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:02:24,868 - logger - INFO - Training configuration:
# 2022-10-07 13:02:24,868 - logger - INFO - Prediction methodology: M_RandomForest
# 2022-10-07 13:02:24,869 - logger - INFO - Prediction type: classification
# 2022-10-07 13:02:24,869 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:02:24,870 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:02:24,871 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:02:24,871 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:02:24,872 - logger - INFO - Model storage: model_rf_classifier_Morgan_1024_pca_256_QED_mean_no_limit_HIV.model
# 2022-10-07 13:02:24,872 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:02:24,874 - logger - INFO - FPs?: yes
# 2022-10-07 13:02:24,874 - logger - INFO - FP size?: 1024
# 2022-10-07 13:02:24,875 - logger - INFO - MDs?: yes
# 2022-10-07 13:02:24,875 - logger - INFO - Scaling?: no
# 2022-10-07 13:02:24,875 - logger - INFO - PCA?: yes
# 2022-10-07 13:02:24,876 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:02:24,876 - logger - INFO - PCA - number of components: 256
# 2022-10-07 13:02:24,877 - logger - INFO - Target transform?: no
# 2022-10-07 13:02:24,877 - logger - INFO - Target binarization?: no
# 2022-10-07 13:02:25,529 - logger - INFO - PCA constructor...
# 2022-10-07 13:02:25,531 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'gini', 'max_depth': 28, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 118, 'n_jobs': 8, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 2022-10-07 13:02:25,532 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:02:25,533 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:02:25,534 - logger - INFO - CreateFPS transform...
# [13:02:30] WARNING: not removing hydrogen atom without neighbors
# [13:02:30] WARNING: not removing hydrogen atom without neighbors
# [13:04:21] WARNING: not removing hydrogen atom without neighbors
# [13:04:21] WARNING: not removing hydrogen atom without neighbors
# [13:04:21] WARNING: not removing hydrogen atom without neighbors
# [13:04:21] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:07<00:00, 290.51it/s]
# [13:05:39] WARNING: not removing hydrogen atom without neighbors
# [13:05:39] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:05:55,481 - logger - INFO - Scaler fit...
# 2022-10-07 13:06:07,812 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:06:07,815 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 322.32it/s]
# 2022-10-07 13:06:29,277 - logger - INFO - PCA transform...
# 2022-10-07 13:06:29,785 - logger - INFO - Precision on hold-out: 0.793103
# 2022-10-07 13:06:29,786 - logger - INFO - Recall on hold-out: 0.165468
# 2022-10-07 13:06:29,787 - logger - INFO - Accuracy on hold-out: 0.970338
# 2022-10-07 13:06:29,788 - logger - INFO - F1-score on hold-out: 0.273810
# 2022-10-07 13:06:29,788 - logger - INFO - ROC-AUC on hold-out: 0.581979
# 2022-10-07 13:06:29,789 - logger - INFO - Average precision on hold-out: 0.159436
# 2022-10-07 13:06:29,789 - logger - INFO - MCC on hold-out: 0.354088
# 2022-10-07 13:06:30,161 - logger - INFO - Performance on training set
# 2022-10-07 13:06:30,163 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:06:30,163 - logger - INFO - CreateFPS transform...
# [13:06:35] WARNING: not removing hydrogen atom without neighbors
# [13:06:35] WARNING: not removing hydrogen atom without neighbors
# [13:08:42] WARNING: not removing hydrogen atom without neighbors
# [13:08:42] WARNING: not removing hydrogen atom without neighbors
# [13:08:42] WARNING: not removing hydrogen atom without neighbors
# [13:08:42] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:21<00:00, 261.27it/s]
# [13:09:57] WARNING: not removing hydrogen atom without neighbors
# [13:09:57] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:10:13,783 - logger - INFO - Scaler fit...
# 2022-10-07 13:10:26,356 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:10:26,359 - logger - INFO - CreateFPS transform...
# [13:10:31] WARNING: not removing hydrogen atom without neighbors
# [13:10:31] WARNING: not removing hydrogen atom without neighbors
# [13:12:22] WARNING: not removing hydrogen atom without neighbors
# [13:12:22] WARNING: not removing hydrogen atom without neighbors
# [13:12:22] WARNING: not removing hydrogen atom without neighbors
# [13:12:22] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:02<00:00, 302.16it/s]
# [13:13:34] WARNING: not removing hydrogen atom without neighbors
# [13:13:34] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:13:50,160 - logger - INFO - PCA transform...
# 2022-10-07 13:13:52,049 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:13:52,050 - logger - INFO - Recall on training: 0.446319
# 2022-10-07 13:13:52,051 - logger - INFO - Accuracy on training: 0.980494
# 2022-10-07 13:13:52,052 - logger - INFO - F1-score on training: 0.617179
# 2022-10-07 13:13:52,053 - logger - INFO - ROC-AUC on training: 0.723160
# 2022-10-07 13:13:52,054 - logger - INFO - Average precision on training: 0.465825
# 2022-10-07 13:13:52,055 - logger - INFO - MCC on training 0.661418

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:16:23,005 - logger - INFO - Training configuration:
# 2022-10-07 13:16:23,007 - logger - INFO - Prediction methodology: M_RandomForest
# 2022-10-07 13:16:23,008 - logger - INFO - Prediction type: classification
# 2022-10-07 13:16:23,009 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:16:23,009 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:16:23,010 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:16:23,011 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:16:23,012 - logger - INFO - Model storage: model_rf_classifier_Morgan_1024_pca_512_QED_mean_no_limit_HIV.model
# 2022-10-07 13:16:23,012 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:16:23,013 - logger - INFO - FPs?: yes
# 2022-10-07 13:16:23,014 - logger - INFO - FP size?: 1024
# 2022-10-07 13:16:23,014 - logger - INFO - MDs?: yes
# 2022-10-07 13:16:23,015 - logger - INFO - Scaling?: no
# 2022-10-07 13:16:23,016 - logger - INFO - PCA?: yes
# 2022-10-07 13:16:23,016 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:16:23,017 - logger - INFO - PCA - number of components: 512
# 2022-10-07 13:16:23,018 - logger - INFO - Target transform?: no
# 2022-10-07 13:16:23,018 - logger - INFO - Target binarization?: no
# 2022-10-07 13:16:23,733 - logger - INFO - PCA constructor...
# 2022-10-07 13:16:23,734 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'gini', 'max_depth': 22, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 134, 'n_jobs': 8, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 2022-10-07 13:16:23,735 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:16:23,735 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:16:23,736 - logger - INFO - CreateFPS transform...
# [13:16:28] WARNING: not removing hydrogen atom without neighbors
# [13:16:28] WARNING: not removing hydrogen atom without neighbors
# [13:18:18] WARNING: not removing hydrogen atom without neighbors
# [13:18:18] WARNING: not removing hydrogen atom without neighbors
# [13:18:18] WARNING: not removing hydrogen atom without neighbors
# [13:18:18] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:13<00:00, 278.11it/s]
# [13:19:41] WARNING: not removing hydrogen atom without neighbors
# [13:19:41] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:19:59,573 - logger - INFO - Scaler fit...
# 2022-10-07 13:20:32,082 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:20:32,084 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:15<00:00, 258.47it/s]
# 2022-10-07 13:20:59,176 - logger - INFO - PCA transform...
# 2022-10-07 13:20:59,691 - logger - INFO - Precision on hold-out: 0.807692
# 2022-10-07 13:20:59,693 - logger - INFO - Recall on hold-out: 0.151079
# 2022-10-07 13:20:59,694 - logger - INFO - Accuracy on hold-out: 0.970095
# 2022-10-07 13:20:59,695 - logger - INFO - F1-score on hold-out: 0.254545
# 2022-10-07 13:20:59,696 - logger - INFO - ROC-AUC on hold-out: 0.574910
# 2022-10-07 13:20:59,697 - logger - INFO - Average precision on hold-out: 0.150715
# 2022-10-07 13:20:59,698 - logger - INFO - MCC on hold-out: 0.341590
# 2022-10-07 13:20:59,881 - logger - INFO - Performance on training set
# 2022-10-07 13:20:59,883 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:20:59,884 - logger - INFO - CreateFPS transform...
# [13:21:04] WARNING: not removing hydrogen atom without neighbors
# [13:21:04] WARNING: not removing hydrogen atom without neighbors
# [13:22:46] WARNING: not removing hydrogen atom without neighbors
# [13:22:46] WARNING: not removing hydrogen atom without neighbors
# [13:22:46] WARNING: not removing hydrogen atom without neighbors
# [13:22:46] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:04<00:00, 296.62it/s]
# [13:24:07] WARNING: not removing hydrogen atom without neighbors
# [13:24:07] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:24:21,877 - logger - INFO - Scaler fit...
# 2022-10-07 13:24:48,167 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:24:48,168 - logger - INFO - CreateFPS transform...
# [13:24:52] WARNING: not removing hydrogen atom without neighbors
# [13:24:52] WARNING: not removing hydrogen atom without neighbors
# [13:26:37] WARNING: not removing hydrogen atom without neighbors
# [13:26:37] WARNING: not removing hydrogen atom without neighbors
# [13:26:37] WARNING: not removing hydrogen atom without neighbors
# [13:26:37] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [01:54<00:00, 324.43it/s]
# [13:27:59] WARNING: not removing hydrogen atom without neighbors
# [13:27:59] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:28:14,666 - logger - INFO - PCA transform...
# 2022-10-07 13:28:16,746 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:28:16,747 - logger - INFO - Recall on training: 0.340491
# 2022-10-07 13:28:16,748 - logger - INFO - Accuracy on training: 0.976766
# 2022-10-07 13:28:16,748 - logger - INFO - F1-score on training: 0.508009
# 2022-10-07 13:28:16,749 - logger - INFO - ROC-AUC on training: 0.670245
# 2022-10-07 13:28:16,749 - logger - INFO - Average precision on training: 0.363725
# 2022-10-07 13:28:16,749 - logger - INFO - MCC on training 0.576614

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:28:17,547 - logger - INFO - Training configuration:
# 2022-10-07 13:28:17,548 - logger - INFO - Prediction methodology: M_RandomForest
# 2022-10-07 13:28:17,549 - logger - INFO - Prediction type: classification
# 2022-10-07 13:28:17,549 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:28:17,550 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:28:17,550 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:28:17,551 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:28:17,552 - logger - INFO - Model storage: model_rf_classifier_Morgan_1024_pca_1024_QED_mean_no_limit_HIV.model
# 2022-10-07 13:28:17,552 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:28:17,553 - logger - INFO - FPs?: yes
# 2022-10-07 13:28:17,553 - logger - INFO - FP size?: 1024
# 2022-10-07 13:28:17,554 - logger - INFO - MDs?: yes
# 2022-10-07 13:28:17,554 - logger - INFO - Scaling?: no
# 2022-10-07 13:28:17,555 - logger - INFO - PCA?: yes
# 2022-10-07 13:28:17,555 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:28:17,556 - logger - INFO - PCA - number of components: 1024
# 2022-10-07 13:28:17,556 - logger - INFO - Target transform?: no
# 2022-10-07 13:28:17,556 - logger - INFO - Target binarization?: no
# 2022-10-07 13:28:18,203 - logger - INFO - PCA constructor...
# 2022-10-07 13:28:18,205 - logger - INFO - Optimal hyperparameters:, {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'gini', 'max_depth': 20, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 108, 'n_jobs': 8, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 2022-10-07 13:28:18,206 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:28:18,208 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:28:18,210 - logger - INFO - CreateFPS transform...
# [13:28:23] WARNING: not removing hydrogen atom without neighbors
# [13:28:23] WARNING: not removing hydrogen atom without neighbors
# [13:30:27] WARNING: not removing hydrogen atom without neighbors
# [13:30:27] WARNING: not removing hydrogen atom without neighbors
# [13:30:27] WARNING: not removing hydrogen atom without neighbors
# [13:30:27] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:07<00:00, 290.43it/s]
# [13:31:43] WARNING: not removing hydrogen atom without neighbors
# [13:31:43] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:31:58,940 - logger - INFO - Scaler fit...
# 2022-10-07 13:32:09,836 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:32:09,838 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:22<00:00, 181.00it/s]
# 2022-10-07 13:32:45,156 - logger - INFO - PCA transform...
# 2022-10-07 13:32:45,678 - logger - INFO - Precision on hold-out: 0.888889
# 2022-10-07 13:32:45,679 - logger - INFO - Recall on hold-out: 0.115108
# 2022-10-07 13:32:45,680 - logger - INFO - Accuracy on hold-out: 0.969609
# 2022-10-07 13:32:45,681 - logger - INFO - F1-score on hold-out: 0.203822
# 2022-10-07 13:32:45,682 - logger - INFO - ROC-AUC on hold-out: 0.557302
# 2022-10-07 13:32:45,683 - logger - INFO - Average precision on hold-out: 0.132223
# 2022-10-07 13:32:45,684 - logger - INFO - MCC on hold-out: 0.313733
# 2022-10-07 13:32:45,840 - logger - INFO - Performance on training set
# 2022-10-07 13:32:45,841 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:32:45,842 - logger - INFO - CreateFPS transform...
# [13:32:50] WARNING: not removing hydrogen atom without neighbors
# [13:32:50] WARNING: not removing hydrogen atom without neighbors
# [13:34:51] WARNING: not removing hydrogen atom without neighbors
# [13:34:51] WARNING: not removing hydrogen atom without neighbors
# [13:34:51] WARNING: not removing hydrogen atom without neighbors
# [13:34:51] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:00<00:00, 306.44it/s]
# [13:36:04] WARNING: not removing hydrogen atom without neighbors
# [13:36:04] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:36:19,860 - logger - INFO - Scaler fit...
# 2022-10-07 13:36:32,088 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:36:32,090 - logger - INFO - CreateFPS transform...
# [13:36:36] WARNING: not removing hydrogen atom without neighbors
# [13:36:36] WARNING: not removing hydrogen atom without neighbors
# [13:38:27] WARNING: not removing hydrogen atom without neighbors
# [13:38:27] WARNING: not removing hydrogen atom without neighbors
# [13:38:27] WARNING: not removing hydrogen atom without neighbors
# [13:38:27] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:01<00:00, 304.24it/s]
# [13:39:38] WARNING: not removing hydrogen atom without neighbors
# [13:39:38] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:39:53,004 - logger - INFO - PCA transform...
# 2022-10-07 13:39:55,946 - logger - INFO - Precision on training: 1.000000
# 2022-10-07 13:39:55,947 - logger - INFO - Recall on training: 0.283742
# 2022-10-07 13:39:55,948 - logger - INFO - Accuracy on training: 0.974766
# 2022-10-07 13:39:55,949 - logger - INFO - F1-score on training: 0.442055
# 2022-10-07 13:39:55,950 - logger - INFO - ROC-AUC on training: 0.641871
# 2022-10-07 13:39:55,953 - logger - INFO - Average precision on training: 0.308976
# 2022-10-07 13:39:55,954 - logger - INFO - MCC on training 0.525842

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)
