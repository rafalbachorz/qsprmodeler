# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "mlp"
RESULT_FILE_REGRESSOR = "result_regressor_mlp.csv"
RESULT_FILE_CLASSIFIER = "result_classifier_mlp_HIV.csv"
# Out:
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-10-07 12:44:01.921510: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-10-07 12:44:03,643 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:44:03,664 - logger - INFO - Training configuration:
# 2022-10-07 12:44:03,665 - logger - INFO - Prediction methodology: M_MLP
# 2022-10-07 12:44:03,665 - logger - INFO - Prediction type: classification
# 2022-10-07 12:44:03,666 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:44:03,667 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:44:03,667 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:44:03,668 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:44:03,669 - logger - INFO - Model storage: model_mlp_clasifier_QED_mean_no_limit_HIV.model
# 2022-10-07 12:44:03,669 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:44:03,670 - logger - INFO - FPs?: no
# 2022-10-07 12:44:03,670 - logger - INFO - MDs?: yes
# 2022-10-07 12:44:03,671 - logger - INFO - Scaling?: yes
# 2022-10-07 12:44:03,671 - logger - INFO - PCA?: no
# 2022-10-07 12:44:03,672 - logger - INFO - Target transform?: no
# 2022-10-07 12:44:03,672 - logger - INFO - Target binarization?: no
# 2022-10-07 12:44:03,706 - logger - INFO - Scaler constructor...
# 2022-10-07 12:44:03.826420: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-07 12:44:06.791304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9645 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:18:00.0, compute capability: 7.5
# 2022-10-07 12:44:06.792787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9645 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3b:00.0, compute capability: 7.5
# 2022-10-07 12:44:06.793524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9645 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:86:00.0, compute capability: 7.5
# 2022-10-07 12:44:06.794262: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9645 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:af:00.0, compute capability: 7.5
# 2022-10-07 12:44:07,130 - logger - INFO - Optimal hyperparameters:, {'mlp_architecture': (64, 32, 32), 'activation': 'elu', 'batch_size': 32, 'initial_lr': 0.013985658161325416, 'regularization_weight': 0.01573649269279523, 'optimizer': 'Adam', 'min_lr': 0.0007003390925286271, 'dropout_rate': 0.383523716331076}
# 2022-10-07 12:44:07,131 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:44:07,133 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:44:07,135 - logger - INFO - CreateFPS transform...
# [12:44:11] WARNING: not removing hydrogen atom without neighbors
# [12:44:11] WARNING: not removing hydrogen atom without neighbors
# [12:45:33] WARNING: not removing hydrogen atom without neighbors
# [12:45:33] WARNING: not removing hydrogen atom without neighbors
# [12:45:33] WARNING: not removing hydrogen atom without neighbors
# [12:45:33] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:49<00:00, 336.78it/s]
# [12:46:37] WARNING: not removing hydrogen atom without neighbors
# [12:46:37] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:46:51,184 - logger - INFO - Scaler fit...
# 2022-10-07 12:46:51,194 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:46:51,195 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 342.73it/s]
# 2022-10-07 12:47:09,156 - logger - INFO - Scaler transform...
# 129/129 [==============================] - 1s 1ms/step
# 2022-10-07 12:47:10,896 - logger - INFO - Precision on hold-out: 0.000000
# 2022-10-07 12:47:10,898 - logger - INFO - Recall on hold-out: 0.000000
# 2022-10-07 12:47:10,899 - logger - INFO - Accuracy on hold-out: 0.965718
# 2022-10-07 12:47:10,900 - logger - INFO - F1-score on hold-out: 0.000000
# 2022-10-07 12:47:10,901 - logger - INFO - ROC-AUC on hold-out: 0.499748
# 2022-10-07 12:47:10,902 - logger - INFO - Average precision on hold-out: 0.033795
# 2022-10-07 12:47:10,903 - logger - INFO - MCC on hold-out: -0.004125
# 2022-10-07 12:47:11,065 - logger - INFO - Performance on training set
# 2022-10-07 12:47:11,066 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:47:11,067 - logger - INFO - CreateFPS transform...
# [12:47:15] WARNING: not removing hydrogen atom without neighbors
# [12:47:15] WARNING: not removing hydrogen atom without neighbors
# [12:48:36] WARNING: not removing hydrogen atom without neighbors
# [12:48:36] WARNING: not removing hydrogen atom without neighbors
# [12:48:36] WARNING: not removing hydrogen atom without neighbors
# [12:48:36] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:50<00:00, 335.28it/s]
# [12:49:44] WARNING: not removing hydrogen atom without neighbors
# [12:49:44] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:49:59,047 - logger - INFO - Scaler fit...
# 2022-10-07 12:49:59,059 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:49:59,060 - logger - INFO - CreateFPS transform...
# [12:50:03] WARNING: not removing hydrogen atom without neighbors
# [12:50:03] WARNING: not removing hydrogen atom without neighbors
# [12:51:27] WARNING: not removing hydrogen atom without neighbors
# [12:51:27] WARNING: not removing hydrogen atom without neighbors
# [12:51:27] WARNING: not removing hydrogen atom without neighbors
# [12:51:27] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:51<00:00, 331.37it/s]
# [12:52:33] WARNING: not removing hydrogen atom without neighbors
# [12:52:33] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:52:47,475 - logger - INFO - Scaler transform...
# 1157/1157 [==============================] - 2s 1ms/step
# 2022-10-07 12:52:49,600 - logger - INFO - Precision on training: 0.190476
# 2022-10-07 12:52:49,601 - logger - INFO - Recall on training: 0.003067
# 2022-10-07 12:52:49,602 - logger - INFO - Accuracy on training: 0.964419
# 2022-10-07 12:52:49,603 - logger - INFO - F1-score on training: 0.006038
# 2022-10-07 12:52:49,604 - logger - INFO - ROC-AUC on training: 0.501296
# 2022-10-07 12:52:49,605 - logger - INFO - Average precision on training: 0.035706
# 2022-10-07 12:52:49,606 - logger - INFO - MCC on training 0.020063

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limit

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:52:50,441 - logger - INFO - Training configuration:
# 2022-10-07 12:52:50,442 - logger - INFO - Prediction methodology: M_MLP
# 2022-10-07 12:52:50,443 - logger - INFO - Prediction type: classification
# 2022-10-07 12:52:50,443 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:52:50,444 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:52:50,445 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:52:50,445 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:52:50,446 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_128_QED_mean_no_limit_HIV.model
# 2022-10-07 12:52:50,446 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:52:50,447 - logger - INFO - FPs?: yes
# 2022-10-07 12:52:50,447 - logger - INFO - FP size?: 1024
# 2022-10-07 12:52:50,448 - logger - INFO - MDs?: yes
# 2022-10-07 12:52:50,448 - logger - INFO - Scaling?: yes
# 2022-10-07 12:52:50,450 - logger - INFO - PCA?: yes
# 2022-10-07 12:52:50,450 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 12:52:50,451 - logger - INFO - PCA - number of components: 128
# 2022-10-07 12:52:50,451 - logger - INFO - Target transform?: no
# 2022-10-07 12:52:50,452 - logger - INFO - Target binarization?: no
# 2022-10-07 12:52:51,107 - logger - INFO - Scaler constructor...
# 2022-10-07 12:52:51,108 - logger - INFO - PCA constructor...
# 2022-10-07 12:52:51,186 - logger - INFO - Optimal hyperparameters:, {'mlp_architecture': (64, 32), 'activation': 'tanh', 'batch_size': 16, 'initial_lr': 0.01560260401799883, 'regularization_weight': 0.04142136439556537, 'optimizer': 'SGD', 'min_lr': 0.0005129639306883817, 'dropout_rate': 0.1539429208653328}
# 2022-10-07 12:52:51,188 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:52:51,189 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:52:51,190 - logger - INFO - CreateFPS transform...
# [12:52:55] WARNING: not removing hydrogen atom without neighbors
# [12:52:55] WARNING: not removing hydrogen atom without neighbors
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# [12:54:38] WARNING: not removing hydrogen atom without neighbors
# [12:54:38] WARNING: not removing hydrogen atom without neighbors
# [12:54:38] WARNING: not removing hydrogen atom without neighbors
# [12:54:38] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:54<00:00, 322.22it/s]
# [12:55:48] WARNING: not removing hydrogen atom without neighbors
# [12:55:48] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:56:03,957 - logger - INFO - Scaler fit...
# 2022-10-07 12:56:04,224 - logger - INFO - Scaler transform...
# 2022-10-07 12:56:04,509 - logger - INFO - Scaler fit...
# 2022-10-07 12:56:10,756 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:56:10,758 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 320.28it/s]
# 2022-10-07 12:56:31,964 - logger - INFO - Scaler transform...
# 2022-10-07 12:56:32,024 - logger - INFO - PCA transform...
# 129/129 [==============================] - 0s 1ms/step
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-07 12:56:32,747 - logger - INFO - Precision on hold-out: 0.000000
# 2022-10-07 12:56:32,748 - logger - INFO - Recall on hold-out: 0.000000
# 2022-10-07 12:56:32,749 - logger - INFO - Accuracy on hold-out: 0.966205
# 2022-10-07 12:56:32,751 - logger - INFO - F1-score on hold-out: 0.000000
# 2022-10-07 12:56:32,752 - logger - INFO - ROC-AUC on hold-out: 0.500000
# 2022-10-07 12:56:32,753 - logger - INFO - Average precision on hold-out: 0.033795
# 2022-10-07 12:56:32,754 - logger - INFO - MCC on hold-out: 0.000000
# 2022-10-07 12:56:32,907 - logger - INFO - Performance on training set
# 2022-10-07 12:56:32,909 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:56:32,910 - logger - INFO - CreateFPS transform...
# [12:56:37] WARNING: not removing hydrogen atom without neighbors
# [12:56:37] WARNING: not removing hydrogen atom without neighbors
# [12:58:24] WARNING: not removing hydrogen atom without neighbors
# [12:58:24] WARNING: not removing hydrogen atom without neighbors
# [12:58:24] WARNING: not removing hydrogen atom without neighbors
# [12:58:24] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:01<00:00, 305.11it/s]
# [12:59:39] WARNING: not removing hydrogen atom without neighbors
# [12:59:39] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:59:54,411 - logger - INFO - Scaler fit...
# 2022-10-07 12:59:54,682 - logger - INFO - Scaler transform...
# 2022-10-07 12:59:55,008 - logger - INFO - Scaler fit...
# 2022-10-07 13:00:01,755 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:01,757 - logger - INFO - CreateFPS transform...
# [13:00:06] WARNING: not removing hydrogen atom without neighbors
# [13:00:06] WARNING: not removing hydrogen atom without neighbors
# [13:01:54] WARNING: not removing hydrogen atom without neighbors
# [13:01:54] WARNING: not removing hydrogen atom without neighbors
# [13:01:54] WARNING: not removing hydrogen atom without neighbors
# [13:01:54] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:58<00:00, 313.45it/s]
# [13:03:05] WARNING: not removing hydrogen atom without neighbors
# [13:03:05] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:03:21,604 - logger - INFO - Scaler transform...
# 2022-10-07 13:03:22,237 - logger - INFO - PCA transform...
# 1157/1157 [==============================] - 1s 1ms/step
# 2022-10-07 13:03:25,222 - logger - INFO - Precision on training: 0.333333
# 2022-10-07 13:03:25,224 - logger - INFO - Recall on training: 0.000767
# 2022-10-07 13:03:25,225 - logger - INFO - Accuracy on training: 0.964743
# 2022-10-07 13:03:25,226 - logger - INFO - F1-score on training: 0.001530
# 2022-10-07 13:03:25,227 - logger - INFO - ROC-AUC on training: 0.500355
# 2022-10-07 13:03:25,228 - logger - INFO - Average precision on training: 0.035459
# 2022-10-07 13:03:25,229 - logger - INFO - MCC on training 0.014558

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:03:26,150 - logger - INFO - Training configuration:
# 2022-10-07 13:03:26,151 - logger - INFO - Prediction methodology: M_MLP
# 2022-10-07 13:03:26,151 - logger - INFO - Prediction type: classification
# 2022-10-07 13:03:26,152 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:03:26,152 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:03:26,153 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:03:26,154 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:03:26,154 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_256_QED_no_limit_HIV.model
# 2022-10-07 13:03:26,155 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:03:26,155 - logger - INFO - FPs?: yes
# 2022-10-07 13:03:26,156 - logger - INFO - FP size?: 1024
# 2022-10-07 13:03:26,156 - logger - INFO - MDs?: yes
# 2022-10-07 13:03:26,157 - logger - INFO - Scaling?: yes
# 2022-10-07 13:03:26,157 - logger - INFO - PCA?: yes
# 2022-10-07 13:03:26,157 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:03:26,158 - logger - INFO - PCA - number of components: 256
# 2022-10-07 13:03:26,158 - logger - INFO - Target transform?: no
# 2022-10-07 13:03:26,159 - logger - INFO - Target binarization?: no
# 2022-10-07 13:03:26,796 - logger - INFO - Scaler constructor...
# 2022-10-07 13:03:26,797 - logger - INFO - PCA constructor...
# 2022-10-07 13:03:26,919 - logger - INFO - Optimal hyperparameters:, {'mlp_architecture': (64, 32, 32), 'activation': 'elu', 'batch_size': 32, 'initial_lr': 0.013985658161325416, 'regularization_weight': 0.01573649269279523, 'optimizer': 'Adam', 'min_lr': 0.0007003390925286271, 'dropout_rate': 0.383523716331076}
# 2022-10-07 13:03:26,920 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:03:26,921 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:03:26,922 - logger - INFO - CreateFPS transform...
# [13:03:31] WARNING: not removing hydrogen atom without neighbors
# [13:03:31] WARNING: not removing hydrogen atom without neighbors
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.momentum
# [13:05:27] WARNING: not removing hydrogen atom without neighbors
# [13:05:27] WARNING: not removing hydrogen atom without neighbors
# [13:05:27] WARNING: not removing hydrogen atom without neighbors
# [13:05:27] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:10<00:00, 283.20it/s]
# [13:06:46] WARNING: not removing hydrogen atom without neighbors
# [13:06:46] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:07:01,934 - logger - INFO - Scaler fit...
# 2022-10-07 13:07:02,196 - logger - INFO - Scaler transform...
# 2022-10-07 13:07:02,575 - logger - INFO - Scaler fit...
# 2022-10-07 13:07:15,190 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:07:15,196 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:13<00:00, 314.50it/s]
# 2022-10-07 13:07:37,156 - logger - INFO - Scaler transform...
# 2022-10-07 13:07:37,218 - logger - INFO - PCA transform...
# 129/129 [==============================] - 0s 1ms/step
# 2022-10-07 13:07:38,059 - logger - INFO - Precision on hold-out: 1.000000
# 2022-10-07 13:07:38,060 - logger - INFO - Recall on hold-out: 0.014388
# 2022-10-07 13:07:38,060 - logger - INFO - Accuracy on hold-out: 0.966691
# 2022-10-07 13:07:38,061 - logger - INFO - F1-score on hold-out: 0.028369
# 2022-10-07 13:07:38,061 - logger - INFO - ROC-AUC on hold-out: 0.507194
# 2022-10-07 13:07:38,062 - logger - INFO - Average precision on hold-out: 0.047698
# 2022-10-07 13:07:38,063 - logger - INFO - MCC on hold-out: 0.117936
# 2022-10-07 13:07:38,243 - logger - INFO - Performance on training set
# 2022-10-07 13:07:38,244 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:07:38,245 - logger - INFO - CreateFPS transform...
# [13:07:43] WARNING: not removing hydrogen atom without neighbors
# [13:07:43] WARNING: not removing hydrogen atom without neighbors
# [13:09:51] WARNING: not removing hydrogen atom without neighbors
# [13:09:51] WARNING: not removing hydrogen atom without neighbors
# [13:09:51] WARNING: not removing hydrogen atom without neighbors
# [13:09:51] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:24<00:00, 256.56it/s]
# [13:11:09] WARNING: not removing hydrogen atom without neighbors
# [13:11:09] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:11:25,390 - logger - INFO - Scaler fit...
# 2022-10-07 13:11:25,657 - logger - INFO - Scaler transform...
# 2022-10-07 13:11:26,043 - logger - INFO - Scaler fit...
# 2022-10-07 13:11:38,033 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:11:38,035 - logger - INFO - CreateFPS transform...
# [13:11:42] WARNING: not removing hydrogen atom without neighbors
# [13:11:42] WARNING: not removing hydrogen atom without neighbors
# [13:13:30] WARNING: not removing hydrogen atom without neighbors
# [13:13:30] WARNING: not removing hydrogen atom without neighbors
# [13:13:30] WARNING: not removing hydrogen atom without neighbors
# [13:13:30] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:58<00:00, 313.49it/s]
# [13:14:42] WARNING: not removing hydrogen atom without neighbors
# [13:14:42] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:14:56,866 - logger - INFO - Scaler transform...
# 2022-10-07 13:14:57,485 - logger - INFO - PCA transform...
# 1157/1157 [==============================] - 1s 1ms/step
# 2022-10-07 13:15:00,579 - logger - INFO - Precision on training: 0.866667
# 2022-10-07 13:15:00,580 - logger - INFO - Recall on training: 0.009969
# 2022-10-07 13:15:00,582 - logger - INFO - Accuracy on training: 0.965067
# 2022-10-07 13:15:00,583 - logger - INFO - F1-score on training: 0.019712
# 2022-10-07 13:15:00,584 - logger - INFO - ROC-AUC on training: 0.504957
# 2022-10-07 13:15:00,585 - logger - INFO - Average precision on training: 0.043519
# 2022-10-07 13:15:00,587 - logger - INFO - MCC on training 0.090806

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:15:01,397 - logger - INFO - Training configuration:
# 2022-10-07 13:15:01,398 - logger - INFO - Prediction methodology: M_MLP
# 2022-10-07 13:15:01,399 - logger - INFO - Prediction type: classification
# 2022-10-07 13:15:01,400 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:15:01,401 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:15:01,402 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:15:01,403 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:15:01,404 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_512_QED_no_limit_HIV.model
# 2022-10-07 13:15:01,405 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:15:01,406 - logger - INFO - FPs?: yes
# 2022-10-07 13:15:01,406 - logger - INFO - FP size?: 1024
# 2022-10-07 13:15:01,407 - logger - INFO - MDs?: yes
# 2022-10-07 13:15:01,408 - logger - INFO - Scaling?: yes
# 2022-10-07 13:15:01,409 - logger - INFO - PCA?: yes
# 2022-10-07 13:15:01,409 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:15:01,409 - logger - INFO - PCA - number of components: 512
# 2022-10-07 13:15:01,410 - logger - INFO - Target transform?: no
# 2022-10-07 13:15:01,410 - logger - INFO - Target binarization?: no
# 2022-10-07 13:15:02,043 - logger - INFO - Scaler constructor...
# 2022-10-07 13:15:02,044 - logger - INFO - PCA constructor...
# 2022-10-07 13:15:02,142 - logger - INFO - Optimal hyperparameters:, {'mlp_architecture': (128, 64), 'activation': 'relu', 'batch_size': 96, 'initial_lr': 0.01803142069101716, 'regularization_weight': 0.046327818213770224, 'optimizer': 'Adam', 'min_lr': 0.0003856613159005945, 'dropout_rate': 0.22935128258712675}
# 2022-10-07 13:15:02,143 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:15:02,145 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:15:02,146 - logger - INFO - CreateFPS transform...
# [13:15:06] WARNING: not removing hydrogen atom without neighbors
# [13:15:06] WARNING: not removing hydrogen atom without neighbors
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# [13:17:04] WARNING: not removing hydrogen atom without neighbors
# [13:17:04] WARNING: not removing hydrogen atom without neighbors
# [13:17:04] WARNING: not removing hydrogen atom without neighbors
# [13:17:04] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:10<00:00, 284.08it/s]
# [13:18:16] WARNING: not removing hydrogen atom without neighbors
# [13:18:16] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:18:32,712 - logger - INFO - Scaler fit...
# 2022-10-07 13:18:32,974 - logger - INFO - Scaler transform...
# 2022-10-07 13:18:33,350 - logger - INFO - Scaler fit...
# 2022-10-07 13:18:58,381 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:18:58,383 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 330.50it/s]
# 2022-10-07 13:19:19,145 - logger - INFO - Scaler transform...
# 2022-10-07 13:19:19,191 - logger - INFO - PCA transform...
# 129/129 [==============================] - 0s 1ms/step
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-07 13:19:20,102 - logger - INFO - Precision on hold-out: 0.000000
# 2022-10-07 13:19:20,103 - logger - INFO - Recall on hold-out: 0.000000
# 2022-10-07 13:19:20,103 - logger - INFO - Accuracy on hold-out: 0.966205
# 2022-10-07 13:19:20,104 - logger - INFO - F1-score on hold-out: 0.000000
# 2022-10-07 13:19:20,104 - logger - INFO - ROC-AUC on hold-out: 0.500000
# 2022-10-07 13:19:20,105 - logger - INFO - Average precision on hold-out: 0.033795
# 2022-10-07 13:19:20,105 - logger - INFO - MCC on hold-out: 0.000000
# 2022-10-07 13:19:20,281 - logger - INFO - Performance on training set
# 2022-10-07 13:19:20,282 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:19:20,282 - logger - INFO - CreateFPS transform...
# [13:19:24] WARNING: not removing hydrogen atom without neighbors
# [13:19:24] WARNING: not removing hydrogen atom without neighbors
# [13:21:40] WARNING: not removing hydrogen atom without neighbors
# [13:21:40] WARNING: not removing hydrogen atom without neighbors
# [13:21:40] WARNING: not removing hydrogen atom without neighbors
# [13:21:40] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:24<00:00, 255.37it/s]
# [13:22:48] WARNING: not removing hydrogen atom without neighbors
# [13:22:48] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:23:02,892 - logger - INFO - Scaler fit...
# 2022-10-07 13:23:03,151 - logger - INFO - Scaler transform...
# 2022-10-07 13:23:03,530 - logger - INFO - Scaler fit...
# 2022-10-07 13:23:29,213 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:23:29,216 - logger - INFO - CreateFPS transform...
# [13:23:33] WARNING: not removing hydrogen atom without neighbors
# [13:23:33] WARNING: not removing hydrogen atom without neighbors
# [13:25:32] WARNING: not removing hydrogen atom without neighbors
# [13:25:32] WARNING: not removing hydrogen atom without neighbors
# [13:25:32] WARNING: not removing hydrogen atom without neighbors
# [13:25:32] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:10<00:00, 282.86it/s]
# [13:26:41] WARNING: not removing hydrogen atom without neighbors
# [13:26:41] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:26:56,101 - logger - INFO - Scaler transform...
# 2022-10-07 13:26:56,735 - logger - INFO - PCA transform...
# 1157/1157 [==============================] - 2s 1ms/step
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-07 13:27:00,610 - logger - INFO - Precision on training: 0.000000
# 2022-10-07 13:27:00,611 - logger - INFO - Recall on training: 0.000000
# 2022-10-07 13:27:00,612 - logger - INFO - Accuracy on training: 0.964770
# 2022-10-07 13:27:00,612 - logger - INFO - F1-score on training: 0.000000
# 2022-10-07 13:27:00,612 - logger - INFO - ROC-AUC on training: 0.500000
# 2022-10-07 13:27:00,613 - logger - INFO - Average precision on training: 0.035230
# 2022-10-07 13:27:00,613 - logger - INFO - MCC on training 0.000000

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:27:01,366 - logger - INFO - Training configuration:
# 2022-10-07 13:27:01,367 - logger - INFO - Prediction methodology: M_MLP
# 2022-10-07 13:27:01,367 - logger - INFO - Prediction type: classification
# 2022-10-07 13:27:01,368 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:27:01,369 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:27:01,369 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:27:01,370 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:27:01,370 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_1024_QED_mean_no_limit_HIV.model
# 2022-10-07 13:27:01,371 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:27:01,371 - logger - INFO - FPs?: yes
# 2022-10-07 13:27:01,372 - logger - INFO - FP size?: 1024
# 2022-10-07 13:27:01,372 - logger - INFO - MDs?: yes
# 2022-10-07 13:27:01,373 - logger - INFO - Scaling?: yes
# 2022-10-07 13:27:01,373 - logger - INFO - PCA?: yes
# 2022-10-07 13:27:01,374 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:27:01,374 - logger - INFO - PCA - number of components: 1024
# 2022-10-07 13:27:01,375 - logger - INFO - Target transform?: no
# 2022-10-07 13:27:01,375 - logger - INFO - Target binarization?: no
# 2022-10-07 13:27:02,008 - logger - INFO - Scaler constructor...
# 2022-10-07 13:27:02,009 - logger - INFO - PCA constructor...
# 2022-10-07 13:27:02,103 - logger - INFO - Optimal hyperparameters:, {'mlp_architecture': (256, 128), 'activation': 'tanh', 'batch_size': 256, 'initial_lr': 0.018823372468878455, 'regularization_weight': 0.06857435053522586, 'optimizer': 'Adagrad', 'min_lr': 5.829816530169608e-05, 'dropout_rate': 0.14849242227567105}
# 2022-10-07 13:27:02,104 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:27:02,105 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:27:02,106 - logger - INFO - CreateFPS transform...
# [13:27:06] WARNING: not removing hydrogen atom without neighbors
# [13:27:06] WARNING: not removing hydrogen atom without neighbors
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# [13:29:22] WARNING: not removing hydrogen atom without neighbors
# [13:29:22] WARNING: not removing hydrogen atom without neighbors
# [13:29:22] WARNING: not removing hydrogen atom without neighbors
# [13:29:22] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:29<00:00, 247.38it/s]
# [13:30:37] WARNING: not removing hydrogen atom without neighbors
# [13:30:37] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:30:52,920 - logger - INFO - Scaler fit...
# 2022-10-07 13:30:53,185 - logger - INFO - Scaler transform...
# 2022-10-07 13:30:53,570 - logger - INFO - Scaler fit...
# 2022-10-07 13:31:02,774 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:31:02,775 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 321.36it/s]
# 2022-10-07 13:31:23,951 - logger - INFO - Scaler transform...
# 2022-10-07 13:31:24,006 - logger - INFO - PCA transform...
# 129/129 [==============================] - 0s 2ms/step
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-07 13:31:25,177 - logger - INFO - Precision on hold-out: 0.000000
# 2022-10-07 13:31:25,178 - logger - INFO - Recall on hold-out: 0.000000
# 2022-10-07 13:31:25,179 - logger - INFO - Accuracy on hold-out: 0.966205
# 2022-10-07 13:31:25,180 - logger - INFO - F1-score on hold-out: 0.000000
# 2022-10-07 13:31:25,181 - logger - INFO - ROC-AUC on hold-out: 0.500000
# 2022-10-07 13:31:25,181 - logger - INFO - Average precision on hold-out: 0.033795
# 2022-10-07 13:31:25,182 - logger - INFO - MCC on hold-out: 0.000000
# 2022-10-07 13:31:25,537 - logger - INFO - Performance on training set
# 2022-10-07 13:31:25,538 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:31:25,539 - logger - INFO - CreateFPS transform...
# [13:31:29] WARNING: not removing hydrogen atom without neighbors
# [13:31:29] WARNING: not removing hydrogen atom without neighbors
# [13:33:50] WARNING: not removing hydrogen atom without neighbors
# [13:33:50] WARNING: not removing hydrogen atom without neighbors
# [13:33:50] WARNING: not removing hydrogen atom without neighbors
# [13:33:50] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:29<00:00, 246.86it/s]
# [13:34:59] WARNING: not removing hydrogen atom without neighbors
# [13:34:59] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:35:15,257 - logger - INFO - Scaler fit...
# 2022-10-07 13:35:15,518 - logger - INFO - Scaler transform...
# 2022-10-07 13:35:15,895 - logger - INFO - Scaler fit...
# 2022-10-07 13:35:24,403 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:35:24,405 - logger - INFO - CreateFPS transform...
# [13:35:28] WARNING: not removing hydrogen atom without neighbors
# [13:35:28] WARNING: not removing hydrogen atom without neighbors
# [13:37:21] WARNING: not removing hydrogen atom without neighbors
# [13:37:21] WARNING: not removing hydrogen atom without neighbors
# [13:37:21] WARNING: not removing hydrogen atom without neighbors
# [13:37:21] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:04<00:00, 297.10it/s]
# [13:38:33] WARNING: not removing hydrogen atom without neighbors
# [13:38:33] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:38:49,053 - logger - INFO - Scaler transform...
# 2022-10-07 13:38:49,702 - logger - INFO - PCA transform...
# 1157/1157 [==============================] - 2s 2ms/step
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-07 13:38:55,386 - logger - INFO - Precision on training: 0.000000
# 2022-10-07 13:38:55,387 - logger - INFO - Recall on training: 0.000000
# 2022-10-07 13:38:55,388 - logger - INFO - Accuracy on training: 0.964770
# 2022-10-07 13:38:55,388 - logger - INFO - F1-score on training: 0.000000
# 2022-10-07 13:38:55,389 - logger - INFO - ROC-AUC on training: 0.500000
# 2022-10-07 13:38:55,390 - logger - INFO - Average precision on training: 0.035230
# 2022-10-07 13:38:55,390 - logger - INFO - MCC on training 0.000000

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)
