# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "ridge"
RESULT_FILE_REGRESSOR = "result_regressor_ridge.csv"
RESULT_FILE_CLASSIFIER = "result_classifier_ridge_HIV.csv"
# Out:
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 2022-10-07 12:51:25.953164: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-10-07 12:51:27,676 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 12:51:27,695 - logger - INFO - Training configuration:
# 2022-10-07 12:51:27,696 - logger - INFO - Prediction methodology: M_Ridge
# 2022-10-07 12:51:27,697 - logger - INFO - Prediction type: classification
# 2022-10-07 12:51:27,697 - logger - INFO - Data file: HIV.csv
# 2022-10-07 12:51:27,698 - logger - INFO - Max. activity level: 1
# 2022-10-07 12:51:27,698 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 12:51:27,699 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 12:51:27,700 - logger - INFO - Model storage: model_ridge_classifier_QED_mean_no_limit_HIV.model
# 2022-10-07 12:51:27,700 - logger - INFO - Pipeline configuration:
# 2022-10-07 12:51:27,701 - logger - INFO - FPs?: no
# 2022-10-07 12:51:27,701 - logger - INFO - MDs?: yes
# 2022-10-07 12:51:27,702 - logger - INFO - Scaling?: yes
# 2022-10-07 12:51:27,703 - logger - INFO - PCA?: no
# 2022-10-07 12:51:27,705 - logger - INFO - Target transform?: no
# 2022-10-07 12:51:27,706 - logger - INFO - Target binarization?: no
# 2022-10-07 12:51:27,734 - logger - INFO - Scaler constructor...
# 2022-10-07 12:51:27,734 - logger - INFO - Optimal hyperparameters:, {'alpha': 0.8357475000715241, 'fit_intercept': True, 'max_iter': 15000, 'tol': 0.001, 'solver': 'sag'}
# 2022-10-07 12:51:27,735 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 12:51:27,736 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:51:27,737 - logger - INFO - CreateFPS transform...
# [12:51:32] WARNING: not removing hydrogen atom without neighbors
# [12:51:32] WARNING: not removing hydrogen atom without neighbors
# [12:52:54] WARNING: not removing hydrogen atom without neighbors
# [12:52:54] WARNING: not removing hydrogen atom without neighbors
# [12:52:54] WARNING: not removing hydrogen atom without neighbors
# [12:52:54] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:51<00:00, 332.81it/s]
# [12:54:02] WARNING: not removing hydrogen atom without neighbors
# [12:54:02] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:54:16,681 - logger - INFO - Scaler fit...
# 2022-10-07 12:54:16,698 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:54:16,699 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:12<00:00, 336.59it/s]
# 2022-10-07 12:54:35,252 - logger - INFO - Scaler transform...
# /home/dnowak/miniconda3/envs/rorgammaqsar/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 2022-10-07 12:54:35,610 - logger - INFO - Precision on hold-out: 0.000000
# 2022-10-07 12:54:35,611 - logger - INFO - Recall on hold-out: 0.000000
# 2022-10-07 12:54:35,611 - logger - INFO - Accuracy on hold-out: 0.966205
# 2022-10-07 12:54:35,612 - logger - INFO - F1-score on hold-out: 0.000000
# 2022-10-07 12:54:35,612 - logger - INFO - ROC-AUC on hold-out: 0.500000
# 2022-10-07 12:54:35,613 - logger - INFO - Average precision on hold-out: 0.033795
# 2022-10-07 12:54:35,614 - logger - INFO - MCC on hold-out: 0.000000
# 2022-10-07 12:54:35,765 - logger - INFO - Performance on training set
# 2022-10-07 12:54:35,766 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:54:35,767 - logger - INFO - CreateFPS transform...
# [12:54:40] WARNING: not removing hydrogen atom without neighbors
# [12:54:40] WARNING: not removing hydrogen atom without neighbors
# [12:56:06] WARNING: not removing hydrogen atom without neighbors
# [12:56:06] WARNING: not removing hydrogen atom without neighbors
# [12:56:06] WARNING: not removing hydrogen atom without neighbors
# [12:56:06] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:57<00:00, 313.85it/s]
# [12:57:18] WARNING: not removing hydrogen atom without neighbors
# [12:57:18] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 12:57:34,431 - logger - INFO - Scaler fit...
# 2022-10-07 12:57:34,443 - logger - INFO - CreateFPS fit...
# 2022-10-07 12:57:34,444 - logger - INFO - CreateFPS transform...
# [12:57:39] WARNING: not removing hydrogen atom without neighbors
# [12:57:39] WARNING: not removing hydrogen atom without neighbors
# [12:59:10] WARNING: not removing hydrogen atom without neighbors
# [12:59:10] WARNING: not removing hydrogen atom without neighbors
# [12:59:10] WARNING: not removing hydrogen atom without neighbors
# [12:59:10] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:00<00:00, 306.81it/s]
# [13:00:23] WARNING: not removing hydrogen atom without neighbors
# [13:00:23] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:00:39,071 - logger - INFO - Scaler transform...
# 2022-10-07 13:00:39,396 - logger - INFO - Precision on training: 0.500000
# 2022-10-07 13:00:39,397 - logger - INFO - Recall on training: 0.003067
# 2022-10-07 13:00:39,397 - logger - INFO - Accuracy on training: 0.964770
# 2022-10-07 13:00:39,398 - logger - INFO - F1-score on training: 0.006098
# 2022-10-07 13:00:39,398 - logger - INFO - ROC-AUC on training: 0.501478
# 2022-10-07 13:00:39,399 - logger - INFO - Average precision on training: 0.036656
# 2022-10-07 13:00:39,399 - logger - INFO - MCC on training 0.037066

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limit

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:00:40,255 - logger - INFO - Training configuration:
# 2022-10-07 13:00:40,256 - logger - INFO - Prediction methodology: M_Ridge
# 2022-10-07 13:00:40,256 - logger - INFO - Prediction type: classification
# 2022-10-07 13:00:40,257 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:00:40,257 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:00:40,258 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:00:40,258 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:00:40,259 - logger - INFO - Model storage: model_ridge_classifier_Morgan_1024_mean_no_limit_HIV.model
# 2022-10-07 13:00:40,259 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:00:40,260 - logger - INFO - FPs?: yes
# 2022-10-07 13:00:40,260 - logger - INFO - FP size?: 1024
# 2022-10-07 13:00:40,261 - logger - INFO - MDs?: no
# 2022-10-07 13:00:40,261 - logger - INFO - Scaling?: no
# 2022-10-07 13:00:40,262 - logger - INFO - PCA?: no
# 2022-10-07 13:00:40,262 - logger - INFO - Target transform?: no
# 2022-10-07 13:00:40,263 - logger - INFO - Target binarization?: no
# 2022-10-07 13:00:40,909 - logger - INFO - Optimal hyperparameters:, {'alpha': 4.1396402434853465, 'fit_intercept': True, 'max_iter': 15000, 'tol': 0.001, 'solver': 'sag'}
# 2022-10-07 13:00:40,910 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:00:40,910 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:40,911 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:40,912 - logger - INFO - CreateFPS transform...
# 2022-10-07 13:00:44,337 - logger - INFO - Precision on hold-out: 0.809524
# 2022-10-07 13:00:44,338 - logger - INFO - Recall on hold-out: 0.122302
# 2022-10-07 13:00:44,339 - logger - INFO - Accuracy on hold-out: 0.969365
# 2022-10-07 13:00:44,339 - logger - INFO - F1-score on hold-out: 0.212500
# 2022-10-07 13:00:44,340 - logger - INFO - ROC-AUC on hold-out: 0.560648
# 2022-10-07 13:00:44,340 - logger - INFO - Average precision on hold-out: 0.128669
# 2022-10-07 13:00:44,341 - logger - INFO - MCC on hold-out: 0.307531
# 2022-10-07 13:00:44,498 - logger - INFO - Performance on training set
# 2022-10-07 13:00:44,499 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:44,499 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:00:44,500 - logger - INFO - CreateFPS transform...
# [13:00:49] WARNING: not removing hydrogen atom without neighbors
# [13:00:49] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:01:13,360 - logger - INFO - Precision on training: 0.854651
# 2022-10-07 13:01:13,361 - logger - INFO - Recall on training: 0.112730
# 2022-10-07 13:01:13,362 - logger - INFO - Accuracy on training: 0.968066
# 2022-10-07 13:01:13,363 - logger - INFO - F1-score on training: 0.199187
# 2022-10-07 13:01:13,364 - logger - INFO - ROC-AUC on training: 0.556015
# 2022-10-07 13:01:13,364 - logger - INFO - Average precision on training: 0.127603
# 2022-10-07 13:01:13,365 - logger - INFO - MCC on training 0.303691

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:01:14,267 - logger - INFO - Training configuration:
# 2022-10-07 13:01:14,268 - logger - INFO - Prediction methodology: M_Ridge
# 2022-10-07 13:01:14,269 - logger - INFO - Prediction type: classification
# 2022-10-07 13:01:14,269 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:01:14,270 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:01:14,270 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:01:14,271 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:01:14,271 - logger - INFO - Model storage: model_ridge_classifier_Morgan_1024_pca_128_QED_mean_no_limit_HIV.model
# 2022-10-07 13:01:14,272 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:01:14,272 - logger - INFO - FPs?: yes
# 2022-10-07 13:01:14,274 - logger - INFO - FP size?: 1024
# 2022-10-07 13:01:14,275 - logger - INFO - MDs?: yes
# 2022-10-07 13:01:14,275 - logger - INFO - Scaling?: yes
# 2022-10-07 13:01:14,276 - logger - INFO - PCA?: yes
# 2022-10-07 13:01:14,276 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:01:14,276 - logger - INFO - PCA - number of components: 128
# 2022-10-07 13:01:14,277 - logger - INFO - Target transform?: no
# 2022-10-07 13:01:14,277 - logger - INFO - Target binarization?: no
# 2022-10-07 13:01:14,916 - logger - INFO - Scaler constructor...
# 2022-10-07 13:01:14,917 - logger - INFO - PCA constructor...
# 2022-10-07 13:01:14,918 - logger - INFO - Optimal hyperparameters:, {'alpha': 0.8161063930975895, 'fit_intercept': True, 'max_iter': 15000, 'tol': 0.001, 'solver': 'lsqr'}
# 2022-10-07 13:01:14,919 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:01:14,921 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:01:14,922 - logger - INFO - CreateFPS transform...
# [13:01:19] WARNING: not removing hydrogen atom without neighbors
# [13:01:19] WARNING: not removing hydrogen atom without neighbors
# [13:03:09] WARNING: not removing hydrogen atom without neighbors
# [13:03:09] WARNING: not removing hydrogen atom without neighbors
# [13:03:09] WARNING: not removing hydrogen atom without neighbors
# [13:03:09] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:59<00:00, 308.90it/s]
# [13:04:23] WARNING: not removing hydrogen atom without neighbors
# [13:04:23] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:04:39,924 - logger - INFO - Scaler fit...
# 2022-10-07 13:04:40,186 - logger - INFO - Scaler transform...
# 2022-10-07 13:04:40,566 - logger - INFO - Scaler fit...
# 2022-10-07 13:04:47,183 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:04:47,184 - logger - INFO - CreateFPS transform...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4113/4113 [00:13<00:00, 310.95it/s]
# 2022-10-07 13:05:09,125 - logger - INFO - Scaler transform...
# 2022-10-07 13:05:09,179 - logger - INFO - PCA transform...
# 2022-10-07 13:05:09,567 - logger - INFO - Precision on hold-out: 1.000000
# 2022-10-07 13:05:09,569 - logger - INFO - Recall on hold-out: 0.043165
# 2022-10-07 13:05:09,570 - logger - INFO - Accuracy on hold-out: 0.967664
# 2022-10-07 13:05:09,571 - logger - INFO - F1-score on hold-out: 0.082759
# 2022-10-07 13:05:09,572 - logger - INFO - ROC-AUC on hold-out: 0.521583
# 2022-10-07 13:05:09,573 - logger - INFO - Average precision on hold-out: 0.075502
# 2022-10-07 13:05:09,575 - logger - INFO - MCC on hold-out: 0.204371
# 2022-10-07 13:05:09,781 - logger - INFO - Performance on training set
# 2022-10-07 13:05:09,783 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:05:09,784 - logger - INFO - CreateFPS transform...
# [13:05:14] WARNING: not removing hydrogen atom without neighbors
# [13:05:14] WARNING: not removing hydrogen atom without neighbors
# [13:07:13] WARNING: not removing hydrogen atom without neighbors
# [13:07:13] WARNING: not removing hydrogen atom without neighbors
# [13:07:13] WARNING: not removing hydrogen atom without neighbors
# [13:07:13] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:08<00:00, 286.95it/s]
# [13:08:39] WARNING: not removing hydrogen atom without neighbors
# [13:08:39] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:08:55,209 - logger - INFO - Scaler fit...
# 2022-10-07 13:08:55,479 - logger - INFO - Scaler transform...
# 2022-10-07 13:08:55,868 - logger - INFO - Scaler fit...
# 2022-10-07 13:09:03,662 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:09:03,663 - logger - INFO - CreateFPS transform...
# [13:09:08] WARNING: not removing hydrogen atom without neighbors
# [13:09:08] WARNING: not removing hydrogen atom without neighbors
# [13:11:00] WARNING: not removing hydrogen atom without neighbors
# [13:11:00] WARNING: not removing hydrogen atom without neighbors
# [13:11:00] WARNING: not removing hydrogen atom without neighbors
# [13:11:00] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [02:08<00:00, 288.53it/s]
# [13:12:17] WARNING: not removing hydrogen atom without neighbors
# [13:12:17] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:12:33,360 - logger - INFO - Scaler transform...
# 2022-10-07 13:12:33,993 - logger - INFO - PCA transform...
# 2022-10-07 13:12:35,119 - logger - INFO - Precision on training: 0.875000
# 2022-10-07 13:12:35,120 - logger - INFO - Recall on training: 0.037577
# 2022-10-07 13:12:35,121 - logger - INFO - Accuracy on training: 0.965905
# 2022-10-07 13:12:35,122 - logger - INFO - F1-score on training: 0.072059
# 2022-10-07 13:12:35,122 - logger - INFO - ROC-AUC on training: 0.518690
# 2022-10-07 13:12:35,123 - logger - INFO - Average precision on training: 0.066786
# 2022-10-07 13:12:35,124 - logger - INFO - MCC on training 0.177310

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:12:35,973 - logger - INFO - Training configuration:
# 2022-10-07 13:12:35,973 - logger - INFO - Prediction methodology: M_Ridge
# 2022-10-07 13:12:35,974 - logger - INFO - Prediction type: classification
# 2022-10-07 13:12:35,974 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:12:35,975 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:12:35,976 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:12:35,976 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:12:35,977 - logger - INFO - Model storage: model_ridge_classifier_Morgan_1024_pca_256_QED_mean_no_limit_HIV.model
# 2022-10-07 13:12:35,977 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:12:35,977 - logger - INFO - FPs?: yes
# 2022-10-07 13:12:35,978 - logger - INFO - FP size?: 1024
# 2022-10-07 13:12:35,978 - logger - INFO - MDs?: yes
# 2022-10-07 13:12:35,979 - logger - INFO - Scaling?: yes
# 2022-10-07 13:12:35,979 - logger - INFO - PCA?: yes
# 2022-10-07 13:12:35,980 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:12:35,980 - logger - INFO - PCA - number of components: 256
# 2022-10-07 13:12:35,981 - logger - INFO - Target transform?: no
# 2022-10-07 13:12:35,981 - logger - INFO - Target binarization?: no
# 2022-10-07 13:12:36,614 - logger - INFO - Scaler constructor...
# 2022-10-07 13:12:36,615 - logger - INFO - PCA constructor...
# 2022-10-07 13:12:36,616 - logger - INFO - Optimal hyperparameters:, {'alpha': 0.8357475000715241, 'fit_intercept': True, 'max_iter': 15000, 'tol': 0.001, 'solver': 'sag'}
# 2022-10-07 13:12:36,617 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:12:36,617 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:12:36,618 - logger - INFO - CreateFPS transform...
# [13:12:41] WARNING: not removing hydrogen atom without neighbors
# [13:12:41] WARNING: not removing hydrogen atom without neighbors
# [13:14:30] WARNING: not removing hydrogen atom without neighbors
# [13:14:30] WARNING: not removing hydrogen atom without neighbors
# [13:14:30] WARNING: not removing hydrogen atom without neighbors
# [13:14:30] WARNING: not removing hydrogen atom without neighbors
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37014/37014 [01:58<00:00, 311.52it/s]
# [13:15:38] WARNING: not removing hydrogen atom without neighbors
# [13:15:38] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:16:00,141 - logger - INFO - Scaler fit...
# 2022-10-07 13:16:00,403 - logger - INFO - Scaler transform...
# 2022-10-07 13:16:00,776 - logger - INFO - Scaler fit...
# 2022-10-07 13:16:13,112 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:16:13,114 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 323.44it/s]
# 2022-10-07 13:16:34,660 - logger - INFO - Scaler transform...
# 2022-10-07 13:16:34,722 - logger - INFO - PCA transform...
# 2022-10-07 13:16:35,139 - logger - INFO - Precision on hold-out: 0.833333
# 2022-10-07 13:16:35,140 - logger - INFO - Recall on hold-out: 0.107914
# 2022-10-07 13:16:35,141 - logger - INFO - Accuracy on hold-out: 0.969122
# 2022-10-07 13:16:35,141 - logger - INFO - F1-score on hold-out: 0.191083
# 2022-10-07 13:16:35,142 - logger - INFO - ROC-AUC on hold-out: 0.553579
# 2022-10-07 13:16:35,142 - logger - INFO - Average precision on hold-out: 0.120076
# 2022-10-07 13:16:35,143 - logger - INFO - MCC on hold-out: 0.293350
# 2022-10-07 13:16:35,313 - logger - INFO - Performance on training set
# 2022-10-07 13:16:35,314 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:16:35,316 - logger - INFO - CreateFPS transform...
# [13:16:40] WARNING: not removing hydrogen atom without neighbors
# [13:16:40] WARNING: not removing hydrogen atom without neighbors
# [13:18:30] WARNING: not removing hydrogen atom without neighbors
# [13:18:30] WARNING: not removing hydrogen atom without neighbors
# [13:18:30] WARNING: not removing hydrogen atom without neighbors
# [13:18:30] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:12<00:00, 279.92it/s]
# [13:19:52] WARNING: not removing hydrogen atom without neighbors
# [13:19:52] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:20:31,341 - logger - INFO - Scaler fit...
# 2022-10-07 13:20:31,694 - logger - INFO - Scaler transform...
# 2022-10-07 13:20:32,121 - logger - INFO - Scaler fit...
# 2022-10-07 13:20:44,877 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:20:44,881 - logger - INFO - CreateFPS transform...
# [13:20:50] WARNING: not removing hydrogen atom without neighbors
# [13:20:50] WARNING: not removing hydrogen atom without neighbors
# [13:22:44] WARNING: not removing hydrogen atom without neighbors
# [13:22:44] WARNING: not removing hydrogen atom without neighbors
# [13:22:44] WARNING: not removing hydrogen atom without neighbors
# [13:22:44] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:17<00:00, 269.73it/s]
# [13:24:11] WARNING: not removing hydrogen atom without neighbors
# [13:24:11] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:24:33,040 - logger - INFO - Scaler transform...
# 2022-10-07 13:24:33,871 - logger - INFO - PCA transform...
# 2022-10-07 13:24:36,072 - logger - INFO - Precision on training: 0.847826
# 2022-10-07 13:24:36,075 - logger - INFO - Recall on training: 0.089724
# 2022-10-07 13:24:36,076 - logger - INFO - Accuracy on training: 0.967364
# 2022-10-07 13:24:36,078 - logger - INFO - F1-score on training: 0.162275
# 2022-10-07 13:24:36,080 - logger - INFO - ROC-AUC on training: 0.544568
# 2022-10-07 13:24:36,081 - logger - INFO - Average precision on training: 0.108139
# 2022-10-07 13:24:36,082 - logger - INFO - MCC on training 0.269634

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:24:38,352 - logger - INFO - Training configuration:
# 2022-10-07 13:24:38,353 - logger - INFO - Prediction methodology: M_Ridge
# 2022-10-07 13:24:38,354 - logger - INFO - Prediction type: classification
# 2022-10-07 13:24:38,355 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:24:38,356 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:24:38,357 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:24:38,358 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:24:38,359 - logger - INFO - Model storage: model_ridge_classifier_Morgan_1024_pca_512_QED_mean_no_limit_HIV.model
# 2022-10-07 13:24:38,360 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:24:38,361 - logger - INFO - FPs?: yes
# 2022-10-07 13:24:38,362 - logger - INFO - FP size?: 1024
# 2022-10-07 13:24:38,363 - logger - INFO - MDs?: yes
# 2022-10-07 13:24:38,364 - logger - INFO - Scaling?: yes
# 2022-10-07 13:24:38,375 - logger - INFO - PCA?: yes
# 2022-10-07 13:24:38,377 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:24:38,378 - logger - INFO - PCA - number of components: 512
# 2022-10-07 13:24:38,384 - logger - INFO - Target transform?: no
# 2022-10-07 13:24:38,385 - logger - INFO - Target binarization?: no
# 2022-10-07 13:24:39,207 - logger - INFO - Scaler constructor...
# 2022-10-07 13:24:39,219 - logger - INFO - PCA constructor...
# 2022-10-07 13:24:39,221 - logger - INFO - Optimal hyperparameters:, {'alpha': 0.11304774403562312, 'fit_intercept': True, 'max_iter': 15000, 'tol': 0.001, 'solver': 'lsqr'}
# 2022-10-07 13:24:39,222 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:24:39,224 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:24:39,225 - logger - INFO - CreateFPS transform...
# [13:24:48] WARNING: not removing hydrogen atom without neighbors
# [13:24:48] WARNING: not removing hydrogen atom without neighbors
# [13:26:40] WARNING: not removing hydrogen atom without neighbors
# [13:26:40] WARNING: not removing hydrogen atom without neighbors
# [13:26:40] WARNING: not removing hydrogen atom without neighbors
# [13:26:40] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:03<00:00, 300.50it/s]
# [13:28:08] WARNING: not removing hydrogen atom without neighbors
# [13:28:08] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:28:24,399 - logger - INFO - Scaler fit...
# 2022-10-07 13:28:24,667 - logger - INFO - Scaler transform...
# 2022-10-07 13:28:25,055 - logger - INFO - Scaler fit...
# 2022-10-07 13:28:51,506 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:28:51,508 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 317.84it/s]
# 2022-10-07 13:29:12,846 - logger - INFO - Scaler transform...
# 2022-10-07 13:29:12,904 - logger - INFO - PCA transform...
# 2022-10-07 13:29:13,406 - logger - INFO - Precision on hold-out: 0.833333
# 2022-10-07 13:29:13,408 - logger - INFO - Recall on hold-out: 0.143885
# 2022-10-07 13:29:13,409 - logger - INFO - Accuracy on hold-out: 0.970095
# 2022-10-07 13:29:13,409 - logger - INFO - F1-score on hold-out: 0.245399
# 2022-10-07 13:29:13,410 - logger - INFO - ROC-AUC on hold-out: 0.571439
# 2022-10-07 13:29:13,411 - logger - INFO - Average precision on hold-out: 0.148837
# 2022-10-07 13:29:13,411 - logger - INFO - MCC on hold-out: 0.338980
# 2022-10-07 13:29:13,590 - logger - INFO - Performance on training set
# 2022-10-07 13:29:13,592 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:29:13,593 - logger - INFO - CreateFPS transform...
# [13:29:18] WARNING: not removing hydrogen atom without neighbors
# [13:29:18] WARNING: not removing hydrogen atom without neighbors
# [13:31:09] WARNING: not removing hydrogen atom without neighbors
# [13:31:09] WARNING: not removing hydrogen atom without neighbors
# [13:31:09] WARNING: not removing hydrogen atom without neighbors
# [13:31:09] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:03<00:00, 299.33it/s]
# [13:32:42] WARNING: not removing hydrogen atom without neighbors
# [13:32:42] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:32:57,873 - logger - INFO - Scaler fit...
# 2022-10-07 13:32:58,144 - logger - INFO - Scaler transform...
# 2022-10-07 13:32:58,539 - logger - INFO - Scaler fit...
# 2022-10-07 13:33:25,584 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:33:25,588 - logger - INFO - CreateFPS transform...
# [13:33:30] WARNING: not removing hydrogen atom without neighbors
# [13:33:30] WARNING: not removing hydrogen atom without neighbors
# [13:35:20] WARNING: not removing hydrogen atom without neighbors
# [13:35:20] WARNING: not removing hydrogen atom without neighbors
# [13:35:20] WARNING: not removing hydrogen atom without neighbors
# [13:35:20] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:02<00:00, 302.93it/s]
# [13:36:39] WARNING: not removing hydrogen atom without neighbors
# [13:36:39] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:36:54,207 - logger - INFO - Scaler transform...
# 2022-10-07 13:36:54,862 - logger - INFO - PCA transform...
# 2022-10-07 13:36:56,563 - logger - INFO - Precision on training: 0.860465
# 2022-10-07 13:36:56,563 - logger - INFO - Recall on training: 0.113497
# 2022-10-07 13:36:56,564 - logger - INFO - Accuracy on training: 0.968120
# 2022-10-07 13:36:56,565 - logger - INFO - F1-score on training: 0.200542
# 2022-10-07 13:36:56,565 - logger - INFO - ROC-AUC on training: 0.556412
# 2022-10-07 13:36:56,566 - logger - INFO - Average precision on training: 0.128892
# 2022-10-07 13:36:56,566 - logger - INFO - MCC on training 0.305846

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_CLASSIFIER)

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED_HIV.json"), result_file=RESULT_FILE_CLASSIFIER)
# Out:
# 2022-10-07 13:36:57,439 - logger - INFO - Training configuration:
# 2022-10-07 13:36:57,439 - logger - INFO - Prediction methodology: M_Ridge
# 2022-10-07 13:36:57,440 - logger - INFO - Prediction type: classification
# 2022-10-07 13:36:57,440 - logger - INFO - Data file: HIV.csv
# 2022-10-07 13:36:57,441 - logger - INFO - Max. activity level: 1
# 2022-10-07 13:36:57,441 - logger - INFO - Std. threshold: 1000000
# 2022-10-07 13:36:57,441 - logger - INFO - Data preparation strategy: mean
# 2022-10-07 13:36:57,442 - logger - INFO - Model storage: model_ridge_classifier_Morgan_1024_pca_1024_QED_mean_no_limit_HIV.model
# 2022-10-07 13:36:57,442 - logger - INFO - Pipeline configuration:
# 2022-10-07 13:36:57,442 - logger - INFO - FPs?: yes
# 2022-10-07 13:36:57,443 - logger - INFO - FP size?: 1024
# 2022-10-07 13:36:57,443 - logger - INFO - MDs?: yes
# 2022-10-07 13:36:57,443 - logger - INFO - Scaling?: yes
# 2022-10-07 13:36:57,444 - logger - INFO - PCA?: yes
# 2022-10-07 13:36:57,444 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2022-10-07 13:36:57,445 - logger - INFO - PCA - number of components: 1024
# 2022-10-07 13:36:57,445 - logger - INFO - Target transform?: no
# 2022-10-07 13:36:57,445 - logger - INFO - Target binarization?: no
# 2022-10-07 13:36:58,082 - logger - INFO - Scaler constructor...
# 2022-10-07 13:36:58,083 - logger - INFO - PCA constructor...
# 2022-10-07 13:36:58,084 - logger - INFO - Optimal hyperparameters:, {'alpha': 0.7325351213407632, 'fit_intercept': True, 'max_iter': 15000, 'tol': 0.001, 'solver': 'auto'}
# 2022-10-07 13:36:58,085 - logger - INFO - Performance on external (hold-out) set
# 2022-10-07 13:36:58,086 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:36:58,086 - logger - INFO - CreateFPS transform...
# [13:37:02] WARNING: not removing hydrogen atom without neighbors
# [13:37:02] WARNING: not removing hydrogen atom without neighbors
# [13:38:53] WARNING: not removing hydrogen atom without neighbors
# [13:38:53] WARNING: not removing hydrogen atom without neighbors
# [13:38:53] WARNING: not removing hydrogen atom without neighbors
# [13:38:53] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:00<00:00, 306.18it/s]
# [13:40:07] WARNING: not removing hydrogen atom without neighbors
# [13:40:07] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:40:21,852 - logger - INFO - Scaler fit...
# 2022-10-07 13:40:22,126 - logger - INFO - Scaler transform...
# 2022-10-07 13:40:22,525 - logger - INFO - Scaler fit...
# 2022-10-07 13:40:31,329 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:40:31,332 - logger - INFO - CreateFPS transform...
# 100%|████████████████████████████████████████| 4113/4113 [00:12<00:00, 342.63it/s]
# 2022-10-07 13:40:51,676 - logger - INFO - Scaler transform...
# 2022-10-07 13:40:51,729 - logger - INFO - PCA transform...
# 2022-10-07 13:40:52,222 - logger - INFO - Precision on hold-out: 0.846154
# 2022-10-07 13:40:52,224 - logger - INFO - Recall on hold-out: 0.158273
# 2022-10-07 13:40:52,224 - logger - INFO - Accuracy on hold-out: 0.970581
# 2022-10-07 13:40:52,225 - logger - INFO - F1-score on hold-out: 0.266667
# 2022-10-07 13:40:52,226 - logger - INFO - ROC-AUC on hold-out: 0.578633
# 2022-10-07 13:40:52,227 - logger - INFO - Average precision on hold-out: 0.162370
# 2022-10-07 13:40:52,227 - logger - INFO - MCC on hold-out: 0.358566
# 2022-10-07 13:40:52,371 - logger - INFO - Performance on training set
# 2022-10-07 13:40:52,373 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:40:52,373 - logger - INFO - CreateFPS transform...
# [13:40:56] WARNING: not removing hydrogen atom without neighbors
# [13:40:56] WARNING: not removing hydrogen atom without neighbors
# [13:42:45] WARNING: not removing hydrogen atom without neighbors
# [13:42:45] WARNING: not removing hydrogen atom without neighbors
# [13:42:45] WARNING: not removing hydrogen atom without neighbors
# [13:42:45] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [01:57<00:00, 315.47it/s]
# [13:43:56] WARNING: not removing hydrogen atom without neighbors
# [13:43:56] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:44:11,456 - logger - INFO - Scaler fit...
# 2022-10-07 13:44:11,721 - logger - INFO - Scaler transform...
# 2022-10-07 13:44:12,102 - logger - INFO - Scaler fit...
# 2022-10-07 13:44:19,100 - logger - INFO - CreateFPS fit...
# 2022-10-07 13:44:19,102 - logger - INFO - CreateFPS transform...
# [13:44:23] WARNING: not removing hydrogen atom without neighbors
# [13:44:23] WARNING: not removing hydrogen atom without neighbors
# [13:46:18] WARNING: not removing hydrogen atom without neighbors
# [13:46:18] WARNING: not removing hydrogen atom without neighbors
# [13:46:18] WARNING: not removing hydrogen atom without neighbors
# [13:46:18] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████████████████████████████████| 37014/37014 [02:07<00:00, 290.35it/s]
# [13:47:28] WARNING: not removing hydrogen atom without neighbors
# [13:47:28] WARNING: not removing hydrogen atom without neighbors
# 2022-10-07 13:47:42,412 - logger - INFO - Scaler transform...
# 2022-10-07 13:47:43,044 - logger - INFO - PCA transform...
# 2022-10-07 13:47:45,473 - logger - INFO - Precision on training: 0.863636
# 2022-10-07 13:47:45,474 - logger - INFO - Recall on training: 0.131135
# 2022-10-07 13:47:45,474 - logger - INFO - Accuracy on training: 0.968661
# 2022-10-07 13:47:45,475 - logger - INFO - F1-score on training: 0.227696
# 2022-10-07 13:47:45,475 - logger - INFO - ROC-AUC on training: 0.565189
# 2022-10-07 13:47:45,476 - logger - INFO - Average precision on training: 0.143863
# 2022-10-07 13:47:45,476 - logger - INFO - MCC on training 0.329526

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, 100 nM

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)

# %% [markdown]
# ### Mean, no limits

# %%
#analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"), result_file=RESULT_FILE_REGRESSOR)
