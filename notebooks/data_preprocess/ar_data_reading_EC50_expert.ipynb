# %%
import pandas as pd
pd.options.display.max_colwidth = 300
pd.options.display.max_columns = 300
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

DATA_DIR=Path("../data")
nm2mol = 1E9

# %%
df = pd.read_csv("C:/Users/rbachorz/Projects/AR/fromMarcin/AR_EC50_processed_MRedit_RB.csv", sep="|")
df.head(2)
# Out:
#    comp_molregno act_standard_units act_standard_type  act_activity_comment  \
# 0            173                 nM              EC50                   NaN
# 1            716                 nM              EC50                   NaN
#
#   act_bao_endpoint act_type ass_assay_id  \
# 0      BAO_0000188     EC50       941808
# 1      BAO_0000188     EC50        35936
#
#                                                                                                                                                                                                           ass_description  \
# 0  Agonist activity at androgen receptor (unknown origin) expressed in HeLa cells co-expressing PSA-(ARE)4-Luc13 assessed as induction of DHT-induced luciferase activity after 20 mins by luciferase reporter gene assay
# 1                                                                                                                   In vitro agonistic activity against human androgen receptor using cotransfection assay in CV-1 cells.
#
#   ass_expert_selection ass_assay_type  ass_assay_category  ass_chembl_id  \
# 0                  NaN              B                 NaN  CHEMBL2329799
# 1                  NaN              F                 NaN   CHEMBL646844
#
#                          doc_doi doc_pubmed_id  doc_chembl_id  \
# 0              10.1021/jm3017656      23432095  CHEMBL2321830
# 1  10.1016/s0960-894x(99)00118-3      10230628  CHEMBL1132082
#
#                                                                                                                                                                                            doc_title  \
# 0  Development of potent and selective indomethacin analogues for the inhibition of AKR1C3 (Type 5 17β-hydroxysteroid dehydrogenase/prostaglandin F synthase) in castrate-resistant prostate cancer.
# 1                                                                                               Nonsteroidal androgen receptor agonists based on 4-(trifluoromethyl)-2H-pyrano[3,2-g]quinolin-2-one.
#
#   doc_doc_type  \
# 0  PUBLICATION
# 1  PUBLICATION
#
#                                                                                                                                                                                                                                                                                                   doc_abstract  \
# 0  Castrate-resistant prostate cancer (CRPC) is a fatal, metastatic form of prostate cancer. CRPC is characterized by reactivation of the androgen axis due to changes in androgen receptor signaling and/or adaptive intratumoral androgen biosynthesis. AKR1C3 is upregulated in CRPC where it catalyzes ...
# 1  A series of 2H-pyrano[3,2-g]quinolin-2-ones was prepared and tested for the ability to modulate the transcriptional activity of the human androgen receptor (hAR). The parent compound, 4-(trifluoromethyl)-2H-pyrano[3,2-g]quinolin-2-one, displayed moderate interaction with hAR, but substituted ana...
#
#    doc_patent_id                           coms_canonical_smiles  \
# 0            NaN  COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1
# 1            NaN            CCC1CCNc2cc3oc(=O)cc(C(F)(F)F)c3cc21
#
#   comp_full_molformula mold_chembl_id  act_0  act_1  act_2  act_3  act_4  \
# 0          C19H16ClNO4        CHEMBL6   0.14    NaN    NaN    NaN    NaN
# 1          C15H14F3NO2     CHEMBL6843   2.00    NaN    NaN    NaN    NaN
#
#    act_5  act_6  act_7  act_8  act_9  act_10  act_11  act_12  act_13  act_14  \
# 0    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN     NaN
#
#    act_15  act_16  act_17  act_18  act_19  act_20  act_21  act_22  act_23  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    act_24  act_25  act_std  act_min  act_mean  act_median  act_max  \
# 0     NaN     NaN      0.0     0.14      0.14        0.14     0.14
# 1     NaN     NaN      0.0     2.00      2.00        2.00     2.00
#
#    log_act_mean  log_act_median  log_act_min  pEC50_mean  pEC50_median  \
# 0     -0.853872       -0.853872    -0.853872    9.853872      9.853872
# 1      0.301030        0.301030     0.301030    8.698970      8.698970
#
#    pEC50_min  meas_count class_activity_mean_1000 class_activity_median_1000  \
# 0   9.853872           1                   ACTIVE                     ACTIVE
# 1   8.698970           1                   ACTIVE                     ACTIVE
#
#   class_activity_min_1000 class_activity_max_1000 class_activity_mean_2000  \
# 0                  ACTIVE                  ACTIVE                   ACTIVE
# 1                  ACTIVE                  ACTIVE                   ACTIVE
#
#   class_activity_median_2000 class_activity_min_2000 class_activity_max_2000  \
# 0                     ACTIVE                  ACTIVE                  ACTIVE
# 1                     ACTIVE                  ACTIVE                  ACTIVE
#
#   class_activity_mean_3000 class_activity_median_3000 class_activity_min_3000  \
# 0                   ACTIVE                     ACTIVE                  ACTIVE
# 1                   ACTIVE                     ACTIVE                  ACTIVE
#
#   class_activity_max_3000 class_activity_mean_4000 class_activity_median_4000  \
# 0                  ACTIVE                   ACTIVE                     ACTIVE
# 1                  ACTIVE                   ACTIVE                     ACTIVE
#
#   class_activity_min_4000 class_activity_max_4000 class_activity_mean_5000  \
# 0                  ACTIVE                  ACTIVE                   ACTIVE
# 1                  ACTIVE                  ACTIVE                   ACTIVE
#
#   class_activity_median_5000 class_activity_min_5000 class_activity_max_5000
# 0                     ACTIVE                  ACTIVE                  ACTIVE
# 1                     ACTIVE                  ACTIVE                  ACTIVE

# %% [markdown]
# # neglect the rows

# %%
df = df[~(pd.isna(df["ass_expert_selection"]))]
df.head(2)
# Out:
#      comp_molregno act_standard_units act_standard_type  act_activity_comment  \
# 590        2343587                 nM              EC50                   NaN
# 591        2343897                 nM              EC50                   NaN
#
#     act_bao_endpoint act_type ass_assay_id  \
# 590      BAO_0000188     EC50      1929733
# 591      BAO_0000188     EC50      1929733
#
#                                                                                                                                                        ass_description  \
# 590  Antagonist activity at androgen receptor in human C4-2-PSA-rl cells incubated for 24 hrs in presence of androgen R1881 by dual-glo luciferase reporter gene assay
# 591  Antagonist activity at androgen receptor in human C4-2-PSA-rl cells incubated for 24 hrs in presence of androgen R1881 by dual-glo luciferase reporter gene assay
#
#     ass_expert_selection ass_assay_type  ass_assay_category  ass_chembl_id  \
# 590                    0              B                 NaN  CHEMBL4432909
# 591                    0              B                 NaN  CHEMBL4432909
#
#                             doc_doi doc_pubmed_id  doc_chembl_id  \
# 590  10.1021/acsmedchemlett.6b00186      27563404  CHEMBL4431378
# 591  10.1021/acsmedchemlett.6b00186      27563404  CHEMBL4431378
#
#                                                                                                                   doc_title  \
# 590  Small Molecule Antagonists of the Nuclear Androgen Receptor for the Treatment of Castration-Resistant Prostate Cancer.
# 591  Small Molecule Antagonists of the Nuclear Androgen Receptor for the Treatment of Castration-Resistant Prostate Cancer.
#
#     doc_doc_type  \
# 590  PUBLICATION
# 591  PUBLICATION
#
#                                                                                                                                                                                                                                                                                                     doc_abstract  \
# 590  After a high-throughput screening campaign identified thioether 1 as an antagonist of the nuclear androgen receptor, a zone model was developed for structure-activity relationship (SAR) purposes and analogues were synthesized and evaluated in a cell-based luciferase assay. A novel thioether isos...
# 591  After a high-throughput screening campaign identified thioether 1 as an antagonist of the nuclear androgen receptor, a zone model was developed for structure-activity relationship (SAR) purposes and analogues were synthesized and evaluated in a cell-based luciferase assay. A novel thioether isos...
#
#      doc_patent_id                  coms_canonical_smiles  \
# 590            NaN  Cc1noc(C)c1CSCC(=O)N1CCN(c2ccccc2)CC1
# 591            NaN  Cc1ccccc1N1CCN(C(=O)/C=C\c2ccccc2)CC1
#
#     comp_full_molformula mold_chembl_id    act_0  act_1  act_2  act_3  act_4  \
# 590          C18H23N3O2S  CHEMBL4436578  25000.0    NaN    NaN    NaN    NaN
# 591            C20H22N2O  CHEMBL4436888  12700.0    NaN    NaN    NaN    NaN
#
#      act_5  act_6  act_7  act_8  act_9  act_10  act_11  act_12  act_13  \
# 590    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 591    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN
#
#      act_14  act_15  act_16  act_17  act_18  act_19  act_20  act_21  act_22  \
# 590     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 591     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      act_23  act_24  act_25  act_std  act_min  act_mean  act_median  act_max  \
# 590     NaN     NaN     NaN      0.0  25000.0   25000.0     25000.0  25000.0
# 591     NaN     NaN     NaN      0.0  12700.0   12700.0     12700.0  12700.0
#
#      log_act_mean  log_act_median  log_act_min  pEC50_mean  pEC50_median  \
# 590      4.397940        4.397940     4.397940    4.602060      4.602060
# 591      4.103804        4.103804     4.103804    4.896196      4.896196
#
#      pEC50_min  meas_count class_activity_mean_1000  \
# 590   4.602060           1                 INACTIVE
# 591   4.896196           1                 INACTIVE
#
#     class_activity_median_1000 class_activity_min_1000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_1000 class_activity_mean_2000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_2000 class_activity_min_2000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_2000 class_activity_mean_3000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_3000 class_activity_min_3000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_3000 class_activity_mean_4000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_4000 class_activity_min_4000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_4000 class_activity_mean_5000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_5000 class_activity_min_5000 class_activity_max_5000
# 590                   INACTIVE                INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE                INACTIVE

# %%
df.shape
# Out:
# (37, 80)

# %%
def create_relevant_activity_cols(x):
    ret = ["act_"+str(item) for item in x.split(",") if str(item) != ""]
    return ret

# %%
df["ass_expert_selection_list"] = df["ass_expert_selection"].apply(create_relevant_activity_cols)

# %%
expert_mean = []
expert_median = []
expert_min = []
expert_max = []
for index, row in df.iterrows():
    relevant_activities = row["ass_expert_selection_list"]
    expert_mean.append(np.mean(row[relevant_activities]))
    expert_median.append(np.nanmedian(row[relevant_activities]))
    expert_min.append(np.min(row[relevant_activities]))
    expert_max.append(np.max(row[relevant_activities]))
df["act_mean_expert"] = expert_mean
df["act_median_expert"] = expert_median
df["act_min_expert"] = expert_min
df["act_max_expert"] = expert_max

# %%
df["pIC50_expert_mean"] = df["act_mean_expert"].apply(lambda x: -1.0*np.log10(x / nm2mol))
df["pIC50_expert_median"] = df["act_median_expert"].apply(lambda x: -1.0*np.log10(x / nm2mol))
df["pIC50_expert_min"] = df["act_min_expert"].apply(lambda x: -1.0*np.log10(x / nm2mol))
df["pIC50_expert_max"] = df["act_max_expert"].apply(lambda x: -1.0*np.log10(x / nm2mol))

# %%
df["act_mean"].hist(bins=100)
# Out:
# <Axes: >

# %%
data = df[df["act_std"] > 100]["act_std"]
plt.hist(data, bins=50)
plt.grid()
plt.xlabel("Standard deviation of IC50", fontsize=14)
plt.ylabel("Compounds count", fontsize=14)
plt.title("Conflicting IC50 values", fontsize=16)
# plt.savefig("C:\\Users\\rbachorz\\Projects\\rorgammaaidd\\presentation\\IC50_std_distribution.svg", dpi=200)
# Out:
# Text(0.5, 1.0, 'Conflicting IC50 values')

# %%
df.shape[0]/data.shape[0]
# Out:
# 37.0

# %%
activity_thresholds = [1000, 2000, 3000, 4000, 5000]
for at in activity_thresholds:
    df["class_activity_mean_"+str(at)] = df["act_mean"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")
    df["class_activity_mean_expert_"+str(at)] = df["act_mean_expert"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")

    df["class_activity_median_"+str(at)] = df["act_median"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")
    df["class_activity_median_expert_"+str(at)] = df["act_median_expert"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")

    df["class_activity_min_"+str(at)] = df["act_min"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")
    df["class_activity_min_expert_"+str(at)] = df["act_min_expert"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")

    df["class_activity_max_"+str(at)] = df["act_max"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")
    df["class_activity_min_expert_"+str(at)] = df["act_min_expert"].apply(lambda x: "ACTIVE" if x < at else "INACTIVE")

# %%
df.head(2)
# Out:
#      comp_molregno act_standard_units act_standard_type  act_activity_comment  \
# 590        2343587                 nM              EC50                   NaN
# 591        2343897                 nM              EC50                   NaN
#
#     act_bao_endpoint act_type ass_assay_id  \
# 590      BAO_0000188     EC50      1929733
# 591      BAO_0000188     EC50      1929733
#
#                                                                                                                                                        ass_description  \
# 590  Antagonist activity at androgen receptor in human C4-2-PSA-rl cells incubated for 24 hrs in presence of androgen R1881 by dual-glo luciferase reporter gene assay
# 591  Antagonist activity at androgen receptor in human C4-2-PSA-rl cells incubated for 24 hrs in presence of androgen R1881 by dual-glo luciferase reporter gene assay
#
#     ass_expert_selection ass_assay_type  ass_assay_category  ass_chembl_id  \
# 590                    0              B                 NaN  CHEMBL4432909
# 591                    0              B                 NaN  CHEMBL4432909
#
#                             doc_doi doc_pubmed_id  doc_chembl_id  \
# 590  10.1021/acsmedchemlett.6b00186      27563404  CHEMBL4431378
# 591  10.1021/acsmedchemlett.6b00186      27563404  CHEMBL4431378
#
#                                                                                                                   doc_title  \
# 590  Small Molecule Antagonists of the Nuclear Androgen Receptor for the Treatment of Castration-Resistant Prostate Cancer.
# 591  Small Molecule Antagonists of the Nuclear Androgen Receptor for the Treatment of Castration-Resistant Prostate Cancer.
#
#     doc_doc_type  \
# 590  PUBLICATION
# 591  PUBLICATION
#
#                                                                                                                                                                                                                                                                                                     doc_abstract  \
# 590  After a high-throughput screening campaign identified thioether 1 as an antagonist of the nuclear androgen receptor, a zone model was developed for structure-activity relationship (SAR) purposes and analogues were synthesized and evaluated in a cell-based luciferase assay. A novel thioether isos...
# 591  After a high-throughput screening campaign identified thioether 1 as an antagonist of the nuclear androgen receptor, a zone model was developed for structure-activity relationship (SAR) purposes and analogues were synthesized and evaluated in a cell-based luciferase assay. A novel thioether isos...
#
#      doc_patent_id                  coms_canonical_smiles  \
# 590            NaN  Cc1noc(C)c1CSCC(=O)N1CCN(c2ccccc2)CC1
# 591            NaN  Cc1ccccc1N1CCN(C(=O)/C=C\c2ccccc2)CC1
#
#     comp_full_molformula mold_chembl_id    act_0  act_1  act_2  act_3  act_4  \
# 590          C18H23N3O2S  CHEMBL4436578  25000.0    NaN    NaN    NaN    NaN
# 591            C20H22N2O  CHEMBL4436888  12700.0    NaN    NaN    NaN    NaN
#
#      act_5  act_6  act_7  act_8  act_9  act_10  act_11  act_12  act_13  \
# 590    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 591    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN     NaN
#
#      act_14  act_15  act_16  act_17  act_18  act_19  act_20  act_21  act_22  \
# 590     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 591     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      act_23  act_24  act_25  act_std  act_min  act_mean  act_median  act_max  \
# 590     NaN     NaN     NaN      0.0  25000.0   25000.0     25000.0  25000.0
# 591     NaN     NaN     NaN      0.0  12700.0   12700.0     12700.0  12700.0
#
#      log_act_mean  log_act_median  log_act_min  pEC50_mean  pEC50_median  \
# 590      4.397940        4.397940     4.397940    4.602060      4.602060
# 591      4.103804        4.103804     4.103804    4.896196      4.896196
#
#      pEC50_min  meas_count class_activity_mean_1000  \
# 590   4.602060           1                 INACTIVE
# 591   4.896196           1                 INACTIVE
#
#     class_activity_median_1000 class_activity_min_1000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_1000 class_activity_mean_2000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_2000 class_activity_min_2000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_2000 class_activity_mean_3000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_3000 class_activity_min_3000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_3000 class_activity_mean_4000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_4000 class_activity_min_4000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_4000 class_activity_mean_5000  \
# 590                INACTIVE                 INACTIVE
# 591                INACTIVE                 INACTIVE
#
#     class_activity_median_5000 class_activity_min_5000  \
# 590                   INACTIVE                INACTIVE
# 591                   INACTIVE                INACTIVE
#
#     class_activity_max_5000 ass_expert_selection_list  act_mean_expert  \
# 590                INACTIVE                   [act_0]          25000.0
# 591                INACTIVE                   [act_0]          12700.0
#
#      act_median_expert  act_min_expert  act_max_expert  pIC50_expert_mean  \
# 590            25000.0         25000.0         25000.0           4.602060
# 591            12700.0         12700.0         12700.0           4.896196
#
#      pIC50_expert_median  pIC50_expert_min  pIC50_expert_max  \
# 590             4.602060          4.602060          4.602060
# 591             4.896196          4.896196          4.896196
#
#     class_activity_mean_expert_1000 class_activity_median_expert_1000  \
# 590                        INACTIVE                          INACTIVE
# 591                        INACTIVE                          INACTIVE
#
#     class_activity_min_expert_1000 class_activity_mean_expert_2000  \
# 590                       INACTIVE                        INACTIVE
# 591                       INACTIVE                        INACTIVE
#
#     class_activity_median_expert_2000 class_activity_min_expert_2000  \
# 590                          INACTIVE                       INACTIVE
# 591                          INACTIVE                       INACTIVE
#
#     class_activity_mean_expert_3000 class_activity_median_expert_3000  \
# 590                        INACTIVE                          INACTIVE
# 591                        INACTIVE                          INACTIVE
#
#     class_activity_min_expert_3000 class_activity_mean_expert_4000  \
# 590                       INACTIVE                        INACTIVE
# 591                       INACTIVE                        INACTIVE
#
#     class_activity_median_expert_4000 class_activity_min_expert_4000  \
# 590                          INACTIVE                       INACTIVE
# 591                          INACTIVE                       INACTIVE
#
#     class_activity_mean_expert_5000 class_activity_median_expert_5000  \
# 590                        INACTIVE                          INACTIVE
# 591                        INACTIVE                          INACTIVE
#
#     class_activity_min_expert_5000
# 590                       INACTIVE
# 591                       INACTIVE

# %%
df.columns
# Out:
# Index(['comp_molregno', 'act_standard_units', 'act_standard_type',
#        'act_activity_comment', 'act_bao_endpoint', 'act_type', 'ass_assay_id',
#        'ass_description', 'ass_expert_selection', 'ass_assay_type',
#        ...
#        'class_activity_min_expert_2000', 'class_activity_mean_expert_3000',
#        'class_activity_median_expert_3000', 'class_activity_min_expert_3000',
#        'class_activity_mean_expert_4000', 'class_activity_median_expert_4000',
#        'class_activity_min_expert_4000', 'class_activity_mean_expert_5000',
#        'class_activity_median_expert_5000', 'class_activity_min_expert_5000'],
#       dtype='object', length=104)

# %%
df["class_activity_median_1000"].hist()
# Out:
# <Axes: >

# %%
df["class_activity_median_expert_1000"].hist()
# Out:
# <Axes: >

# %%
df[["class_activity_median_expert_1000", "class_activity_median_1000"]]
# Out:
#      class_activity_median_expert_1000 class_activity_median_1000
# 0                               ACTIVE                     ACTIVE
# 1                               ACTIVE                     ACTIVE
# 2                               ACTIVE                     ACTIVE
# 3                               ACTIVE                     ACTIVE
# 4                               ACTIVE                     ACTIVE
# ...                                ...                        ...
# 2323                            ACTIVE                     ACTIVE
# 2324                            ACTIVE                     ACTIVE
# 2325                          INACTIVE                   INACTIVE
# 2326                          INACTIVE                   INACTIVE
# 2327                            ACTIVE                     ACTIVE
#
# [1538 rows x 2 columns]

# %%
df[["act_median_expert", "act_median"]]
# Out:
#      act_median_expert  act_median
# 590            25000.0     25000.0
# 591            12700.0     12700.0
# 592             7200.0      7200.0
# 593             7800.0      7800.0
# 594            25000.0     25000.0
# 595            25000.0     25000.0
# 596            16100.0     16100.0
# 597             3100.0      3100.0
# 599            25000.0     25000.0
# 602            10800.0     10800.0
# 603            25000.0     25000.0
# 605            13700.0     13700.0
# 606            20300.0     20300.0
# 607            25000.0     25000.0
# 608            25000.0     25000.0
# 609            14500.0     14500.0
# 611            14400.0     14400.0
# 612            25000.0     25000.0
# 617            12600.0     12600.0
# 620            25000.0     25000.0
# 621             2700.0      2700.0
# 622            25000.0     25000.0
# 623            25000.0     25000.0
# 625              100.0       100.0
# 627              470.0       470.0
# 628             1650.0      1650.0
# 630            25000.0     25000.0
# 631             1700.0      1700.0
# 632            12000.0     12000.0
# 633             2900.0      2900.0
# 634            11100.0     11100.0
# 637             8450.0      8450.0
# 639            11100.0     11100.0
# 641            18400.0     18400.0
# 642            14700.0     14700.0
# 644              190.0       190.0
# 645            16600.0     16600.0

# %%
df = df.drop(["ass_expert_selection_list"], axis=1)

# %%
df["source"] = "EC50"

# %%
df.to_csv(DATA_DIR/"processed"/"ar_homo_sapiens_chembl_3.3_more_ChEMBL_columnsEC50.csv_processed_expert.csv", sep=",", index=False)
