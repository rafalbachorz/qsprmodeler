# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor, get_predictions_regressor, get_predictions_classifier, \
    get_model_predictions, get_model_ext_predictions

from pathlib import Path

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from rdkit import Chem
from rdkit.Chem import Draw

pd.set_option('display.max_columns', None)
random_seed = 42

TRAINING_CONF_DIR = Path("../training_configurations")

# %%
## REG -> RF, Bagging, Ridge

# %%
analyze_regressor(TRAINING_CONF_DIR/"PXR_xgboost_regressor_pca50_expert.json")
# Out:
# 2024-01-10 10:46:05,982 - logger - INFO - Training configuration:
# 2024-01-10 10:46:05,984 - logger - INFO - Prediction methodology: M_XGBoost
# 2024-01-10 10:46:05,986 - logger - INFO - Prediction type: regression
# 2024-01-10 10:46:05,988 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:46:05,988 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:46:05,989 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:46:05,990 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:46:05,991 - logger - INFO - Model storage: ../models/PXR_xgboost_regressor_pca50_expert.model
# 2024-01-10 10:46:05,992 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:46:05,992 - logger - INFO - FPs?: yes
# 2024-01-10 10:46:05,993 - logger - INFO - FP size?: 1024
# 2024-01-10 10:46:05,994 - logger - INFO - MDs?: yes
# 2024-01-10 10:46:05,995 - logger - INFO - Scaling?: no
# 2024-01-10 10:46:05,996 - logger - INFO - PCA?: yes
# ...

# %%
analyze_regressor(TRAINING_CONF_DIR/"PXR_mlp_regressor_pca50_expert.json")
# Out:
# 2024-01-10 10:46:20,811 - logger - INFO - Training configuration:
# 2024-01-10 10:46:20,812 - logger - INFO - Prediction methodology: M_MLP
# 2024-01-10 10:46:20,813 - logger - INFO - Prediction type: regression
# 2024-01-10 10:46:20,814 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:46:20,815 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:46:20,816 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:46:20,816 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:46:20,817 - logger - INFO - Model storage: ../models/PXR_mlp_regressor_pca50_expert.model
# 2024-01-10 10:46:20,817 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:46:20,819 - logger - INFO - FPs?: yes
# 2024-01-10 10:46:20,820 - logger - INFO - FP size?: 1024
# 2024-01-10 10:46:20,822 - logger - INFO - MDs?: yes
# 2024-01-10 10:46:20,823 - logger - INFO - Scaling?: no
# 2024-01-10 10:46:20,823 - logger - INFO - PCA?: yes
# ...

# %%
analyze_regressor(TRAINING_CONF_DIR/"PXR_rf_regressor_pca50_expert.json")
# Out:
# 2024-01-10 10:46:36,239 - logger - INFO - Training configuration:
# 2024-01-10 10:46:36,240 - logger - INFO - Prediction methodology: M_RandomForest
# 2024-01-10 10:46:36,241 - logger - INFO - Prediction type: regression
# 2024-01-10 10:46:36,242 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:46:36,243 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:46:36,243 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:46:36,244 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:46:36,245 - logger - INFO - Model storage: ../models/PXR_rf_regressor_pca50_expert.model
# 2024-01-10 10:46:36,246 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:46:36,247 - logger - INFO - FPs?: yes
# 2024-01-10 10:46:36,247 - logger - INFO - FP size?: 1024
# 2024-01-10 10:46:36,248 - logger - INFO - MDs?: yes
# 2024-01-10 10:46:36,249 - logger - INFO - Scaling?: no
# 2024-01-10 10:46:36,249 - logger - INFO - PCA?: yes
# ...

# %%
analyze_regressor(TRAINING_CONF_DIR/"PXR_svm_regressor_pca50_expert.json")
# Out:
# 2024-01-10 10:46:51,106 - logger - INFO - Training configuration:
# 2024-01-10 10:46:51,106 - logger - INFO - Prediction methodology: M_SVM
# 2024-01-10 10:46:51,108 - logger - INFO - Prediction type: regression
# 2024-01-10 10:46:51,109 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:46:51,109 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:46:51,111 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:46:51,111 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:46:51,113 - logger - INFO - Model storage: ../models/PXR_svm_regressor_pca50_expert.model
# 2024-01-10 10:46:51,114 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:46:51,114 - logger - INFO - FPs?: yes
# 2024-01-10 10:46:51,115 - logger - INFO - FP size?: 1024
# 2024-01-10 10:46:51,115 - logger - INFO - MDs?: yes
# 2024-01-10 10:46:51,116 - logger - INFO - Scaling?: no
# 2024-01-10 10:46:51,118 - logger - INFO - PCA?: yes
# ...

# %%
analyze_regressor(TRAINING_CONF_DIR/"PXR_bagging_regressor_pca50_expert.json")
# Out:
# 2024-01-10 10:47:05,854 - logger - INFO - Training configuration:
# 2024-01-10 10:47:05,855 - logger - INFO - Prediction methodology: M_Bagging
# 2024-01-10 10:47:05,856 - logger - INFO - Prediction type: regression
# 2024-01-10 10:47:05,857 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:47:05,858 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:47:05,859 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:47:05,859 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:47:05,860 - logger - INFO - Model storage: ../models/PXR_bagging_regressor_pca50_expert.model
# 2024-01-10 10:47:05,861 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:47:05,862 - logger - INFO - FPs?: yes
# 2024-01-10 10:47:05,863 - logger - INFO - FP size?: 1024
# 2024-01-10 10:47:05,864 - logger - INFO - MDs?: yes
# 2024-01-10 10:47:05,865 - logger - INFO - Scaling?: no
# 2024-01-10 10:47:05,866 - logger - INFO - PCA?: yes
# ...

# %%
analyze_regressor(TRAINING_CONF_DIR/"PXR_ridge_regressor_pca50_expert.json")
# Out:
# 2024-01-10 10:47:21,859 - logger - INFO - Training configuration:
# 2024-01-10 10:47:21,860 - logger - INFO - Prediction methodology: M_Ridge
# 2024-01-10 10:47:21,861 - logger - INFO - Prediction type: regression
# 2024-01-10 10:47:21,862 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:47:21,862 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:47:21,863 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:47:21,864 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:47:21,865 - logger - INFO - Model storage: ../models/PXR_ridge_regressor_pca50_expert.model
# 2024-01-10 10:47:21,866 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:47:21,866 - logger - INFO - FPs?: yes
# 2024-01-10 10:47:21,867 - logger - INFO - FP size?: 1024
# 2024-01-10 10:47:21,868 - logger - INFO - MDs?: yes
# 2024-01-10 10:47:21,868 - logger - INFO - Scaling?: no
# 2024-01-10 10:47:21,869 - logger - INFO - PCA?: yes
# ...

# %%
# CLA => RF, Bagging, Ridge!!!

# %%
analyze_classifier(TRAINING_CONF_DIR/"PXR_xgboost_classifier_pca50_expert.json")
# Out:
# 2024-01-10 10:47:36,489 - logger - INFO - Training configuration:
# 2024-01-10 10:47:36,491 - logger - INFO - Prediction methodology: M_XGBoost
# 2024-01-10 10:47:36,491 - logger - INFO - Prediction type: classification
# 2024-01-10 10:47:36,492 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:47:36,493 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:47:36,493 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:47:36,495 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:47:36,496 - logger - INFO - Model storage: ../models/PXR_xgboost_classifier_pca50_expert.model
# 2024-01-10 10:47:36,497 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:47:36,498 - logger - INFO - FPs?: yes
# 2024-01-10 10:47:36,499 - logger - INFO - FP size?: 1024
# 2024-01-10 10:47:36,499 - logger - INFO - MDs?: yes
# 2024-01-10 10:47:36,500 - logger - INFO - Scaling?: no
# 2024-01-10 10:47:36,501 - logger - INFO - PCA?: yes
# ...

# %%
analyze_classifier(TRAINING_CONF_DIR/"PXR_mlp_classifier_pca50_expert.json")
# Out:
# 2024-01-10 10:47:52,502 - logger - INFO - Training configuration:
# 2024-01-10 10:47:52,503 - logger - INFO - Prediction methodology: M_MLP
# 2024-01-10 10:47:52,504 - logger - INFO - Prediction type: classification
# 2024-01-10 10:47:52,505 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:47:52,506 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:47:52,507 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:47:52,507 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:47:52,509 - logger - INFO - Model storage: ../models/PXR_mlp_classifier_pca50_expert.model
# 2024-01-10 10:47:52,510 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:47:52,511 - logger - INFO - FPs?: yes
# 2024-01-10 10:47:52,512 - logger - INFO - FP size?: 1024
# 2024-01-10 10:47:52,513 - logger - INFO - MDs?: yes
# 2024-01-10 10:47:52,514 - logger - INFO - Scaling?: no
# 2024-01-10 10:47:52,516 - logger - INFO - PCA?: yes
# ...

# %%
analyze_classifier(TRAINING_CONF_DIR/"PXR_rf_classifier_pca50_expert.json")
# Out:
# 2024-01-10 10:48:08,687 - logger - INFO - Training configuration:
# 2024-01-10 10:48:08,687 - logger - INFO - Prediction methodology: M_RandomForest
# 2024-01-10 10:48:08,689 - logger - INFO - Prediction type: classification
# 2024-01-10 10:48:08,690 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:48:08,690 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:48:08,692 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:48:08,693 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:48:08,693 - logger - INFO - Model storage: ../models/PXR_rf_classifier_pca50_expert.model
# 2024-01-10 10:48:08,693 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:48:08,693 - logger - INFO - FPs?: yes
# 2024-01-10 10:48:08,693 - logger - INFO - FP size?: 1024
# 2024-01-10 10:48:08,698 - logger - INFO - MDs?: yes
# 2024-01-10 10:48:08,699 - logger - INFO - Scaling?: no
# 2024-01-10 10:48:08,700 - logger - INFO - PCA?: yes
# ...

# %%
analyze_classifier(TRAINING_CONF_DIR/"PXR_svm_classifier_pca50_expert.json")
# Out:
# 2024-01-10 10:48:24,542 - logger - INFO - Training configuration:
# 2024-01-10 10:48:24,544 - logger - INFO - Prediction methodology: M_SVM
# 2024-01-10 10:48:24,545 - logger - INFO - Prediction type: classification
# 2024-01-10 10:48:24,545 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:48:24,546 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:48:24,547 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:48:24,547 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:48:24,548 - logger - INFO - Model storage: ../models/PXR_svm_classifier_pca50_expert.model
# 2024-01-10 10:48:24,549 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:48:24,549 - logger - INFO - FPs?: yes
# 2024-01-10 10:48:24,550 - logger - INFO - FP size?: 1024
# 2024-01-10 10:48:24,551 - logger - INFO - MDs?: yes
# 2024-01-10 10:48:24,552 - logger - INFO - Scaling?: no
# 2024-01-10 10:48:24,553 - logger - INFO - PCA?: yes
# ...

# %%
analyze_classifier(TRAINING_CONF_DIR/"PXR_bagging_classifier_pca50_expert.json")
# Out:
# 2024-01-10 10:48:40,736 - logger - INFO - Training configuration:
# 2024-01-10 10:48:40,738 - logger - INFO - Prediction methodology: M_Bagging
# 2024-01-10 10:48:40,739 - logger - INFO - Prediction type: classification
# 2024-01-10 10:48:40,739 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:48:40,740 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:48:40,741 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:48:40,742 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:48:40,743 - logger - INFO - Model storage: ../models/PXR_bagging_classifer_pca50_expert.model
# 2024-01-10 10:48:40,744 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:48:40,745 - logger - INFO - FPs?: yes
# 2024-01-10 10:48:40,746 - logger - INFO - FP size?: 1024
# 2024-01-10 10:48:40,747 - logger - INFO - MDs?: yes
# 2024-01-10 10:48:40,749 - logger - INFO - Scaling?: no
# 2024-01-10 10:48:40,749 - logger - INFO - PCA?: yes
# ...

# %%
analyze_classifier(TRAINING_CONF_DIR/"PXR_ridge_classifier_pca50_expert.json")
# Out:
# 2024-01-10 10:48:57,772 - logger - INFO - Training configuration:
# 2024-01-10 10:48:57,773 - logger - INFO - Prediction methodology: M_Ridge
# 2024-01-10 10:48:57,774 - logger - INFO - Prediction type: classification
# 2024-01-10 10:48:57,774 - logger - INFO - Data file: ../data/PXR_training_data.csv
# 2024-01-10 10:48:57,775 - logger - INFO - Max. activity level: 1
# 2024-01-10 10:48:57,776 - logger - INFO - Std. threshold: 100
# 2024-01-10 10:48:57,776 - logger - INFO - Data preparation strategy: median
# 2024-01-10 10:48:57,777 - logger - INFO - Model storage: ../models/PXR_ridge_classifier_pca50_expert.model
# 2024-01-10 10:48:57,777 - logger - INFO - Pipeline configuration:
# 2024-01-10 10:48:57,778 - logger - INFO - FPs?: yes
# 2024-01-10 10:48:57,778 - logger - INFO - FP size?: 1024
# 2024-01-10 10:48:57,780 - logger - INFO - MDs?: yes
# 2024-01-10 10:48:57,781 - logger - INFO - Scaling?: no
# 2024-01-10 10:48:57,781 - logger - INFO - PCA?: yes
# ...
