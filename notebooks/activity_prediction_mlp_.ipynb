# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor
from auxiliary import loggers

from pathlib import Path
import sys

import pandas as pd
import numpy as np
import os

import pickle
import json

# %matplotlib inline
import seaborn as sns

pd.set_option('display.max_columns', None)
random_seed = 42

# %config Completer.use_jedi = False

l = loggers.get_logger(logger_name="logger")

METHOD_PREFIX = "mlp"

# %%
l.info(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2022-07-28 18:09:31,438 - logger - INFO - rorgammaqsar

# %% [markdown]
# # QED

# %% [markdown]
# ## Classifier

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_QED.json"))
# Out:
# 2022-07-28 18:09:31,701 - logger - INFO - Training configuration:
# 2022-07-28 18:09:31,701 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:09:31,702 - logger - INFO - Prediction type: classification
# 2022-07-28 18:09:31,702 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:09:31,703 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:09:31,703 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:09:31,704 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:09:31,704 - logger - INFO - Model storage: model_mlp_clasifier_QED.model
# 2022-07-28 18:09:31,705 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:09:31,706 - logger - INFO - FPs?: no
# 2022-07-28 18:09:31,707 - logger - INFO - MDs?: yes
# 2022-07-28 18:09:31,707 - logger - INFO - Scaling?: yes
# 2022-07-28 18:09:31,708 - logger - INFO - PCA?: no
# 2022-07-28 18:09:31,709 - logger - INFO - Target transform?: no
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_QED.json"))
# Out:
# 2022-07-28 18:09:58,071 - logger - INFO - Training configuration:
# 2022-07-28 18:09:58,072 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:09:58,072 - logger - INFO - Prediction type: classification
# 2022-07-28 18:09:58,073 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:09:58,073 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:09:58,074 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:09:58,074 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:09:58,075 - logger - INFO - Model storage: model_mlp_clasifier_QED_mean_100.model
# 2022-07-28 18:09:58,075 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:09:58,075 - logger - INFO - FPs?: no
# 2022-07-28 18:09:58,076 - logger - INFO - MDs?: yes
# 2022-07-28 18:09:58,076 - logger - INFO - Scaling?: yes
# 2022-07-28 18:09:58,077 - logger - INFO - PCA?: no
# 2022-07-28 18:09:58,077 - logger - INFO - Target transform?: no
# ...

# %% [markdown]
# ### Mean, no limit

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_QED.json"))
# Out:
# 2022-07-28 18:10:22,742 - logger - INFO - Training configuration:
# 2022-07-28 18:10:22,743 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:10:22,743 - logger - INFO - Prediction type: classification
# 2022-07-28 18:10:22,744 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:10:22,744 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:10:22,744 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:10:22,745 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:10:22,745 - logger - INFO - Model storage: model_mlp_clasifier_QED_mean_no_limit.model
# 2022-07-28 18:10:22,745 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:10:22,746 - logger - INFO - FPs?: no
# 2022-07-28 18:10:22,746 - logger - INFO - MDs?: yes
# 2022-07-28 18:10:22,747 - logger - INFO - Scaling?: yes
# 2022-07-28 18:10:22,747 - logger - INFO - PCA?: no
# 2022-07-28 18:10:22,748 - logger - INFO - Target transform?: no
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_QED.json"))
# Out:
# 2022-07-28 18:10:49,800 - logger - INFO - Training configuration:
# 2022-07-28 18:10:49,801 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:10:49,801 - logger - INFO - Prediction type: regression
# 2022-07-28 18:10:49,802 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:10:49,802 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:10:49,803 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:10:49,803 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:10:49,804 - logger - INFO - Model storage: model_mlp_regressor_QED.model
# 2022-07-28 18:10:49,804 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:10:49,804 - logger - INFO - FPs?: no
# 2022-07-28 18:10:49,805 - logger - INFO - MDs?: yes
# 2022-07-28 18:10:49,805 - logger - INFO - Scaling?: yes
# 2022-07-28 18:10:49,806 - logger - INFO - PCA?: no
# 2022-07-28 18:10:49,806 - logger - INFO - Target transform?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_QED.json"))
# Out:
# 2022-07-28 18:11:20,011 - logger - INFO - Training configuration:
# 2022-07-28 18:11:20,012 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:11:20,012 - logger - INFO - Prediction type: regression
# 2022-07-28 18:11:20,013 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:11:20,014 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:11:20,014 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:11:20,015 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:11:20,015 - logger - INFO - Model storage: model_mlp_regressor_QED_mean_100.model
# 2022-07-28 18:11:20,016 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:11:20,016 - logger - INFO - FPs?: no
# 2022-07-28 18:11:20,017 - logger - INFO - MDs?: yes
# 2022-07-28 18:11:20,017 - logger - INFO - Scaling?: yes
# 2022-07-28 18:11:20,018 - logger - INFO - PCA?: no
# 2022-07-28 18:11:20,019 - logger - INFO - Target transform?: yes
# ...

# %% [markdown]
# ### Mean, no limit

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_QED.json"))
# Out:
# 2022-07-28 18:11:47,858 - logger - INFO - Training configuration:
# 2022-07-28 18:11:47,858 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:11:47,859 - logger - INFO - Prediction type: regression
# 2022-07-28 18:11:47,859 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:11:47,860 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:11:47,860 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:11:47,861 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:11:47,861 - logger - INFO - Model storage: model_mlp_regressor_QED_mean_no_limit.model
# 2022-07-28 18:11:47,862 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:11:47,862 - logger - INFO - FPs?: no
# 2022-07-28 18:11:47,863 - logger - INFO - MDs?: yes
# 2022-07-28 18:11:47,863 - logger - INFO - Scaling?: yes
# 2022-07-28 18:11:47,864 - logger - INFO - PCA?: no
# 2022-07-28 18:11:47,864 - logger - INFO - Target transform?: yes
# ...

# %% [markdown]
# # Morgan 1024

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"))
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024.json"))
# Out:
# 2022-07-28 17:40:19,239 - logger - INFO - Training configuration:
# 2022-07-28 17:40:19,240 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-07-28 17:40:19,240 - logger - INFO - Prediction type: classification
# 2022-07-28 17:40:19,241 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 17:40:19,241 - logger - INFO - Max. activity level: 15
# 2022-07-28 17:40:19,242 - logger - INFO - Std. threshold: 100
# 2022-07-28 17:40:19,242 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 17:40:19,243 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_mean_100.model
# 2022-07-28 17:40:19,244 - logger - INFO - Pipeline configuration:
# 2022-07-28 17:40:19,244 - logger - INFO - FPs?: yes
# 2022-07-28 17:40:19,245 - logger - INFO - FP size?: 1024
# 2022-07-28 17:40:19,245 - logger - INFO - MDs?: no
# 2022-07-28 17:40:19,246 - logger - INFO - Scaling?: no
# 2022-07-28 17:40:19,246 - logger - INFO - PCA?: no
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024.json"))
# Out:
# 2022-07-28 17:40:31,133 - logger - INFO - Training configuration:
# 2022-07-28 17:40:31,133 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-07-28 17:40:31,134 - logger - INFO - Prediction type: classification
# 2022-07-28 17:40:31,134 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 17:40:31,135 - logger - INFO - Max. activity level: 15
# 2022-07-28 17:40:31,136 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 17:40:31,136 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 17:40:31,137 - logger - INFO - Model storage: model_xgboost_classifier_Morgan_1024_mean_no_limits.model
# 2022-07-28 17:40:31,137 - logger - INFO - Pipeline configuration:
# 2022-07-28 17:40:31,138 - logger - INFO - FPs?: yes
# 2022-07-28 17:40:31,139 - logger - INFO - FP size?: 1024
# 2022-07-28 17:40:31,139 - logger - INFO - MDs?: no
# 2022-07-28 17:40:31,140 - logger - INFO - Scaling?: no
# 2022-07-28 17:40:31,140 - logger - INFO - PCA?: no
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"))
# Out:
# 2022-07-28 17:41:07,935 - logger - INFO - Training configuration:
# 2022-07-28 17:41:07,936 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-07-28 17:41:07,937 - logger - INFO - Prediction type: regression
# 2022-07-28 17:41:07,937 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 17:41:07,938 - logger - INFO - Max. activity level: 15
# 2022-07-28 17:41:07,938 - logger - INFO - Std. threshold: 100
# 2022-07-28 17:41:07,939 - logger - INFO - Data preparation strategy: median
# 2022-07-28 17:41:07,939 - logger - INFO - Model storage: model_xgboost_regressor_Morgan_1024.model
# 2022-07-28 17:41:07,940 - logger - INFO - Pipeline configuration:
# 2022-07-28 17:41:07,940 - logger - INFO - FPs?: yes
# 2022-07-28 17:41:07,940 - logger - INFO - FP size?: 1024
# 2022-07-28 17:41:07,941 - logger - INFO - MDs?: no
# 2022-07-28 17:41:07,941 - logger - INFO - Scaling?: no
# 2022-07-28 17:41:07,942 - logger - INFO - PCA?: no
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024.json"))
# Out:
# 2022-07-28 17:41:18,740 - logger - INFO - Training configuration:
# 2022-07-28 17:41:18,740 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-07-28 17:41:18,741 - logger - INFO - Prediction type: regression
# 2022-07-28 17:41:18,742 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 17:41:18,742 - logger - INFO - Max. activity level: 15
# 2022-07-28 17:41:18,743 - logger - INFO - Std. threshold: 100
# 2022-07-28 17:41:18,743 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 17:41:18,744 - logger - INFO - Model storage: model_xgboost_regressor_Morgan_1024_mean_100.model
# 2022-07-28 17:41:18,745 - logger - INFO - Pipeline configuration:
# 2022-07-28 17:41:18,745 - logger - INFO - FPs?: yes
# 2022-07-28 17:41:18,745 - logger - INFO - FP size?: 1024
# 2022-07-28 17:41:18,746 - logger - INFO - MDs?: no
# 2022-07-28 17:41:18,747 - logger - INFO - Scaling?: no
# 2022-07-28 17:41:18,747 - logger - INFO - PCA?: no
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024.json"))
# Out:
# 2022-07-28 17:41:24,910 - logger - INFO - Training configuration:
# 2022-07-28 17:41:24,910 - logger - INFO - Prediction methodology: M_XGBoost
# 2022-07-28 17:41:24,911 - logger - INFO - Prediction type: regression
# 2022-07-28 17:41:24,912 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 17:41:24,912 - logger - INFO - Max. activity level: 15
# 2022-07-28 17:41:24,913 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 17:41:24,913 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 17:41:24,914 - logger - INFO - Model storage: model_xgboost_regressor_Morgan_1024_mean_no_limits.model
# 2022-07-28 17:41:24,914 - logger - INFO - Pipeline configuration:
# 2022-07-28 17:41:24,914 - logger - INFO - FPs?: yes
# 2022-07-28 17:41:24,915 - logger - INFO - FP size?: 1024
# 2022-07-28 17:41:24,915 - logger - INFO - MDs?: no
# 2022-07-28 17:41:24,916 - logger - INFO - Scaling?: no
# 2022-07-28 17:41:24,916 - logger - INFO - PCA?: no
# ...

# %% [markdown]
# # Morgan 1024, PCA 128, QED

# %% [markdown]
# ## CLassification

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"))
# Out:
# 2022-07-29 06:24:27,264 - logger - INFO - Training configuration:
# 2022-07-29 06:24:27,265 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-29 06:24:27,266 - logger - INFO - Prediction type: classification
# 2022-07-29 06:24:27,266 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-29 06:24:27,267 - logger - INFO - Max. activity level: 15
# 2022-07-29 06:24:27,267 - logger - INFO - Std. threshold: 100
# 2022-07-29 06:24:27,269 - logger - INFO - Data preparation strategy: median
# 2022-07-29 06:24:27,269 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_128_QED.model
# 2022-07-29 06:24:27,270 - logger - INFO - Pipeline configuration:
# 2022-07-29 06:24:27,270 - logger - INFO - FPs?: yes
# 2022-07-29 06:24:27,270 - logger - INFO - FP size?: 1024
# 2022-07-29 06:24:27,271 - logger - INFO - MDs?: yes
# 2022-07-29 06:24:27,271 - logger - INFO - Scaling?: yes
# 2022-07-29 06:24:27,271 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"))
# Out:
# 2022-07-28 18:13:31,471 - logger - INFO - Training configuration:
# 2022-07-28 18:13:31,471 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:13:31,472 - logger - INFO - Prediction type: classification
# 2022-07-28 18:13:31,473 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:13:31,473 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:13:31,474 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:13:31,474 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:13:31,476 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_128_QED_mean_100.model
# 2022-07-28 18:13:31,476 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:13:31,476 - logger - INFO - FPs?: yes
# 2022-07-28 18:13:31,477 - logger - INFO - FP size?: 1024
# 2022-07-28 18:13:31,477 - logger - INFO - MDs?: yes
# 2022-07-28 18:13:31,478 - logger - INFO - Scaling?: yes
# 2022-07-28 18:13:31,478 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_128_QED.json"))
# Out:
# 2022-07-28 18:14:04,060 - logger - INFO - Training configuration:
# 2022-07-28 18:14:04,061 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:14:04,061 - logger - INFO - Prediction type: classification
# 2022-07-28 18:14:04,062 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:14:04,063 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:14:04,063 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:14:04,064 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:14:04,065 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_128_QED_mean_no_limit.model
# 2022-07-28 18:14:04,065 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:14:04,066 - logger - INFO - FPs?: yes
# 2022-07-28 18:14:04,066 - logger - INFO - FP size?: 1024
# 2022-07-28 18:14:04,067 - logger - INFO - MDs?: yes
# 2022-07-28 18:14:04,068 - logger - INFO - Scaling?: yes
# 2022-07-28 18:14:04,068 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"))
# Out:
# 2022-07-28 18:14:39,339 - logger - INFO - Training configuration:
# 2022-07-28 18:14:39,340 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:14:39,341 - logger - INFO - Prediction type: regression
# 2022-07-28 18:14:39,342 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:14:39,342 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:14:39,343 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:14:39,344 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:14:39,344 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_128_QED.model
# 2022-07-28 18:14:39,345 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:14:39,346 - logger - INFO - FPs?: yes
# 2022-07-28 18:14:39,346 - logger - INFO - FP size?: 1024
# 2022-07-28 18:14:39,347 - logger - INFO - MDs?: yes
# 2022-07-28 18:14:39,347 - logger - INFO - Scaling?: yes
# 2022-07-28 18:14:39,348 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"))
# Out:
# 2022-07-28 18:15:11,560 - logger - INFO - Training configuration:
# 2022-07-28 18:15:11,560 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:15:11,561 - logger - INFO - Prediction type: regression
# 2022-07-28 18:15:11,561 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:15:11,562 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:15:11,562 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:15:11,563 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:15:11,563 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_128_QED_mean_100.model
# 2022-07-28 18:15:11,564 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:15:11,564 - logger - INFO - FPs?: yes
# 2022-07-28 18:15:11,565 - logger - INFO - FP size?: 1024
# 2022-07-28 18:15:11,565 - logger - INFO - MDs?: yes
# 2022-07-28 18:15:11,565 - logger - INFO - Scaling?: yes
# 2022-07-28 18:15:11,566 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_128_QED.json"))
# Out:
# 2022-07-28 18:15:46,551 - logger - INFO - Training configuration:
# 2022-07-28 18:15:46,551 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:15:46,552 - logger - INFO - Prediction type: regression
# 2022-07-28 18:15:46,553 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:15:46,553 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:15:46,554 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:15:46,554 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:15:46,554 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_128_QED_mean_no_limit.model
# 2022-07-28 18:15:46,555 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:15:46,555 - logger - INFO - FPs?: yes
# 2022-07-28 18:15:46,556 - logger - INFO - FP size?: 1024
# 2022-07-28 18:15:46,556 - logger - INFO - MDs?: yes
# 2022-07-28 18:15:46,557 - logger - INFO - Scaling?: yes
# 2022-07-28 18:15:46,557 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# # Morgan 1024, PCA 256, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"))
# Out:
# 2022-07-28 18:19:07,213 - logger - INFO - Training configuration:
# 2022-07-28 18:19:07,213 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:19:07,214 - logger - INFO - Prediction type: classification
# 2022-07-28 18:19:07,215 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:19:07,215 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:19:07,216 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:19:07,216 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:19:07,217 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_256_QED.model
# 2022-07-28 18:19:07,217 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:19:07,218 - logger - INFO - FPs?: yes
# 2022-07-28 18:19:07,218 - logger - INFO - FP size?: 1024
# 2022-07-28 18:19:07,219 - logger - INFO - MDs?: yes
# 2022-07-28 18:19:07,219 - logger - INFO - Scaling?: yes
# 2022-07-28 18:19:07,220 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"))
# Out:
# 2022-07-28 18:19:39,793 - logger - INFO - Training configuration:
# 2022-07-28 18:19:39,793 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:19:39,794 - logger - INFO - Prediction type: classification
# 2022-07-28 18:19:39,794 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:19:39,795 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:19:39,795 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:19:39,796 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:19:39,796 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_256_QED_mean_100.model
# 2022-07-28 18:19:39,797 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:19:39,797 - logger - INFO - FPs?: yes
# 2022-07-28 18:19:39,798 - logger - INFO - FP size?: 1024
# 2022-07-28 18:19:39,798 - logger - INFO - MDs?: yes
# 2022-07-28 18:19:39,799 - logger - INFO - Scaling?: yes
# 2022-07-28 18:19:39,799 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_256_QED.json"))
# Out:
# 2022-07-28 18:20:14,572 - logger - INFO - Training configuration:
# 2022-07-28 18:20:14,573 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:20:14,573 - logger - INFO - Prediction type: classification
# 2022-07-28 18:20:14,574 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:20:14,574 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:20:14,575 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:20:14,575 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:20:14,576 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_256_QED_no_limit.model
# 2022-07-28 18:20:14,576 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:20:14,577 - logger - INFO - FPs?: yes
# 2022-07-28 18:20:14,577 - logger - INFO - FP size?: 1024
# 2022-07-28 18:20:14,578 - logger - INFO - MDs?: yes
# 2022-07-28 18:20:14,578 - logger - INFO - Scaling?: yes
# 2022-07-28 18:20:14,578 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"))
# Out:
# 2022-07-28 18:22:11,486 - logger - INFO - Training configuration:
# 2022-07-28 18:22:11,486 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:22:11,487 - logger - INFO - Prediction type: regression
# 2022-07-28 18:22:11,488 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:22:11,489 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:22:11,489 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:22:11,490 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:22:11,490 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_256_QED.model
# 2022-07-28 18:22:11,491 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:22:11,491 - logger - INFO - FPs?: yes
# 2022-07-28 18:22:11,491 - logger - INFO - FP size?: 1024
# 2022-07-28 18:22:11,492 - logger - INFO - MDs?: yes
# 2022-07-28 18:22:11,492 - logger - INFO - Scaling?: yes
# 2022-07-28 18:22:11,493 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"))
# Out:
# 2022-07-28 18:22:43,856 - logger - INFO - Training configuration:
# 2022-07-28 18:22:43,857 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:22:43,857 - logger - INFO - Prediction type: regression
# 2022-07-28 18:22:43,858 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:22:43,858 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:22:43,859 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:22:43,859 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:22:43,860 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_256_QED_mean_100.model
# 2022-07-28 18:22:43,860 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:22:43,861 - logger - INFO - FPs?: yes
# 2022-07-28 18:22:43,861 - logger - INFO - FP size?: 1024
# 2022-07-28 18:22:43,862 - logger - INFO - MDs?: yes
# 2022-07-28 18:22:43,862 - logger - INFO - Scaling?: yes
# 2022-07-28 18:22:43,863 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_256_QED.json"))
# Out:
# 2022-07-28 18:23:17,166 - logger - INFO - Training configuration:
# 2022-07-28 18:23:17,166 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:23:17,167 - logger - INFO - Prediction type: regression
# 2022-07-28 18:23:17,167 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:23:17,168 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:23:17,168 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:23:17,169 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:23:17,170 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_256_QED_mean_no_limit.model
# 2022-07-28 18:23:17,170 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:23:17,171 - logger - INFO - FPs?: yes
# 2022-07-28 18:23:17,171 - logger - INFO - FP size?: 1024
# 2022-07-28 18:23:17,172 - logger - INFO - MDs?: yes
# 2022-07-28 18:23:17,172 - logger - INFO - Scaling?: yes
# 2022-07-28 18:23:17,172 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# # Morgan 1024, PCA 512, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"))
# Out:
# 2022-07-29 06:26:08,970 - logger - INFO - Training configuration:
# 2022-07-29 06:26:08,971 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-29 06:26:08,972 - logger - INFO - Prediction type: classification
# 2022-07-29 06:26:08,972 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-29 06:26:08,973 - logger - INFO - Max. activity level: 15
# 2022-07-29 06:26:08,973 - logger - INFO - Std. threshold: 100
# 2022-07-29 06:26:08,974 - logger - INFO - Data preparation strategy: median
# 2022-07-29 06:26:08,974 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_512_QED.model
# 2022-07-29 06:26:08,975 - logger - INFO - Pipeline configuration:
# 2022-07-29 06:26:08,975 - logger - INFO - FPs?: yes
# 2022-07-29 06:26:08,976 - logger - INFO - FP size?: 1024
# 2022-07-29 06:26:08,976 - logger - INFO - MDs?: yes
# 2022-07-29 06:26:08,976 - logger - INFO - Scaling?: yes
# 2022-07-29 06:26:08,977 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"))
# Out:
# 2022-07-28 18:28:15,198 - logger - INFO - Training configuration:
# 2022-07-28 18:28:15,198 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:28:15,199 - logger - INFO - Prediction type: classification
# 2022-07-28 18:28:15,200 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:28:15,200 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:28:15,201 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:28:15,201 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:28:15,202 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_512_QED_mean_100.model
# 2022-07-28 18:28:15,202 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:28:15,203 - logger - INFO - FPs?: yes
# 2022-07-28 18:28:15,203 - logger - INFO - FP size?: 1024
# 2022-07-28 18:28:15,204 - logger - INFO - MDs?: yes
# 2022-07-28 18:28:15,204 - logger - INFO - Scaling?: yes
# 2022-07-28 18:28:15,205 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_512_QED.json"))
# Out:
# 2022-07-28 18:28:52,048 - logger - INFO - Training configuration:
# 2022-07-28 18:28:52,049 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:28:52,049 - logger - INFO - Prediction type: classification
# 2022-07-28 18:28:52,050 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:28:52,051 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:28:52,052 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:28:52,052 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:28:52,053 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_512_QED_no_limit.model
# 2022-07-28 18:28:52,053 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:28:52,054 - logger - INFO - FPs?: yes
# 2022-07-28 18:28:52,054 - logger - INFO - FP size?: 1024
# 2022-07-28 18:28:52,054 - logger - INFO - MDs?: yes
# 2022-07-28 18:28:52,055 - logger - INFO - Scaling?: yes
# 2022-07-28 18:28:52,055 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"))
# Out:
# 2022-07-29 06:27:47,686 - logger - INFO - Training configuration:
# 2022-07-29 06:27:47,687 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-29 06:27:47,687 - logger - INFO - Prediction type: regression
# 2022-07-29 06:27:47,688 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-29 06:27:47,688 - logger - INFO - Max. activity level: 15
# 2022-07-29 06:27:47,689 - logger - INFO - Std. threshold: 100
# 2022-07-29 06:27:47,689 - logger - INFO - Data preparation strategy: median
# 2022-07-29 06:27:47,689 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_512_QED.model
# 2022-07-29 06:27:47,690 - logger - INFO - Pipeline configuration:
# 2022-07-29 06:27:47,690 - logger - INFO - FPs?: yes
# 2022-07-29 06:27:47,691 - logger - INFO - FP size?: 1024
# 2022-07-29 06:27:47,691 - logger - INFO - MDs?: yes
# 2022-07-29 06:27:47,692 - logger - INFO - Scaling?: yes
# 2022-07-29 06:27:47,692 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"))
# Out:
# 2022-07-28 18:29:43,880 - logger - INFO - Training configuration:
# 2022-07-28 18:29:43,880 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:29:43,881 - logger - INFO - Prediction type: regression
# 2022-07-28 18:29:43,881 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:29:43,882 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:29:43,883 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:29:43,883 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:29:43,884 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_512_QED_mean_100.model
# 2022-07-28 18:29:43,884 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:29:43,885 - logger - INFO - FPs?: yes
# 2022-07-28 18:29:43,885 - logger - INFO - FP size?: 1024
# 2022-07-28 18:29:43,886 - logger - INFO - MDs?: yes
# 2022-07-28 18:29:43,886 - logger - INFO - Scaling?: yes
# 2022-07-28 18:29:43,887 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_512_QED.json"))
# Out:
# 2022-07-28 18:30:45,977 - logger - INFO - Training configuration:
# 2022-07-28 18:30:45,978 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:30:45,978 - logger - INFO - Prediction type: regression
# 2022-07-28 18:30:45,979 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:30:45,979 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:30:45,980 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:30:45,980 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:30:45,982 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_512_QED_mean_no_limit.model
# 2022-07-28 18:30:45,982 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:30:45,983 - logger - INFO - FPs?: yes
# 2022-07-28 18:30:45,984 - logger - INFO - FP size?: 1024
# 2022-07-28 18:30:45,984 - logger - INFO - MDs?: yes
# 2022-07-28 18:30:45,985 - logger - INFO - Scaling?: yes
# 2022-07-28 18:30:45,985 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# # Morgan 1024, PCA 1024, QED

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"))
# Out:
# 2022-07-28 18:31:24,678 - logger - INFO - Training configuration:
# 2022-07-28 18:31:24,678 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:31:24,679 - logger - INFO - Prediction type: classification
# 2022-07-28 18:31:24,680 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:31:24,680 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:31:24,681 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:31:24,681 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:31:24,682 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_1024_QED.model
# 2022-07-28 18:31:24,682 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:31:24,683 - logger - INFO - FPs?: yes
# 2022-07-28 18:31:24,683 - logger - INFO - FP size?: 1024
# 2022-07-28 18:31:24,684 - logger - INFO - MDs?: yes
# 2022-07-28 18:31:24,684 - logger - INFO - Scaling?: yes
# 2022-07-28 18:31:24,685 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"))
# Out:
# 2022-07-28 18:31:57,380 - logger - INFO - Training configuration:
# 2022-07-28 18:31:57,381 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:31:57,381 - logger - INFO - Prediction type: classification
# 2022-07-28 18:31:57,382 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:31:57,382 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:31:57,383 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:31:57,383 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:31:57,384 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_1024_QED_mean_100.model
# 2022-07-28 18:31:57,384 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:31:57,385 - logger - INFO - FPs?: yes
# 2022-07-28 18:31:57,385 - logger - INFO - FP size?: 1024
# 2022-07-28 18:31:57,386 - logger - INFO - MDs?: yes
# 2022-07-28 18:31:57,386 - logger - INFO - Scaling?: yes
# 2022-07-28 18:31:57,387 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_classifier(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_classification_Morgan_1024_pca_1024_QED.json"))
# Out:
# 2022-07-28 18:32:39,194 - logger - INFO - Training configuration:
# 2022-07-28 18:32:39,194 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:32:39,195 - logger - INFO - Prediction type: classification
# 2022-07-28 18:32:39,195 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:32:39,196 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:32:39,196 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:32:39,197 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:32:39,197 - logger - INFO - Model storage: model_mlp_clasifier_Morgan_1024_pca_1024_QED_mean_no_limit.model
# 2022-07-28 18:32:39,197 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:32:39,198 - logger - INFO - FPs?: yes
# 2022-07-28 18:32:39,198 - logger - INFO - FP size?: 1024
# 2022-07-28 18:32:39,199 - logger - INFO - MDs?: yes
# 2022-07-28 18:32:39,199 - logger - INFO - Scaling?: yes
# 2022-07-28 18:32:39,199 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ## Regression

# %% [markdown]
# ### Median, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"median_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"))
# Out:
# 2022-07-28 18:33:23,247 - logger - INFO - Training configuration:
# 2022-07-28 18:33:23,248 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:33:23,249 - logger - INFO - Prediction type: regression
# 2022-07-28 18:33:23,249 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:33:23,250 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:33:23,251 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:33:23,251 - logger - INFO - Data preparation strategy: median
# 2022-07-28 18:33:23,251 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_1024_QED.model
# 2022-07-28 18:33:23,252 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:33:23,252 - logger - INFO - FPs?: yes
# 2022-07-28 18:33:23,253 - logger - INFO - FP size?: 1024
# 2022-07-28 18:33:23,253 - logger - INFO - MDs?: yes
# 2022-07-28 18:33:23,254 - logger - INFO - Scaling?: yes
# 2022-07-28 18:33:23,254 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, 100 nM

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_100"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"))
# Out:
# 2022-07-28 18:33:56,595 - logger - INFO - Training configuration:
# 2022-07-28 18:33:56,596 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:33:56,596 - logger - INFO - Prediction type: regression
# 2022-07-28 18:33:56,597 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:33:56,598 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:33:56,598 - logger - INFO - Std. threshold: 100
# 2022-07-28 18:33:56,599 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:33:56,599 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_1024_QED_mean_100.model
# 2022-07-28 18:33:56,600 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:33:56,600 - logger - INFO - FPs?: yes
# 2022-07-28 18:33:56,600 - logger - INFO - FP size?: 1024
# 2022-07-28 18:33:56,601 - logger - INFO - MDs?: yes
# 2022-07-28 18:33:56,602 - logger - INFO - Scaling?: yes
# 2022-07-28 18:33:56,602 - logger - INFO - PCA?: yes
# ...

# %% [markdown]
# ### Mean, no limits

# %%
analyze_regressor(co.TRAINING_CONF_DIR/"mean_no_limits"/(METHOD_PREFIX+"_regression_Morgan_1024_pca_1024_QED.json"))
# Out:
# 2022-07-28 18:34:32,176 - logger - INFO - Training configuration:
# 2022-07-28 18:34:32,177 - logger - INFO - Prediction methodology: M_MLP
# 2022-07-28 18:34:32,177 - logger - INFO - Prediction type: regression
# 2022-07-28 18:34:32,178 - logger - INFO - Data file: ror_gamma_homo_sapiens_chembl_3.0_IC50.csv
# 2022-07-28 18:34:32,179 - logger - INFO - Max. activity level: 15
# 2022-07-28 18:34:32,179 - logger - INFO - Std. threshold: 1000000
# 2022-07-28 18:34:32,179 - logger - INFO - Data preparation strategy: mean
# 2022-07-28 18:34:32,180 - logger - INFO - Model storage: model_mlp_regressor_Morgan_1024_pca_1024_QED_mean_no_limit.model
# 2022-07-28 18:34:32,180 - logger - INFO - Pipeline configuration:
# 2022-07-28 18:34:32,181 - logger - INFO - FPs?: yes
# 2022-07-28 18:34:32,181 - logger - INFO - FP size?: 1024
# 2022-07-28 18:34:32,182 - logger - INFO - MDs?: yes
# 2022-07-28 18:34:32,183 - logger - INFO - Scaling?: yes
# 2022-07-28 18:34:32,183 - logger - INFO - PCA?: yes
# ...
