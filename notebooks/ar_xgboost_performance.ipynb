# %%
import constants as co
from analyzers import analyze_classifier, analyze_regressor, get_predictions_regressor, get_predictions_classifier, \
    get_model_predictions, get_model_ext_predictions

from pathlib import Path

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from rdkit import Chem
from rdkit.Chem import Draw

pd.set_option('display.max_columns', None)
random_seed = 42

TRAINING_CONF_DIR = Path("../training_configurations")

# %% [markdown]
# # XGBoost model of androgene receptor, performance analysis of trained models

# %% [markdown]
# ## Analyze regressor
# * read in the model (the training configuration json file provides all necessary information)
# * refresh the transformation pipelines
# * calculate the training/validation molecular features as defined in the configuration
# * carry out the prediction on training/validation data sets

# %%
analyze_regressor(TRAINING_CONF_DIR/"ar_xgboost_regressor_pca50_expert.json")
# Out:
# 2023-08-02 20:49:36,024 - logger - INFO - Training configuration:
# 2023-08-02 20:49:36,025 - logger - INFO - Prediction methodology: M_XGBoost
# 2023-08-02 20:49:36,026 - logger - INFO - Prediction type: regression
# 2023-08-02 20:49:36,026 - logger - INFO - Data file: C:/Users/rbachorz/Projects/qsarmodeler/qsarmodeler/data/processed/ar_homo_sapiens_chembl_3.3_more_ChEMBL_columnsIC50EC50_combined_expert.csv
# 2023-08-02 20:49:36,027 - logger - INFO - Max. activity level: 1
# 2023-08-02 20:49:36,027 - logger - INFO - Std. threshold: 100
# 2023-08-02 20:49:36,028 - logger - INFO - Data preparation strategy: median
# 2023-08-02 20:49:36,028 - logger - INFO - Model storage: C:/Users/rbachorz/Projects/qsarmodeler/qsarmodeler/models/ar_xgboost_regressor_pca50_expert.model
# 2023-08-02 20:49:36,029 - logger - INFO - Pipeline configuration:
# 2023-08-02 20:49:36,029 - logger - INFO - FPs?: yes
# 2023-08-02 20:49:36,030 - logger - INFO - FP size?: 1024
# 2023-08-02 20:49:36,030 - logger - INFO - MDs?: yes
# 2023-08-02 20:49:36,030 - logger - INFO - Scaling?: no
# 2023-08-02 20:49:36,031 - logger - INFO - PCA?: yes
# 2023-08-02 20:49:36,032 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2023-08-02 20:49:36,033 - logger - INFO - PCA - number of components: 50
# 2023-08-02 20:49:36,033 - logger - INFO - Target transform?: yes
# 2023-08-02 20:49:36,034 - logger - INFO - Target binarization?: no
# 2023-08-02 20:49:36,060 - logger - INFO - PCA constructor...
# 2023-08-02 20:49:36,078 - logger - INFO - PCA constructor...
# 2023-08-02 20:49:36,079 - logger - INFO - Optimal hyperparameters:, {'n_estimators': 167, 'max_depth': 15, 'min_child_weight': 5.0, 'eta': 0.05039477726622274, 'subsample': 0.9955832032066043, 'colsample_bytree': 0.667532485513278, 'gamma': 0.016631471565583755, 'reg_alpha': 0.7268717199928627, 'reg_lambda': 0.6581110305456547, 'objective': 'reg:squarederror'}
# 2023-08-02 20:49:36,080 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:49:36,081 - logger - INFO - CreateFPS transform...
# [20:49:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [20:49:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
# 100%|██████████| 1417/1417 [00:01<00:00, 939.42it/s]
# 2023-08-02 20:49:39,854 - logger - INFO - Scaler fit...
# 2023-08-02 20:49:40,073 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:49:40,074 - logger - INFO - CreateFPS transform...
# 100%|██████████| 158/158 [00:00<00:00, 990.64it/s]
# 2023-08-02 20:49:40,495 - logger - INFO - PCA transform...
# C:\Users\rbachorz\Projects\qsarmodeler\qsarmodeler\qsprmodeler\auxiliary\various.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=confidence, cmap="gray")
# 2023-08-02 20:49:40,774 - logger - INFO - R2 score on test: 0.3155334486999357
# 2023-08-02 20:49:40,775 - logger - INFO - MSE score on test: 0.7193496639880895
# 2023-08-02 20:49:40,775 - logger - INFO - MSLE score on test: 0.7193496639880895
# 2023-08-02 20:49:40,775 - logger - INFO - MAE score on test: 0.6721736759900505
# 2023-08-02 20:49:40,776 - logger - INFO - MAPE score on test: 0.10646959951915252
# 2023-08-02 20:49:40,777 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:49:40,777 - logger - INFO - CreateFPS transform...
# 100%|██████████| 1417/1417 [00:01<00:00, 975.82it/s]
# 2023-08-02 20:49:44,463 - logger - INFO - Scaler fit...
# 2023-08-02 20:49:44,672 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:49:44,673 - logger - INFO - CreateFPS transform...
# 100%|██████████| 1417/1417 [00:01<00:00, 930.18it/s]
# 2023-08-02 20:49:48,607 - logger - INFO - PCA transform...
# C:\Users\rbachorz\Projects\qsarmodeler\qsarmodeler\qsprmodeler\auxiliary\various.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=confidence, cmap="gray")
# 2023-08-02 20:49:48,730 - logger - INFO - R2 score on training: 0.7230959376499988
# 2023-08-02 20:49:48,731 - logger - INFO - MSE score on training: 0.31442542559069975
# 2023-08-02 20:49:48,732 - logger - INFO - MSLE score on training: 0.006431910705226771
# 2023-08-02 20:49:48,733 - logger - INFO - MAE score on training: 0.4583542096065845
# 2023-08-02 20:49:48,734 - logger - INFO - MAPE score on training: 0.07302260192175977

# %%
analyze_regressor(TRAINING_CONF_DIR/"ar_xgboost_regressor_pca50_expert_special_data.json")
# Out:
# 2023-08-02 20:50:12,348 - logger - INFO - Training configuration:
# 2023-08-02 20:50:12,349 - logger - INFO - Prediction methodology: M_XGBoost
# 2023-08-02 20:50:12,350 - logger - INFO - Prediction type: regression
# 2023-08-02 20:50:12,351 - logger - INFO - Data file: C:/Users/rbachorz/Projects/qsarmodeler/qsarmodeler/data/processed/ar_homo_sapiens_chembl_3.3_more_ChEMBL_columnsIC50EC50_combined_expert_regressor_case.csv
# 2023-08-02 20:50:12,351 - logger - INFO - Max. activity level: 1
# 2023-08-02 20:50:12,352 - logger - INFO - Std. threshold: 100
# 2023-08-02 20:50:12,353 - logger - INFO - Data preparation strategy: median
# 2023-08-02 20:50:12,353 - logger - INFO - Model storage: C:/Users/rbachorz/Projects/qsarmodeler/qsarmodeler/models/ar_xgboost_regressor_pca50_expert_special_data.model
# 2023-08-02 20:50:12,354 - logger - INFO - Pipeline configuration:
# 2023-08-02 20:50:12,355 - logger - INFO - FPs?: yes
# 2023-08-02 20:50:12,355 - logger - INFO - FP size?: 1024
# 2023-08-02 20:50:12,356 - logger - INFO - MDs?: yes
# 2023-08-02 20:50:12,357 - logger - INFO - Scaling?: no
# 2023-08-02 20:50:12,357 - logger - INFO - PCA?: yes
# 2023-08-02 20:50:12,358 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2023-08-02 20:50:12,358 - logger - INFO - PCA - number of components: 50
# 2023-08-02 20:50:12,358 - logger - INFO - Target transform?: yes
# 2023-08-02 20:50:12,359 - logger - INFO - Target binarization?: no
# 2023-08-02 20:50:12,377 - logger - INFO - PCA constructor...
# 2023-08-02 20:50:12,395 - logger - INFO - PCA constructor...
# 2023-08-02 20:50:12,396 - logger - INFO - Optimal hyperparameters:, {'n_estimators': 165, 'max_depth': 19, 'min_child_weight': 4.0, 'eta': 0.052721384855039896, 'subsample': 0.9127439987113598, 'colsample_bytree': 0.9467561247394345, 'gamma': 1.146865724752578, 'reg_alpha': 0.18363195123299003, 'reg_lambda': 0.891897577803261, 'objective': 'reg:squarederror'}
# 2023-08-02 20:50:12,397 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:12,397 - logger - INFO - CreateFPS transform...
# [20:50:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [20:50:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
# 100%|██████████| 1211/1211 [00:01<00:00, 989.46it/s]
# 2023-08-02 20:50:15,498 - logger - INFO - Scaler fit...
# 2023-08-02 20:50:15,689 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:15,690 - logger - INFO - CreateFPS transform...
# 100%|██████████| 135/135 [00:00<00:00, 1002.34it/s]
# 2023-08-02 20:50:16,041 - logger - INFO - PCA transform...
# C:\Users\rbachorz\Projects\qsarmodeler\qsarmodeler\qsprmodeler\auxiliary\various.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=confidence, cmap="gray")
# 2023-08-02 20:50:16,124 - logger - INFO - R2 score on test: 0.20536933110005162
# 2023-08-02 20:50:16,125 - logger - INFO - MSE score on test: 0.6103924313913633
# 2023-08-02 20:50:16,125 - logger - INFO - MSLE score on test: 0.6103924313913633
# 2023-08-02 20:50:16,126 - logger - INFO - MAE score on test: 0.6411167459369269
# 2023-08-02 20:50:16,126 - logger - INFO - MAPE score on test: 0.09874524794303889
# 2023-08-02 20:50:16,127 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:16,128 - logger - INFO - CreateFPS transform...
# 100%|██████████| 1211/1211 [00:01<00:00, 955.33it/s]
# 2023-08-02 20:50:19,543 - logger - INFO - Scaler fit...
# 2023-08-02 20:50:19,751 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:19,752 - logger - INFO - CreateFPS transform...
# 100%|██████████| 1211/1211 [00:01<00:00, 762.75it/s]
# 2023-08-02 20:50:23,529 - logger - INFO - PCA transform...
# C:\Users\rbachorz\Projects\qsarmodeler\qsarmodeler\qsprmodeler\auxiliary\various.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=confidence, cmap="gray")
# 2023-08-02 20:50:23,652 - logger - INFO - R2 score on training: 0.611395400129318
# 2023-08-02 20:50:23,654 - logger - INFO - MSE score on training: 0.3600655755855143
# 2023-08-02 20:50:23,654 - logger - INFO - MSLE score on training: 0.006532186505127327
# 2023-08-02 20:50:23,655 - logger - INFO - MAE score on training: 0.5100376122236766
# 2023-08-02 20:50:23,656 - logger - INFO - MAPE score on training: 0.076945458291083

# %%
analyze_classifier(TRAINING_CONF_DIR/"ar_xgboost_classifier_pca50_expert.json")
# Out:
# 2023-08-02 20:50:33,233 - logger - INFO - Training configuration:
# 2023-08-02 20:50:33,234 - logger - INFO - Prediction methodology: M_XGBoost
# 2023-08-02 20:50:33,235 - logger - INFO - Prediction type: classification
# 2023-08-02 20:50:33,236 - logger - INFO - Data file: C:/Users/rbachorz/Projects/qsarmodeler/qsarmodeler/data/processed/ar_homo_sapiens_chembl_3.3_more_ChEMBL_columnsIC50EC50_combined_expert.csv
# 2023-08-02 20:50:33,238 - logger - INFO - Max. activity level: 1
# 2023-08-02 20:50:33,238 - logger - INFO - Std. threshold: 100
# 2023-08-02 20:50:33,238 - logger - INFO - Data preparation strategy: median
# 2023-08-02 20:50:33,238 - logger - INFO - Model storage: C:/Users/rbachorz/Projects/qsarmodeler/qsarmodeler/models/ar_xgboost_classifier_pca50_expert.model
# 2023-08-02 20:50:33,238 - logger - INFO - Pipeline configuration:
# 2023-08-02 20:50:33,238 - logger - INFO - FPs?: yes
# 2023-08-02 20:50:33,238 - logger - INFO - FP size?: 1024
# 2023-08-02 20:50:33,238 - logger - INFO - MDs?: yes
# 2023-08-02 20:50:33,238 - logger - INFO - Scaling?: no
# 2023-08-02 20:50:33,238 - logger - INFO - PCA?: yes
# 2023-08-02 20:50:33,238 - logger - INFO - PCA - apply to MD, FP?: no, yes
# 2023-08-02 20:50:33,238 - logger - INFO - PCA - number of components: 20
# 2023-08-02 20:50:33,254 - logger - INFO - Target transform?: no
# 2023-08-02 20:50:33,255 - logger - INFO - Target binarization?: yes
# 2023-08-02 20:50:33,277 - logger - INFO - PCA constructor...
# 2023-08-02 20:50:33,279 - logger - INFO - Optimal hyperparameters:, {'n_estimators': 148, 'max_depth': 13, 'min_child_weight': 3.0, 'eta': 0.051240760426061904, 'subsample': 0.8935060800384628, 'colsample_bytree': 0.8686035048893569, 'gamma': 1.5150785233568003, 'reg_alpha': 0.26666559173910065, 'reg_lambda': 0.7682015833394459, 'objective': 'reg:logistic'}
# 2023-08-02 20:50:33,280 - logger - INFO - Performance on external (hold-out) set
# 2023-08-02 20:50:33,281 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:33,282 - logger - INFO - CreateFPS transform...
# [20:50:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
# 100%|██████████| 1417/1417 [00:01<00:00, 992.24it/s]
# 2023-08-02 20:50:36,924 - logger - INFO - Scaler fit...
# 2023-08-02 20:50:37,019 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:37,019 - logger - INFO - CreateFPS transform...
# 100%|██████████| 158/158 [00:00<00:00, 982.42it/s]
# 2023-08-02 20:50:37,437 - logger - INFO - PCA transform...
# 2023-08-02 20:50:37,618 - logger - INFO - Precision on hold-out: 0.813187
# 2023-08-02 20:50:37,619 - logger - INFO - Recall on hold-out: 0.850575
# 2023-08-02 20:50:37,620 - logger - INFO - Accuracy on hold-out: 0.810127
# 2023-08-02 20:50:37,620 - logger - INFO - F1-score on hold-out: 0.831461
# 2023-08-02 20:50:37,621 - logger - INFO - ROC-AUC on hold-out: 0.805569
# 2023-08-02 20:50:37,621 - logger - INFO - Average precision on hold-out: 0.773955
# 2023-08-02 20:50:37,622 - logger - INFO - MCC on hold-out: 0.615134
# 2023-08-02 20:50:37,720 - logger - INFO - Performance on training set
# 2023-08-02 20:50:37,721 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:37,721 - logger - INFO - CreateFPS transform...
# 100%|██████████| 1417/1417 [00:01<00:00, 963.85it/s]
# 2023-08-02 20:50:41,679 - logger - INFO - Scaler fit...
# 2023-08-02 20:50:41,815 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:50:41,816 - logger - INFO - CreateFPS transform...
# 100%|██████████| 1417/1417 [00:01<00:00, 921.23it/s]
# 2023-08-02 20:50:46,309 - logger - INFO - PCA transform...
# 2023-08-02 20:50:46,568 - logger - INFO - Precision on training: 0.959135
# 2023-08-02 20:50:46,569 - logger - INFO - Recall on training: 0.976744
# 2023-08-02 20:50:46,569 - logger - INFO - Accuracy on training: 0.962597
# 2023-08-02 20:50:46,570 - logger - INFO - F1-score on training: 0.967859
# 2023-08-02 20:50:46,572 - logger - INFO - ROC-AUC on training: 0.960039
# 2023-08-02 20:50:46,573 - logger - INFO - Average precision on training: 0.950238
# 2023-08-02 20:50:46,573 - logger - INFO - MCC on training 0.923361

# %% [markdown]
# # Model exposure to external data sets

# %% [markdown]
# ## Read in the external data

# %%
CANDIDATES_DATA = Path("../data/candidates/candidates.smi")
smiles = pd.read_csv(CANDIDATES_DATA, sep="\t")
smiles.head(5)
# Out:
#                                               SMILES  Identifier
# 0   C(N(Cc1cc(Br)c(NC(=O)CCC(=O)N)cc1)C)(=O)c2ccccc2        6155
# 1  C(=O)(c1ccc(cc1)CN(c2ccc(cc2)C)Cc3cc(C(=O)N)cc...        7898
# 2  C(=O)(Nc1c(Cl)c(-c2nc(sc2)NC(=O)C)c(cc1)CN(C=O...        2863
# 3    C(=O)(Nc1cnc(cc1)CN(c2ccccc2)C)Cc3c4n(cc3)CCCC4        5620
# 4  C(=O)(C1=C(N(C(=O)C1)C2CCCCC2)CC)NC3C(=O)NC(=N...        7058

# %%
preds = get_model_ext_predictions(TRAINING_CONF_DIR/"ar_xgboost_classifier_pca50_expert.json", smiles["SMILES"])
# Out:
# 2023-08-02 20:51:02,613 - logger - INFO - PCA constructor...
# 2023-08-02 20:51:02,614 - logger - INFO - Optimal hyperparameters:, {'n_estimators': 148, 'max_depth': 13, 'min_child_weight': 3.0, 'eta': 0.051240760426061904, 'subsample': 0.8935060800384628, 'colsample_bytree': 0.8686035048893569, 'gamma': 1.5150785233568003, 'reg_alpha': 0.26666559173910065, 'reg_lambda': 0.7682015833394459, 'objective': 'reg:logistic'}
# 2023-08-02 20:51:02,615 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:51:02,616 - logger - INFO - CreateFPS transform...
# [20:51:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
# 100%|██████████| 1417/1417 [00:01<00:00, 960.21it/s]
# 2023-08-02 20:51:06,461 - logger - INFO - Scaler fit...
# 2023-08-02 20:51:06,558 - logger - INFO - CreateFPS fit...
# 2023-08-02 20:51:06,559 - logger - INFO - CreateFPS transform...
# 100%|██████████| 60/60 [00:00<00:00, 835.89it/s]
# 2023-08-02 20:51:06,748 - logger - INFO - PCA transform...

# %%
plt.hist(preds, bins=20)
plt.grid(True)
plt.xlabel("Positive class probability")
plt.ylabel("Sample count")
plt.title("Distribution of positive class probabilities from external set")
# Out:
# Text(0.5, 1.0, 'Distribution of positive class probabilities from external set')

# %%
df = pd.concat([smiles, preds], axis=1)
df.columns = ["SMILES", "Identifier", "Prediction"]
df.head()
# Out:
#                                               SMILES  Identifier  Prediction
# 0   C(N(Cc1cc(Br)c(NC(=O)CCC(=O)N)cc1)C)(=O)c2ccccc2        6155    0.070311
# 1  C(=O)(c1ccc(cc1)CN(c2ccc(cc2)C)Cc3cc(C(=O)N)cc...        7898    0.742082
# 2  C(=O)(Nc1c(Cl)c(-c2nc(sc2)NC(=O)C)c(cc1)CN(C=O...        2863    0.215952
# 3    C(=O)(Nc1cnc(cc1)CN(c2ccccc2)C)Cc3c4n(cc3)CCCC4        5620    0.374334
# 4  C(=O)(C1=C(N(C(=O)C1)C2CCCCC2)CC)NC3C(=O)NC(=N...        7058    0.460402

# %%
threshold = 0.7
df_promissing = df[df["Prediction"] > threshold]
promissing_smiles = df_promissing["SMILES"].tolist()
probabilities = df_promissing["Prediction"].astype(str).tolist()
df_promissing
# Out:
#                                                SMILES  Identifier  Prediction
# 1   C(=O)(c1ccc(cc1)CN(c2ccc(cc2)C)Cc3cc(C(=O)N)cc...        7898    0.742082
# 21  C(=O)(Nc1c(-c2c(Cl)[nH]cc2)c(cc(O)c1)C3N(C(=O)...        9162    0.726154
# 37  C(=O)(c1ccc(cc1)CN(c2c3c(c(cc2)C)CCCC3)Cc4cc(C...        9079    0.827010
# 53  C(=O)(c1ccc(cc1)CN(c2c3c(c(cc2)C)CCCC3)Cc4cc(C...        9509    0.710023

# %%
mols = [Chem.MolFromSmiles(s) for s in promissing_smiles]
Draw.MolsToGridImage(mols, legends=probabilities)
